# %% [markdown]
# # PV-BESS optimizer

# %% [markdown]
# ### Example Jupyter notebook for scheduling a PV-BESS system using the Pyomo optimization framework.
# This jupyter notebook generates schedules for the marketing of the energy provided by a combination of a PV plant and a battery storage system (BESS) and calculates the corresponding profits on the day-ahead and intraday markets (DAA, IDA and IDC).
#
# This notebook uses historic market price data and PV production profiles and therefore represents a backtest following the principle of a perfect foresight.
#
# The schedules are generated by functions of the scheduler_three_market.py module, which make use of the Pyomo modelling framework for mathematical opimization. Each function includes an objective and several constraints, which can be reviewed in the module.

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries
from scheduler_three_market import get_daa_schedule, get_ida_schedule, get_idc_schedule # Import the scheduler module which contains the Pyomo model and optimization logic
import matplotlib.pyplot as plt  # Import matplotlib for plotting results
import pandas as pd  # Import pandas for data handling

# %% [markdown]
# ### Set the input parameters

# %%
# BESS (Battery Energy Storage System) parameters
p_limit = 80.0 # 13.5  # Maximum injection power limit in MW
storage_capacity = 80/3 # Storage capacity in MWh
p_charge_max = 80/6 # Maximum charge power in MW
p_discharge_max = 80/6 # Maximum discharge power MW
efficiency = 0.95 # Charge/discharge efficiency of the BESS
start_soc = 0.0  # Initial state of charge
end_soc = 0.0  # End state of charge, can be adjusted as needed
number_of_cycles = 2 * 7  # Number of cycles for the period (weeks)

# General parameters
number_of_weeks = 52  # Number of weeks in the year
year = '2024'  # Year for which the data is being processed

# Commercial parameters
applicable_value = 220 # Strike price for the plant from EEG or tender ("anzulegender Wert") in €/MWh

# %% [markdown]
# ### Year data dictionary

# %%
year_data = {
            # '2020': [24.6,'./data/2020/DA/2020_daa.csv',
            #                   './data/2020/IDA/2020_ida.csv' ,
            #                   './data/2020/ID1/2020_id1.csv',
            #                   './data/2020/PV/2020_pv.csv',
            #                   '2020-01-06 00:00:00'], 
            #  '2021': [75.5,'./data/2021/DA/2021_daa.csv',
            #                   './data/2021/IDA/2021_ida.csv' ,
            #                   './data/2021/ID1/2021_id1.csv',
            #                   './data/2021/PV/2021_pv.csv',
            #                   '2021-01-04 00:00:00'], 
            #  '2022': [223.1,'./data/2022/DA/2022_daa.csv',
            #                   './data/2022/IDA/2022_ida.csv' ,
            #                   './data/2022/ID1/2022_id1.csv',
            #                   './data/2022/PV/2022_pv.csv',
            #                   '2022-01-03 00:00:00'], 
            #  '2023': [72.0,'./data/2023/DA/2023_daa.csv',
            #                   './data/2023/IDA/2023_ida.csv' ,
            #                   './data/2023/ID1/2023_id1.csv',
            #                   './data/2023/PV/2023_pv.csv',
            #                   '2023-01-02 00:00:00'],
             '2024': [46.24,'./data/2024/DA/2024_daa.csv',
                              './data/2024/IDA/2024_ida.csv' ,
                              './data/2024/ID1/2024_id1.csv',
                              './data/2024/PV/2024_pv.csv',
                              '2024-01-01 00:00:00'], 
            }
# Extract the market value (capture price) for the specified year
market_value = year_data[year][0]

# %% [markdown]
# ### Load DAA, IDA and IDC data from files

# %%
daa = pd.read_csv(year_data[year][1], index_col = 0)
daa.index = pd.to_datetime(daa.index)

ida = pd.read_csv(year_data[year][2], index_col = 0)
ida.index = pd.to_datetime(ida.index)

idc = pd.read_csv(year_data[year][3], index_col = 0)
idc.index = pd.to_datetime(idc.index)

# %% [markdown]
# ### Load PV load profile from .csv:

# %%
pv = pd.read_csv(year_data[year][4], index_col = 0)
pv.index = pd.to_datetime(pv.index)
pv.PV = [max(0, v) for v in pv.PV] # Set negative values to zero

# %% [markdown]
# ### Get the optimzized schedule
# This is done for weekly time slices. The results for the single weeks are then concatenated into a result dataframe.

# %%
start = pd.to_datetime(year_data[year][5])
end = start + pd.DateOffset(days=7) - pd.DateOffset(minutes=15)  # Set end to the next week minus 15 minutes
result_list = []

for i in range(1, number_of_weeks + 1):
    print('start/end', start, end)
    pv_vector = pv.PV[start:end].to_list()
    daa_price_vector = daa.DAA[start:end].to_list()
    ida_price_vector = ida.IDA[start:end].to_list()
    idc_price_vector = idc.ID1[start:end].to_list()

    # Ensure the vectors are not empty
    if not pv_vector or not daa_price_vector or not ida_price_vector or not idc_price_vector:
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors cannot be empty.")

    # Ensure the vectors are of the same length
    if len(pv_vector) != len(daa_price_vector) or len(pv_vector) != len(ida_price_vector) or len(pv_vector) != len(idc_price_vector):
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors must have the same length.")

    pv_output, daa_price, p_charge_daa, p_discharge_daa, soc_daa, p_curtailed_daa, injection_power_daa = get_daa_schedule(pv_vector,
                                                                                                  daa_price_vector, 
                                                                                                  p_limit, 
                                                                                                  storage_capacity, 
                                                                                                  p_charge_max, 
                                                                                                  p_discharge_max, 
                                                                                                  number_of_cycles, 
                                                                                                  efficiency, 
                                                                                                  start_soc, 
                                                                                                  end_soc)

    ida_price, p_charge_ida, p_discharge_ida, p_close_charge_daa, p_close_discharge_daa, p_curtailed_ida, \
        p_close_curtailed_daa, p_curtailed_daa_ida ,p_charge_daa_ida, p_discharge_daa_ida, soc_ida, injection_power_ida = get_ida_schedule(
                                                                                                                        ida_price_vector, 
                                                                                                                        pv_output,
                                                                                                                        p_limit, 
                                                                                                                        storage_capacity, 
                                                                                                                        p_charge_max, 
                                                                                                                        p_discharge_max,
                                                                                                                        p_charge_daa,
                                                                                                                        p_discharge_daa,
                                                                                                                        p_curtailed_daa,
                                                                                                                        number_of_cycles, 
                                                                                                                        efficiency, 
                                                                                                                        start_soc, 
                                                                                                                        end_soc)
    
    idc_price, p_charge_idc, p_discharge_idc, p_close_charge_daa_ida, p_close_discharge_daa_ida, p_curtailed_idc, \
        p_close_curtailed_daa_ida, p_curtailed_daa_ida_idc, p_charge_daa_ida_idc, p_discharge_daa_ida_idc, soc_idc, injection_power_idc = get_idc_schedule(    
                                                                                                                                idc_price_vector,
                                                                                                                                pv_output, 
                                                                                                                                p_limit, 
                                                                                                                                storage_capacity, 
                                                                                                                                p_charge_max, 
                                                                                                                                p_discharge_max,
                                                                                                                                p_charge_daa_ida,
                                                                                                                                p_discharge_daa_ida,
                                                                                                                                p_curtailed_daa_ida,
                                                                                                                                number_of_cycles, 
                                                                                                                                efficiency, 
                                                                                                                                start_soc, 
                                                                                                                                end_soc
                                                                                                                            )

    # Create a DataFrame to store the results for the current week
    result = pd.DataFrame({# prices and PV output
                           'daa_price': daa_price,
                           'ida_price': ida_price,
                           'idc_price': idc_price,
                           'pv_output': pv_output,
                            # DAA results
                           'p_charge_daa': p_charge_daa,
                           'p_discharge_daa': p_discharge_daa,
                           'p_curtailed_daa': p_curtailed_daa,
                           'soc_daa': soc_daa,
                           'injection_power_daa': injection_power_daa,
                           # IDA results
                           'p_charge_ida': p_charge_ida,
                           'p_discharge_ida': p_discharge_ida,
                           'p_close_charge_daa': p_close_charge_daa,
                           'p_close_discharge_daa': p_close_discharge_daa,
                           'p_curtailed_ida': p_curtailed_ida,
                           'p_close_curtailed_daa': p_close_curtailed_daa,
                           'p_charge_daa_ida': p_charge_daa_ida,
                           'p_discharge_daa_ida': p_discharge_daa_ida,
                           'p_curtailed_daa_ida': p_curtailed_daa_ida,
                           'soc_ida': soc_ida,
                           'injection_power_ida': injection_power_ida,
                           # IDC results
                           'p_charge_idc': p_charge_idc,
                           'p_discharge_idc': p_discharge_idc,
                           'p_close_charge_daa_ida': p_close_charge_daa_ida,
                           'p_close_discharge_daa_ida': p_close_discharge_daa_ida,
                           'p_curtailed_idc': p_curtailed_idc,
                           'p_close_curtailed_daa_ida': p_close_curtailed_daa_ida,
                           'p_charge_daa_ida_idc': p_charge_daa_ida_idc,
                           'p_discharge_daa_ida_idc': p_discharge_daa_ida_idc,
                           'p_curtailed_daa_ida_idc': p_curtailed_daa_ida_idc,
                           'soc_idc': soc_idc,
                           'injection_power_idc': injection_power_idc
                          }
                         )
    
    result.index = pd.date_range(start=start, end=end, freq='15min')
    
    result_list.append(result)

    start = start + pd.DateOffset(days=7) # Set start and end to the next week
    end = end + pd.DateOffset(days=7)
    
results = pd.concat(result_list)
# Out:
# start/end 2024-01-01 00:00:00 2024-01-07 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14984 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [8e-03, 4e+01]
#   Cost    [3e-03, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [8e-03, 4e+02]
# Presolving model
# 4230 rows, 2687 cols, 9406 nonzeros  0s
# 2194 rows, 2212 cols, 6873 nonzeros  0s
# 1672 rows, 1275 cols, 4029 nonzeros  0s
# 1222 rows, 1273 cols, 3127 nonzeros  0s
# Presolve reductions: rows 1222(-6174); columns 1273(-2760); nonzeros 3127(-11857)
#
# Solving MIP model with:
#    1222 rows
#    1273 cols (220 binary, 0 integer, 0 implied int., 1053 continuous, 0 domain fixed)
#    3127 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             20256.959247       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   24684.206489    24181.047332       2.08%        0      0      0       811     0.1s
#  C       0       0         0   0.00%   24684.206489    24222.294885       1.91%      167     71      0       884     0.1s
#  L       0       0         0   0.00%   24684.206489    24684.206489       0.00%      224     82      0       901     0.2s
#          1       0         1 100.00%   24684.206489    24684.206489       0.00%      224     82      0       943     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      24684.2064889
#   Dual bound        24684.2064889
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0308761654689
#   Solution status   feasible
#                     24684.2064889 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.19
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     943
#                     0 (strong br.)
#                     90 (separation)
#                     42 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [8.43769e-16, 8.43769e-16] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31429 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [8e-03, 4e+01]
#   Cost    [2e-02, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 3e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9056 rows, 2931 cols, 14497 nonzeros  0s
# 2561 rows, 2452 cols, 7938 nonzeros  0s
# 1532 rows, 1461 cols, 4080 nonzeros  0s
# 1498 rows, 1461 cols, 4012 nonzeros  0s
# Presolve reductions: rows 1498(-11274); columns 1461(-6604); nonzeros 4012(-27417)
#
# Solving MIP model with:
#    1498 rows
#    1461 cols (297 binary, 0 integer, 0 implied int., 1164 continuous, 0 domain fixed)
#    4012 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4568.022408       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1766.970305     1585.453273       11.45%        0      0      0      1011     0.1s
#  H       0       0         0   0.00%   1766.970305     1766.970305        0.00%      135     57      0      1073     0.1s
#          1       0         1 100.00%   1766.970305     1766.970305        0.00%      135     57      0      1073     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1766.97030476
#   Dual bound        1766.97030476
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.346724924908
#   Solution status   feasible
#                     1766.97030476 (objective)
#                     0 (bound viol.)
#                     2.95975024393e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1073
#                     0 (strong br.)
#                     62 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 17 |values| in [1.97215e-31, 1.36779e-13] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31477 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [8e-03, 4e+01]
#   Cost    [3e-02, 5e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [5e-32, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9119 rows, 3057 cols, 15024 nonzeros  0s
# 2731 rows, 2573 cols, 8432 nonzeros  0s
# 1664 rows, 1551 cols, 4457 nonzeros  0s
# 1639 rows, 1551 cols, 4407 nonzeros  0s
# Presolve reductions: rows 1639(-11133); columns 1551(-6514); nonzeros 4407(-27070)
#
# Solving MIP model with:
#    1639 rows
#    1551 cols (341 binary, 0 integer, 0 implied int., 1210 continuous, 0 domain fixed)
#    4407 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4503.224838       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3020.134344     2753.594003        9.68%        0      0      0      1003     0.1s
#  C       0       0         0   0.00%   3020.134344     2808.7048          7.53%      133     50      0      1055     0.1s
#  H       0       0         0   0.00%   3020.134344     3020.134344        0.00%      136     51      0      1058     0.1s
#          1       0         1 100.00%   3020.134344     3020.134344        0.00%      136     51      0      1058     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3020.13434363
#   Dual bound        3020.13434363
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.374534823911
#   Solution status   feasible
#                     3020.13434363 (objective)
#                     0 (bound viol.)
#                     8.77076189454e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1058
#                     0 (strong br.)
#                     55 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-08 00:00:00 2024-01-14 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15002 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [2e+01, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-02, 4e+02]
# Presolving model
# 4248 rows, 2687 cols, 9406 nonzeros  0s
# 2155 rows, 2230 cols, 6777 nonzeros  0s
# 1629 rows, 1282 cols, 3901 nonzeros  0s
# 1180 rows, 1280 cols, 3001 nonzeros  0s
# Presolve reductions: rows 1180(-6216); columns 1280(-2753); nonzeros 3001(-12001)
#
# Solving MIP model with:
#    1180 rows
#    1280 cols (214 binary, 0 integer, 0 implied int., 1066 continuous, 0 domain fixed)
#    3001 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             78640.380694       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   82052.744724    81748.872282       0.37%        0      0      0       810     0.1s
#  L       0       0         0   0.00%   82052.744724    82052.744724       0.00%      186     70      0       901     0.2s
#          1       0         1 100.00%   82052.744724    82052.744724       0.00%      186     70      0       936     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      82052.7447239
#   Dual bound        82052.7447239
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.00984682651762
#   Solution status   feasible
#                     82052.7447239 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.17
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     936
#                     0 (strong br.)
#                     91 (separation)
#                     35 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31478 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [1e+01, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-16, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9085 rows, 2953 cols, 14592 nonzeros  0s
# 2523 rows, 2459 cols, 7853 nonzeros  0s
# 1822 rows, 1368 cols, 4617 nonzeros  0s
# 1334 rows, 1366 cols, 3569 nonzeros  0s
# Presolve reductions: rows 1334(-11438); columns 1366(-6699); nonzeros 3569(-27909)
#
# Solving MIP model with:
#    1334 rows
#    1366 cols (241 binary, 0 integer, 0 implied int., 1125 continuous, 0 domain fixed)
#    3569 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -3455.169417       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3511.524002     3337.2928          5.22%        0      0      0      1011     0.1s
#  C       0       0         0   0.00%   3511.524002     3352.283766        4.75%      160     55      0      1069     0.1s
#  L       0       0         0   0.00%   3511.524002     3511.524002        0.00%      178     62      0      1079     0.2s
#          1       0         1 100.00%   3511.524002     3511.524002        0.00%      178     62      0      1180     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3511.52400195
#   Dual bound        3511.52400195
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.489508066478
#   Solution status   feasible
#                     3511.52400195 (objective)
#                     0 (bound viol.)
#                     3.33066907388e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.22
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1180
#                     0 (strong br.)
#                     68 (separation)
#                     101 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 25 |values| in [3.55271e-16, 3.73035e-14] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31547 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [6e+00, 1e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9154 rows, 3091 cols, 15189 nonzeros  0s
# 2720 rows, 2578 cols, 8463 nonzeros  0s
# 1952 rows, 1425 cols, 5065 nonzeros  0s
# 1448 rows, 1423 cols, 3962 nonzeros  0s
# Presolve reductions: rows 1448(-11324); columns 1423(-6642); nonzeros 3962(-27585)
#
# Solving MIP model with:
#    1448 rows
#    1423 cols (267 binary, 0 integer, 0 implied int., 1156 continuous, 0 domain fixed)
#    3962 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4082.285093       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   6640.868219     6541.450074        1.52%        0      0      0       974     0.1s
#  H       0       0         0   0.00%   6640.868219     6640.868219        0.00%      113     45      0      1027     0.1s
#          1       0         1 100.00%   6640.868219     6640.868219        0.00%      113     45      0      1027     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      6640.86821893
#   Dual bound        6640.86821893
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.62870683175
#   Solution status   feasible
#                     6640.86821893 (objective)
#                     0 (bound viol.)
#                     2.14273043753e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.14
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1027
#                     0 (strong br.)
#                     53 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-15 00:00:00 2024-01-21 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14933 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [7e-03, 1e+01]
#   Cost    [9e+00, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [7e-03, 4e+02]
# Presolving model
# 4179 rows, 2687 cols, 9406 nonzeros  0s
# 2162 rows, 2161 cols, 6860 nonzeros  0s
# 1563 rows, 1073 cols, 3562 nonzeros  0s
# 1070 rows, 1071 cols, 2574 nonzeros  0s
# 1023 rows, 1071 cols, 2336 nonzeros  0s
# Presolve reductions: rows 1023(-6373); columns 1071(-2962); nonzeros 2336(-12597)
#
# Solving MIP model with:
#    1023 rows
#    1071 cols (145 binary, 0 integer, 0 implied int., 926 continuous, 0 domain fixed)
#    2336 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             5343.501336        Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   7129.941007     6563.372259        8.63%        0      0      0       884     0.1s
#  L       0       0         0   0.00%   7129.941007     7129.941007        0.00%      245     89      0       973     0.1s
#          1       0         1 100.00%   7129.941007     7129.941007        0.00%      245     89      0      1055     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      7129.94100668
#   Dual bound        7129.94100668
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.108969377057
#   Solution status   feasible
#                     7129.94100668 (objective)
#                     0 (bound viol.)
#                     7.12763181809e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.12
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1055
#                     0 (strong br.)
#                     89 (separation)
#                     82 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 2 |values| in [6.75016e-15, 1.01252e-14] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31361 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [7e-03, 1e+01]
#   Cost    [6e+00, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 3e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9037 rows, 2995 cols, 14802 nonzeros  0s
# 2627 rows, 2471 cols, 8229 nonzeros  0s
# 1503 rows, 1368 cols, 3908 nonzeros  0s
# 1478 rows, 1368 cols, 3858 nonzeros  0s
# Presolve reductions: rows 1478(-11294); columns 1368(-6697); nonzeros 3858(-27503)
#
# Solving MIP model with:
#    1478 rows
#    1368 cols (282 binary, 0 integer, 0 implied int., 1086 continuous, 0 domain fixed)
#    3858 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2203.669684       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   730.1480994     714.8904512        2.13%        0      0      0      1046     0.1s
#  H       0       0         0   0.00%   730.1480994     730.1480994        0.00%      106     30      0      1074     0.1s
#          1       0         1 100.00%   730.1480994     730.1480994        0.00%      106     30      0      1074     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      730.148099354
#   Dual bound        730.148099354
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.774976194503
#   Solution status   feasible
#                     730.148099354 (objective)
#                     0 (bound viol.)
#                     3.14436355478e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.14
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1074
#                     0 (strong br.)
#                     28 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 13 |values| in [1.57772e-30, 1.77636e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31366 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [7e-03, 1e+01]
#   Cost    [3e+00, 5e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [4e-31, 3e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9042 rows, 3005 cols, 14843 nonzeros  0s
# 2642 rows, 2481 cols, 8270 nonzeros  0s
# 1518 rows, 1378 cols, 3949 nonzeros  0s
# 1494 rows, 1378 cols, 3901 nonzeros  0s
# Presolve reductions: rows 1494(-11278); columns 1378(-6687); nonzeros 3901(-27465)
#
# Solving MIP model with:
#    1494 rows
#    1378 cols (287 binary, 0 integer, 0 implied int., 1091 continuous, 0 domain fixed)
#    3901 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -938.1575094       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   962.9637325     957.7710132        0.54%        0      0      0      1025     0.1s
#  H       0       0         0   0.00%   962.9637325     962.9637325        0.00%      110     26      0      1055     0.1s
#          1       0         1 100.00%   962.9637325     962.9637325        0.00%      110     26      0      1055     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      962.963732512
#   Dual bound        962.963732512
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.62532608813
#   Solution status   feasible
#                     962.963732512 (objective)
#                     0 (bound viol.)
#                     1.55431223448e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1055
#                     0 (strong br.)
#                     30 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-22 00:00:00 2024-01-28 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15016 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [7e-03, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 4e+02]
# Presolving model
# 4262 rows, 2687 cols, 9406 nonzeros  0s
# 2191 rows, 2244 cols, 6835 nonzeros  0s
# 1697 rows, 1363 cols, 4159 nonzeros  0s
# 1280 rows, 1361 cols, 3323 nonzeros  0s
# Presolve reductions: rows 1280(-6116); columns 1361(-2672); nonzeros 3323(-11693)
#
# Solving MIP model with:
#    1280 rows
#    1361 cols (248 binary, 0 integer, 0 implied int., 1113 continuous, 0 domain fixed)
#    3323 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             34025.747305       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   38738.863975    38269.229372       1.23%        0      0      0       816     0.1s
#  C       0       0         0   0.00%   38738.863975    38292.905081       1.16%      232     72      0       907     0.1s
#  L       0       0         0   0.00%   38738.863975    38738.863975       0.00%      259     82      0       928     0.2s
#          1       0         1 100.00%   38738.863975    38738.863975       0.00%      259     82      0       960     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      38738.8639753
#   Dual bound        38738.8639753
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0155199285868
#   Solution status   feasible
#                     38738.8639753 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     960
#                     0 (strong br.)
#                     112 (separation)
#                     32 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31537 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [2e-03, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-16, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9130 rows, 3015 cols, 14858 nonzeros  0s
# 2667 rows, 2543 cols, 8235 nonzeros  0s
# 1994 rows, 1520 cols, 5205 nonzeros  0s
# 1541 rows, 1518 cols, 4225 nonzeros  0s
# Presolve reductions: rows 1541(-11231); columns 1518(-6547); nonzeros 4225(-27312)
#
# Solving MIP model with:
#    1541 rows
#    1518 cols (305 binary, 0 integer, 0 implied int., 1213 continuous, 0 domain fixed)
#    4225 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -5010.611749       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2771.48125      2556.780698        8.40%        0      0      0      1022     0.1s
#  H       0       0         0   0.00%   2771.48125      2771.48125         0.00%      194     63      0      1102     0.1s
#          1       0         1 100.00%   2771.48125      2771.48125         0.00%      194     63      0      1102     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      2771.48125031
#   Dual bound        2771.48125031
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.32716227331
#   Solution status   feasible
#                     2771.48125031 (objective)
#                     0 (bound viol.)
#                     3.73034936274e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1102
#                     0 (strong br.)
#                     80 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 26 |values| in [1.77636e-15, 8.88178e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31587 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [4e-03, 2e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-16, 1e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9191 rows, 3137 cols, 15369 nonzeros  0s
# 2840 rows, 2657 cols, 8738 nonzeros  0s
# 2147 rows, 1633 cols, 5716 nonzeros  0s
# 1699 rows, 1631 cols, 4733 nonzeros  0s
# Presolve reductions: rows 1699(-11073); columns 1631(-6434); nonzeros 4733(-26854)
#
# Solving MIP model with:
#    1699 rows
#    1631 cols (359 binary, 0 integer, 0 implied int., 1272 continuous, 0 domain fixed)
#    4733 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -6423.584951       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3860.049359     3791.616604        1.80%        0      0      0      1059     0.1s
#  H       0       0         0   0.00%   3860.049359     3860.049359        0.00%      149     45      0      1109     0.2s
#          1       0         1 100.00%   3860.049359     3860.049359        0.00%      149     45      0      1109     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3860.04935908
#   Dual bound        3860.04935908
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.260526456647
#   Solution status   feasible
#                     3860.04935908 (objective)
#                     0 (bound viol.)
#                     2.33146835171e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1109
#                     0 (strong br.)
#                     50 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-29 00:00:00 2024-02-04 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15027 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [3e-02, 5e+01]
#   Cost    [1e-01, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-02, 4e+02]
# Presolving model
# 4273 rows, 2687 cols, 9406 nonzeros  0s
# 2194 rows, 2255 cols, 6830 nonzeros  0s
# 1697 rows, 1359 cols, 4112 nonzeros  0s
# 1265 rows, 1357 cols, 3246 nonzeros  0s
# Presolve reductions: rows 1265(-6131); columns 1357(-2676); nonzeros 3246(-11781)
#
# Solving MIP model with:
#    1265 rows
#    1357 cols (239 binary, 0 integer, 0 implied int., 1118 continuous, 0 domain fixed)
#    3246 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             48067.987696       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   52821.887579    52250.069917       1.09%        0      0      0       831     0.1s
#  L       0       0         0   0.00%   52821.887579    52821.887579       0.00%      204     81      0       925     0.2s
#          1       0         1 100.00%   52821.887579    52821.887579       0.00%      204     81      0       965     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      52821.8875795
#   Dual bound        52821.8875795
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0114591493741
#   Solution status   feasible
#                     52821.8875795 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.17
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     965
#                     0 (strong br.)
#                     94 (separation)
#                     40 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31551 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [3e-02, 5e+01]
#   Cost    [1e-02, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [8e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9133 rows, 2999 cols, 14787 nonzeros  0s
# 2649 rows, 2545 cols, 8139 nonzeros  0s
# 1991 rows, 1536 cols, 5155 nonzeros  0s
# 1537 rows, 1534 cols, 4174 nonzeros  0s
# Presolve reductions: rows 1537(-11235); columns 1534(-6531); nonzeros 4174(-27377)
#
# Solving MIP model with:
#    1537 rows
#    1534 cols (303 binary, 0 integer, 0 implied int., 1231 continuous, 0 domain fixed)
#    4174 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4877.747267       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2604.256089     2422.953936        7.48%        0      0      0      1057     0.1s
#  H       0       0         0   0.00%   2604.256089     2604.256089        0.00%      173     64      0      1126     0.1s
#          1       0         1 100.00%   2604.256089     2604.256089        0.00%      173     64      0      1126     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      2604.2560895
#   Dual bound        2604.2560895
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.291795195179
#   Solution status   feasible
#                     2604.2560895 (objective)
#                     0 (bound viol.)
#                     1.11022302463e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.12
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1126
#                     0 (strong br.)
#                     69 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 24 |values| in [1.77636e-15, 5.32907e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31619 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [3e-02, 5e+01]
#   Cost    [3e-02, 1e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [8e-17, 1e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9227 rows, 3187 cols, 15559 nonzeros  0s
# 2885 rows, 2709 cols, 8834 nonzeros  0s
# 2190 rows, 1692 cols, 5844 nonzeros  0s
# 1749 rows, 1690 cols, 4868 nonzeros  0s
# Presolve reductions: rows 1749(-11023); columns 1690(-6375); nonzeros 4868(-26751)
#
# Solving MIP model with:
#    1749 rows
#    1690 cols (382 binary, 0 integer, 0 implied int., 1308 continuous, 0 domain fixed)
#    4868 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -8422.011623       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3345.395924     3309.862954        1.07%        0      0      0      1078     0.1s
#  T       0       0         0   0.00%   3345.395924     3345.395924        0.00%      164     54      0      1139     0.2s
#          1       0         1 100.00%   3345.395924     3345.395924        0.00%      164     54      0      1139     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3345.39592406
#   Dual bound        3345.39592406
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.274336688252
#   Solution status   feasible
#                     3345.39592406 (objective)
#                     0 (bound viol.)
#                     1.53210777398e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1139
#                     0 (strong br.)
#                     61 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-05 00:00:00 2024-02-11 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15028 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [7e-03, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 4e+02]
# Presolving model
# 4274 rows, 2687 cols, 9406 nonzeros  0s
# 2225 rows, 2256 cols, 6891 nonzeros  0s
# 1721 rows, 1358 cols, 4163 nonzeros  0s
# 1289 rows, 1356 cols, 3297 nonzeros  0s
# Presolve reductions: rows 1289(-6107); columns 1356(-2677); nonzeros 3297(-11731)
#
# Solving MIP model with:
#    1289 rows
#    1356 cols (240 binary, 0 integer, 0 implied int., 1116 continuous, 0 domain fixed)
#    3297 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             33932.088846       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   38298.309808    37268.587094       2.76%        0      0      0       902     0.1s
#  C       0       0         0   0.00%   38298.309808    37339.773826       2.57%      235    100      0      1003     0.1s
#  L       0       0         0   0.00%   38298.309808    38298.309808       0.00%      272    110      0      1018     0.2s
#          1       0         1 100.00%   38298.309808    38298.309808       0.00%      272    110      0      1057     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      38298.3098081
#   Dual bound        38298.3098081
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0220687886224
#   Solution status   feasible
#                     38298.3098081 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.17
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1057
#                     0 (strong br.)
#                     116 (separation)
#                     39 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31566 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [3e-02, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9153 rows, 3037 cols, 14956 nonzeros  0s
# 2734 rows, 2592 cols, 8374 nonzeros  0s
# 2119 rows, 1625 cols, 5490 nonzeros  0s
# 1684 rows, 1623 cols, 4567 nonzeros  0s
# Presolve reductions: rows 1684(-11088); columns 1623(-6442); nonzeros 4567(-26999)
#
# Solving MIP model with:
#    1684 rows
#    1623 cols (355 binary, 0 integer, 0 implied int., 1268 continuous, 0 domain fixed)
#    4567 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4434.922894       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1603.944182     1483.94079         8.09%        0      0      0      1019     0.1s
#  C       0       0         0   0.00%   1603.944182     1498.80246         7.02%      119     43      0      1068     0.1s
#  T       0       0         0   0.00%   1603.944182     1603.944182        0.00%      119     43      0      1068     0.1s
#          1       0         1 100.00%   1603.944182     1603.944182        0.00%      119     43      0      1068     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1603.94418153
#   Dual bound        1603.94418153
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.334589678684
#   Solution status   feasible
#                     1603.94418153 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.13
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1068
#                     0 (strong br.)
#                     49 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 20 |values| in [1.77636e-15, 3.01981e-14] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31592 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 5e+01]
#   Cost    [1e-01, 8e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9174 rows, 3079 cols, 15146 nonzeros  0s
# 2794 rows, 2625 cols, 8577 nonzeros  0s
# 1766 rows, 1655 cols, 4825 nonzeros  0s
# 1739 rows, 1655 cols, 4771 nonzeros  0s
# Presolve reductions: rows 1739(-11033); columns 1655(-6410); nonzeros 4771(-26821)
#
# Solving MIP model with:
#    1739 rows
#    1655 cols (372 binary, 0 integer, 0 implied int., 1283 continuous, 0 domain fixed)
#    4771 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4590.365779       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3674.108447     3568.729767        2.95%        0      0      0      1068     0.1s
#  C       0       0         0   0.00%   3674.108447     3571.258267        2.88%      158     49      0      1121     0.1s
#  H       0       0         0   0.00%   3674.108447     3674.108447        0.00%      158     49      0      1121     0.1s
#          1       0         1 100.00%   3674.108447     3674.108447        0.00%      158     49      0      1121     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3674.1084465
#   Dual bound        3674.1084465
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.435646367788
#   Solution status   feasible
#                     3674.1084465 (objective)
#                     0 (bound viol.)
#                     3.72713657637e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1121
#                     0 (strong br.)
#                     53 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-12 00:00:00 2024-02-18 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15051 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [5e-02, 5e+01]
#   Cost    [1e+01, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [5e-02, 4e+02]
# Presolving model
# 4297 rows, 2687 cols, 9406 nonzeros  0s
# 2197 rows, 2279 cols, 6812 nonzeros  0s
# 1724 rows, 1431 cols, 4238 nonzeros  0s
# 1317 rows, 1429 cols, 3422 nonzeros  0s
# Presolve reductions: rows 1317(-6079); columns 1429(-2604); nonzeros 3422(-11629)
#
# Solving MIP model with:
#    1317 rows
#    1429 cols (263 binary, 0 integer, 0 implied int., 1166 continuous, 0 domain fixed)
#    3422 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# ...
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.13
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1125
#                     0 (strong br.)
#                     49 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-16 00:00:00 2024-12-22 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14966 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [5e-02, 3e+01]
#   Cost    [3e-03, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [5e-02, 4e+02]
# Presolving model
# 4212 rows, 2687 cols, 9406 nonzeros  0s
# 2181 rows, 2194 cols, 6865 nonzeros  0s
# 1643 rows, 1228 cols, 3933 nonzeros  0s
# 1211 rows, 1226 cols, 3067 nonzeros  0s
# 1181 rows, 1226 cols, 3007 nonzeros  0s
# Presolve reductions: rows 1181(-6215); columns 1226(-2807); nonzeros 3007(-11959)
#
# Solving MIP model with:
#    1181 rows
#    1226 cols (206 binary, 0 integer, 0 implied int., 1020 continuous, 0 domain fixed)
#    3007 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             15695.931033       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   18125.693018    17576.767118       3.12%        0      0      0       802     0.1s
#  L       0       0         0   0.00%   18125.693018    18125.693018       0.00%      279     97      0       876     0.1s
#  T       0       0         0   0.00%   18125.693018    18125.693018       0.00%      279     97      0       911     0.1s
#          1       0         1 100.00%   18125.693018    18125.693018       0.00%      279     97      0       911     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      18125.6930176
#   Dual bound        18125.6930176
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0307442654132
#   Solution status   feasible
#                     18125.6930176 (objective)
#                     0 (bound viol.)
#                     5.55111512313e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.13
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     911
#                     0 (strong br.)
#                     74 (separation)
#                     35 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31395 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [5e-02, 3e+01]
#   Cost    [2e-02, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-17, 3e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9038 rows, 2931 cols, 14507 nonzeros  0s
# 2547 rows, 2430 cols, 7943 nonzeros  0s
# 1507 rows, 1423 cols, 4018 nonzeros  0s
# 1483 rows, 1423 cols, 3970 nonzeros  0s
# Presolve reductions: rows 1483(-11289); columns 1423(-6642); nonzeros 3970(-27425)
#
# Solving MIP model with:
#    1483 rows
#    1423 cols (292 binary, 0 integer, 0 implied int., 1131 continuous, 0 domain fixed)
#    3970 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2295.00584        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1054.813305     943.0645672       11.85%        0      0      0       985     0.1s
#  H       0       0         0   0.00%   1054.813305     1054.813305        0.00%      110     47      0      1036     0.1s
#          1       0         1 100.00%   1054.813305     1054.813305        0.00%      110     47      0      1036     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1054.81330537
#   Dual bound        1054.81330537
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.54182457763
#   Solution status   feasible
#                     1054.81330537 (objective)
#                     0 (bound viol.)
#                     5.10702591328e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.13
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1036
#                     0 (strong br.)
#                     51 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 13 |values| in [1.68754e-15, 1.77636e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31448 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [5e-02, 3e+01]
#   Cost    [5e-02, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9093 rows, 3041 cols, 14979 nonzeros  0s
# 2707 rows, 2535 cols, 8411 nonzeros  0s
# 1655 rows, 1530 cols, 4508 nonzeros  0s
# 1635 rows, 1530 cols, 4468 nonzeros  0s
# Presolve reductions: rows 1635(-11137); columns 1530(-6535); nonzeros 4468(-26980)
#
# Solving MIP model with:
#    1635 rows
#    1530 cols (341 binary, 0 integer, 0 implied int., 1189 continuous, 0 domain fixed)
#    4468 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2530.371591       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2852.233871     2690.01348         6.03%        0      0      0      1003     0.1s
#  C       0       0         0   0.00%   2852.233871     2711.610298        5.19%      131     46      0      1052     0.1s
#  H       0       0         0   0.00%   2852.233871     2852.233871        0.00%      131     47      0      1053     0.1s
#          1       0         1 100.00%   2852.233871     2852.233871        0.00%      131     47      0      1053     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      2852.23387076
#   Dual bound        2852.23387076
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.614829171553
#   Solution status   feasible
#                     2852.23387076 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.15
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1053
#                     0 (strong br.)
#                     50 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-23 00:00:00 2024-12-29 23:45:00
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14994 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [2e+00, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-02, 4e+02]
# Presolving model
# 4240 rows, 2687 cols, 9406 nonzeros  0s
# 2160 rows, 2222 cols, 6795 nonzeros  0s
# 1626 rows, 1258 cols, 3871 nonzeros  0s
# 1192 rows, 1256 cols, 3001 nonzeros  0s
# 1167 rows, 1256 cols, 2951 nonzeros  0s
# Presolve reductions: rows 1167(-6229); columns 1256(-2777); nonzeros 2951(-12043)
#
# Solving MIP model with:
#    1167 rows
#    1256 cols (206 binary, 0 integer, 0 implied int., 1050 continuous, 0 domain fixed)
#    2951 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             59515.802337       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   63878.96919     63664.031023       0.34%        0      0      0       763     0.0s
#  L       0       0         0   0.00%   63878.96919     63878.96919        0.00%      115     43      0       813     0.1s
#          1       0         1 100.00%   63878.96919     63878.96919        0.00%      115     43      0       838     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      63878.9691896
#   Dual bound        63878.9691896
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.0115153960964
#   Solution status   feasible
#                     63878.9691896 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.13
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     838
#                     0 (strong br.)
#                     50 (separation)
#                     25 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31442 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [3e-01, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-16, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9057 rows, 2913 cols, 14413 nonzeros  0s
# 2484 rows, 2422 cols, 7727 nonzeros  0s
# 1796 rows, 1342 cols, 4519 nonzeros  0s
# 1305 rows, 1340 cols, 3470 nonzeros  0s
# Presolve reductions: rows 1305(-11467); columns 1340(-6725); nonzeros 3470(-27972)
#
# Solving MIP model with:
#    1305 rows
#    1340 cols (229 binary, 0 integer, 0 implied int., 1111 continuous, 0 domain fixed)
#    3470 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4235.709693       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   1727.005812     1601.789415        7.82%        0      0      0       938     0.1s
#  C       0       0         0   0.00%   1727.005812     1654.410343        4.39%       92     40      0       981     0.1s
#  H       0       0         0   0.00%   1727.005812     1727.005812        0.00%       92     40      0       981     0.1s
#          1       0         1 100.00%   1727.005812     1727.005812        0.00%       92     40      0       981     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1727.00581231
#   Dual bound        1727.00581231
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.344208971251
#   Solution status   feasible
#                     1727.00581231 (objective)
#                     0 (bound viol.)
#                     1.42774680967e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            0.09
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     981
#                     0 (strong br.)
#                     43 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.12.0 (git hash: 755a8e0): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 21 |values| in [1.77636e-15, 1.77636e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31478 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [2e-02, 4e+01]
#   Cost    [5e+00, 8e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 2e+02]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9093 rows, 2985 cols, 14727 nonzeros  0s
# 2585 rows, 2485 cols, 8047 nonzeros  0s
# 1413 rows, 1383 cols, 3775 nonzeros  0s
# 1386 rows, 1383 cols, 3720 nonzeros  0s
# Presolve reductions: rows 1386(-11386); columns 1383(-6682); nonzeros 3720(-27758)
#
# Solving MIP model with:
#    1386 rows
#    1383 cols (252 binary, 0 integer, 0 implied int., 1131 continuous, 0 domain fixed)
#    3720 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -6366.999058       Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   2529.749928     2301.107626        9.94%        0      0      0       953     0.1s
#  H       0       0         0   0.00%   2529.749928     2529.749928        0.00%      118     52      0      1010     0.1s
#          1       0         1 100.00%   2529.749928     2529.749928        0.00%      118     52      0      1010     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      2529.74992792
#   Dual bound        2529.74992792
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.295366145826
#   Solution status   feasible
#                     2529.74992792 (objective)
#                     0 (bound viol.)
#                     4.66293670343e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.11
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1010
#                     0 (strong br.)
#                     57 (separation)
#                     0 (heuristics)
# Optimal solution found.

# %%
pd.set_option("display.max_columns", None)
results.head()
# Out:
#                      daa_price  ida_price  idc_price  pv_output  p_charge_daa  \
# 2024-01-01 00:00:00       0.10  18.908018   0.950255        0.0           0.0
# 2024-01-01 00:15:00       0.10   7.136068  -0.149025        0.0           0.0
# 2024-01-01 00:30:00       0.10   3.224757  -2.394920        0.0           0.0
# 2024-01-01 00:45:00       0.10   1.080706   3.409062        0.0           0.0
# 2024-01-01 01:00:00       0.01   5.907751  -0.344401        0.0           0.0
#
#                      p_discharge_daa  p_curtailed_daa  soc_daa  \
# 2024-01-01 00:00:00              0.0              0.0      0.0
# 2024-01-01 00:15:00              0.0              0.0      0.0
# 2024-01-01 00:30:00              0.0              0.0      0.0
# 2024-01-01 00:45:00              0.0              0.0      0.0
# 2024-01-01 01:00:00              0.0              0.0      0.0
#
#                      injection_power_daa  p_charge_ida  p_discharge_ida  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa  p_close_discharge_daa  \
# 2024-01-01 00:00:00                 0.0                    0.0
# 2024-01-01 00:15:00                 0.0                    0.0
# 2024-01-01 00:30:00                 0.0                    0.0
# 2024-01-01 00:45:00                 0.0                    0.0
# 2024-01-01 01:00:00                 0.0                    0.0
#
#                      p_curtailed_ida  p_close_curtailed_daa  p_charge_daa_ida  \
# 2024-01-01 00:00:00              0.0                    0.0               0.0
# 2024-01-01 00:15:00              0.0                    0.0               0.0
# 2024-01-01 00:30:00              0.0                    0.0               0.0
# 2024-01-01 00:45:00              0.0                    0.0               0.0
# 2024-01-01 01:00:00              0.0                    0.0               0.0
#
#                      p_discharge_daa_ida  p_curtailed_daa_ida  soc_ida  \
# 2024-01-01 00:00:00                  0.0                  0.0      0.0
# 2024-01-01 00:15:00                  0.0                  0.0      0.0
# 2024-01-01 00:30:00                  0.0                  0.0      0.0
# 2024-01-01 00:45:00                  0.0                  0.0      0.0
# 2024-01-01 01:00:00                  0.0                  0.0      0.0
#
#                      injection_power_ida  p_charge_idc  p_discharge_idc  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa_ida  p_close_discharge_daa_ida  \
# 2024-01-01 00:00:00                     0.0                        0.0
# 2024-01-01 00:15:00                     0.0                        0.0
# 2024-01-01 00:30:00                     0.0                        0.0
# 2024-01-01 00:45:00                     0.0                        0.0
# 2024-01-01 01:00:00                     0.0                        0.0
#
#                      p_curtailed_idc  p_close_curtailed_daa_ida  \
# 2024-01-01 00:00:00              0.0                        0.0
# 2024-01-01 00:15:00              0.0                        0.0
# 2024-01-01 00:30:00              0.0                        0.0
# 2024-01-01 00:45:00              0.0                        0.0
# 2024-01-01 01:00:00              0.0                        0.0
#
#                      p_charge_daa_ida_idc  p_discharge_daa_ida_idc  \
# 2024-01-01 00:00:00                   0.0                      0.0
# 2024-01-01 00:15:00                   0.0                      0.0
# 2024-01-01 00:30:00                   0.0                      0.0
# 2024-01-01 00:45:00                   0.0                      0.0
# 2024-01-01 01:00:00                   0.0                      0.0
#
#                      p_curtailed_daa_ida_idc  soc_idc  injection_power_idc
# 2024-01-01 00:00:00                      0.0      0.0                  0.0
# 2024-01-01 00:15:00                      0.0      0.0                  0.0
# 2024-01-01 00:30:00                      0.0      0.0                  0.0
# 2024-01-01 00:45:00                      0.0      0.0                  0.0
# 2024-01-01 01:00:00                      0.0      0.0                  0.0

# %% [markdown]
# ### Plot the results

# %%
# Plotting the results
# Set timerange for plotting
plot_start = pd.to_datetime('2024-06-21 00:00:00')
plot_end = pd.to_datetime('2024-06-28 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(21, 1, figsize=(12,36))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.ida_price, label='IDA [€/MWh]', color='cyan')
ax[3].plot(results_slice.idc_price, label='IDC [€/MWh]', color='magenta')
ax[4].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[4].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[5].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[6].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[7].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')

ax[8].plot(results_slice.p_close_charge_daa, label='Closed Charge Power DAA [MW]', color='yellow')
ax[8].plot(-results_slice.p_close_discharge_daa, label='Closed Discharge Power DAA [MW]', color='goldenrod')
ax[9].plot(results_slice.p_charge_ida, label='Charge Power IDA [MW]', color='lightblue')
ax[9].plot(-results_slice.p_discharge_ida, label='Discharge Power IDA [MW]', color='blue')
ax[10].plot(results_slice.p_close_curtailed_daa, label='Closed Curtailed Power DAA [MW]', color='plum')
ax[11].plot(results_slice.p_curtailed_daa_ida, label='Curtailed Power DAA IDA [MW]', color='lightcoral')
ax[12].plot(results_slice.soc_ida, label='SoC [MWh] IDA', color='lime')
ax[13].plot(results_slice.injection_power_ida, label='Injection Power DAA IDA [MW]', color='plum')

ax[14].plot(results_slice.p_close_charge_daa_ida, label='Closed Charge Power DAA IDA [MW]', color='lightgreen')
ax[14].plot(-results_slice.p_close_discharge_daa_ida, label='Closed Discharge Power DAA IDA [MW]', color='green')
ax[15].plot(results_slice.p_charge_idc, label='Charge Power IDC [MW]', color='#bfcf7c')
ax[15].plot(-results_slice.p_discharge_idc, label='Discharge Power IDC [MW]', color='olive') #, ls='', marker='_')
ax[16].plot(results_slice.p_close_curtailed_daa_ida, label='Closed Curtailed Power DAA IDA [MW]', color='plum')
ax[17].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='lightcoral')
ax[18].plot(results_slice.soc_idc, label='SoC [MWh] IDC', color='lime')
ax[19].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='plum')
ax[20].plot(results_slice.pv_output, label='PV Power [MW]', color='orange')
ax[20].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='red')
ax[20].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='darkred')

ax[20].set_xlabel('Time')

for i in range(21):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results.png')

# %% [markdown]
# ### Calculate energies and profits

# %%
##### Calculate pv_output considering clipping due to limited injection power
results['p_limit'] = p_limit
results['pv_output_clipped'] = results[['pv_output', 'p_limit']].min(axis=1)

##### Calculate energies
pv_production = results.pv_output.sum() * 15 / 60  # Convert from MW to MWh
injected_energy_daa = results.injection_power_daa.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_daa = results.p_curtailed_daa.sum() * 15 / 60 # Convert from MW to MWh
discharge_energy_daa = results.p_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa = results.p_charge_daa.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_ida = results.injection_power_ida.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_ida = results.p_curtailed_daa_ida.sum() * 15 / 60 # Convert from MW to MWh
closed_curtailed_daa_energy = results.p_close_curtailed_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_ida = results.p_discharge_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_ida = results.p_charge_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_energy = results.p_close_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_energy = results.p_close_charge_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida = results.p_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida = results.p_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_idc = results.injection_power_idc.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_idc = results.p_curtailed_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_curtailed_daa_ida_energy = results.p_close_curtailed_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_idc = results.p_discharge_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_idc = results.p_charge_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_ida_energy = results.p_close_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_ida_energy = results.p_close_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida_idc = results.p_discharge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida_idc = results.p_charge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh

# Print calculated energies
print('Annual Energies:')
print('==========================================')
print('PV')
print('----------')
print('PV Production:', f'{pv_production:.2f} MWh')
print('------------------------------------------')
print('DAA Market')
print('----------')
print('Injected Energy DAA:', f'{injected_energy_daa:.2f} MWh')
print('Curtailed Energy DAA:', f'{curtailed_energy_daa:.2f} MWh')
print('Charge Energy DAA:', f'{charge_energy_daa:.2f} MWh')
print('Discharge Energy DAA:', f'{discharge_energy_daa:.2f} MWh')
print('------------------------------------------')
print('IDA Market')
print('----------')
print('Injected Energy IDA:', f'{injected_energy_ida:.2f} MWh')
print('Curtailed Energy IDA:', f'{curtailed_energy_ida:.2f} MWh')
print('Closed Curtailed Energy DAA:', f'{closed_curtailed_daa_energy:.2f} MWh')
print('Charge Energy IDA:', f'{charge_energy_ida:.2f} MWh')
print('Discharge Energy IDA:', f'{discharge_energy_ida:.2f} MWh')
print('Closed Charge Energy DAA:', f'{closed_charge_daa_energy:.2f} MWh')
print('Closed Discharge Energy DAA:', f'{closed_discharge_daa_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA:', f'{charge_energy_daa_ida:.2f} MWh')
print('Physical Discharge Energy DAA IDA:', f'{discharge_energy_daa_ida:.2f} MWh')
print('------------------------------------------')
print('IDC Market')
print('----------')
print('Injected Energy IDC:', f'{injected_energy_idc:.2f} MWh')
print('Curtailed Energy IDC:', f'{curtailed_energy_idc:.2f} MWh')
print('Closed Curtailed Energy DAA IDA:', f'{closed_curtailed_daa_ida_energy:.2f} MWh')
print('Charge Energy IDC:', f'{charge_energy_idc:.2f} MWh')
print('Discharge Energy IDC:', f'{discharge_energy_idc:.2f} MWh')
print('Closed Charge Energy DAA IDA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA IDA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA IDC:', f'{charge_energy_daa_ida_idc:.2f} MWh')
print('Physical Discharge Energy DAA IDA IDC:', f'{discharge_energy_daa_ida_idc:.2f} MWh')
print('------------------------------------------')

##### Calculate profits
# Calculate annual profit from PV Output multiplied with DAA prices as reference
results['pv_direct_market_profit_reference'] = results.daa_price * results.pv_output * 15 / 60
results['pv_direct_market_profit_clipped_reference'] = results.daa_price * results.pv_output_clipped * 15 / 60
# Only sum up profit at positive market prices, because plant will be curtailed at other times
condition_daa_positive = results.daa_price >= 0
annual_pv_production_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'pv_output'].sum() * 15 / 60
annual_pv_production_clipped_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'pv_output_clipped'].sum() * 15 / 60
annual_pv_direct_market_profit_reference = results.loc[condition_daa_positive, 'pv_direct_market_profit_reference'].sum()
annual_pv_direct_market_profit_clipped_reference = results.loc[condition_daa_positive, 'pv_direct_market_profit_clipped_reference'].sum()

# Calculate annual profit on DAA market
results['injected_power_direct_market_profit_daa'] = results.daa_price * results.injection_power_daa * 15 / 60
annual_injected_energy_direct_market_profit_daa = results.injected_power_direct_market_profit_daa.sum()

# Calculate annual profit on IDA market
results['ida_market_profit'] = (results['p_discharge_ida'] - results['p_charge_ida'] 
                                + results['p_close_charge_daa'] - results['p_close_discharge_daa'] 
                                + results['p_close_curtailed_daa'] - results['p_curtailed_ida']) * results['ida_price']  / 4
annual_ida_market_profit = results['ida_market_profit'].sum()

# Calculate annual profit on IDC market
results['idc_market_profit'] = (results['p_discharge_idc'] - results['p_charge_idc'] 
                                + results['p_close_charge_daa_ida'] - results['p_close_discharge_daa_ida'] 
                                + results['p_close_curtailed_daa_ida'] - results['p_curtailed_idc']) * results['idc_price']  / 4
annual_idc_market_profit = results['idc_market_profit'].sum()

# Print annual profit values
print('Annual Direct Market Profits:')
print('----------------------------------------------------------------------------------------')
print('Annual PV Direct Market Profit (Reference):', f'{annual_pv_direct_market_profit_reference:.2f} €', '(excl. negative DAA price hours)')
print('Annual PV Direct Market Profit Clipped (Reference):', f'{annual_pv_direct_market_profit_clipped_reference:.2f} €', '(excl. negative DAA price hours)')
print('Annual Injected Energy Direct Market Profit (DAA):', f'{annual_injected_energy_direct_market_profit_daa:.2f} €')
print('Annual IDA Market Profit:', f'{annual_ida_market_profit:.2f} €')
print('Annual IDC Market Profit:', f'{annual_idc_market_profit:.2f} €')
print('----------------------------------------------------------------------------------------')

# Calculate annual market bonus (market premium)
annual_injected_energy_idc_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'injection_power_idc'].sum() * 15 / 60
market_bonus_injected_energy_idc = annual_injected_energy_idc_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_injected_energy_idc < 0:
    market_bonus_injected_energy_idc = 0
market_bonus_pv_production = annual_pv_production_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_pv_production < 0:
    market_bonus_pv_production = 0
market_bonus_pv_production_clipped = annual_pv_production_clipped_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_pv_production_clipped < 0:
    market_bonus_pv_production_clipped = 0

print('Annual Market Boni ():')
print('------------------------------------------------------------------')
print('Annual Market Bonus PV + BESS (IDC):', f'{market_bonus_injected_energy_idc:.2f} €', '(excl. negative DAA price hours)')
print('Annual Market Bonus PV only:', f'{market_bonus_pv_production:.2f} €', '(excl. negative DAA price hours)')
print('------------------------------------------------------------------')

print('Final Results:')
print('------------------------------------------------------------')
print('Annual profit PV only (reference):', f'{market_bonus_pv_production + annual_pv_direct_market_profit_reference:.2f} €')
print('Annual profit PV only clipped (reference):', f'{market_bonus_pv_production_clipped + annual_pv_direct_market_profit_clipped_reference:.2f} €')

print('Annual profit PV + BESS (DAA IDA IDC):', f'{market_bonus_injected_energy_idc 
                                                   + annual_injected_energy_direct_market_profit_daa 
                                                   + annual_ida_market_profit + annual_idc_market_profit:.2f} €')
print('Annual BESS profit (DAA IDA IDC):', f'{annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_clipped_reference - market_bonus_pv_production_clipped:.2f} €')
print('Specific Annual BESS profit (DAA IDA IDC):', f'{(annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_clipped_reference - market_bonus_pv_production_clipped) / storage_capacity:.2f} €/MWh')
# Out:
# Annual Energies:
# ==========================================
# PV
# ----------
# PV Production: 84933.36 MWh
# ------------------------------------------
# DAA Market
# ----------
# Injected Energy DAA: 70431.89 MWh
# Curtailed Energy DAA: 13593.25 MWh
# Charge Energy DAA: 9315.06 MWh
# Discharge Energy DAA: 8406.84 MWh
# ------------------------------------------
# IDA Market
# ----------
# Injected Energy IDA: 70383.15 MWh
# Curtailed Energy IDA: 13032.15 MWh
# Closed Curtailed Energy DAA: 4671.19 MWh
# Charge Energy IDA: 9289.08 MWh
# Discharge Energy IDA: 10276.98 MWh
# Closed Charge Energy DAA: 3034.27 MWh
# Closed Discharge Energy DAA: 4632.02 MWh
# Physical Charge Energy DAA IDA: 15569.87 MWh
# Physical Discharge Energy DAA IDA: 14051.81 MWh
# ------------------------------------------
# IDC Market
# ----------
# Injected Energy IDC: 68517.98 MWh
# Curtailed Energy IDC: 14880.73 MWh
# Closed Curtailed Energy DAA IDA: 3597.28 MWh
# Charge Energy IDC: 4912.01 MWh
# Discharge Energy IDC: 6414.50 MWh
# Closed Charge Energy DAA IDA: 4741.87 MWh
# Closed Discharge Energy DAA IDA: 6260.94 MWh
# Physical Charge Energy DAA IDA IDC: 15740.01 MWh
# Physical Discharge Energy DAA IDA IDC: 14205.36 MWh
# ------------------------------------------
# Annual Direct Market Profits:
# ----------------------------------------------------------------------------------------
# Annual PV Direct Market Profit (Reference): 4246765.13 € (excl. negative DAA price hours)
# Annual PV Direct Market Profit Clipped (Reference): 4246765.13 € (excl. negative DAA price hours)
# Annual Injected Energy Direct Market Profit (DAA): 4993657.61 €
# Annual IDA Market Profit: 600583.66 €
# Annual IDC Market Profit: 540579.09 €
# ----------------------------------------------------------------------------------------
# Annual Market Boni ():
# ------------------------------------------------------------------
# Annual Market Bonus PV + BESS (IDC): 10896963.76 € (excl. negative DAA price hours)
# Annual Market Bonus PV only: 12057933.03 € (excl. negative DAA price hours)
# ------------------------------------------------------------------
# Final Results:
# ------------------------------------------------------------
# Annual profit PV only (reference): 16304698.16 €
# Annual profit PV only clipped (reference): 16304698.16 €
# Annual profit PV + BESS (DAA IDA IDC): 17031784.12 €
# Annual BESS profit (DAA IDA IDC): 727085.96 €
# Specific Annual BESS profit (DAA IDA IDC): 27265.72 €/MWh
