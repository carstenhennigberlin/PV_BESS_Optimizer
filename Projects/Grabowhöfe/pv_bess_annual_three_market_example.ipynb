# %% [markdown]
# # PV-BESS optimizer

# %% [markdown]
# ### Example Jupyter notebook for scheduling a PV-BESS system using the Pyomo optimization framework.
# This jupyter notebook generates schedules for the marketing of the energy provided by a combination of a PV plant and a battery storage system (BESS) and calculates the corresponding profits on the day-ahead and intraday markets (DAA, IDA and IDC).
#
# This notebook uses historic market price data and PV production profiles and therefore represents a backtest following the principle of a perfect foresight.
#
# The schedules are generated by functions of the scheduler_three_market.py module, which make use of the Pyomo modelling framework for mathematical opimization. Each function includes an objective and several constraints, which can be reviewed in the module.

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries
from scheduler_three_market import get_daa_schedule, get_ida_schedule, get_idc_schedule # Import the scheduler module which contains the Pyomo model and optimization logic
import matplotlib.pyplot as plt  # Import matplotlib for plotting results
import pandas as pd  # Import pandas for data handling

# %% [markdown]
# ### Set the input parameters

# %%
# BESS (Battery Energy Storage System) parameters
p_limit = 3.507  # Maximum injection power limit in MW
storage_capacity = 5 # Storage capacity in MWh
p_charge_max = 2.5 # Maximum charge power in MW
p_discharge_max = 2.5 # Maximum discharge power MW
efficiency = 0.95 # Charge/discharge efficiency of the BESS
start_soc = 0.0  # Initial state of charge
end_soc = 0.0  # End state of charge, can be adjusted as needed
number_of_cycles = 2 * 7  # Number of cycles for the period (week)

# General parameters
number_of_weeks = 52  # Number of weeks in the year
year = '2024'  # Year for which the data is being processed

# Commercial parameters
applicable_value = 45.0 # Applicable value for the plant from EEG or tender ("anzulegneder Wert") in €/MWh

# %% [markdown]
# ### Year data dictionary

# %%
year_data = {
            # '2020': [24.6,'./data/2020/DA/2020_daa.csv',
            #                   './data/2020/IDA/2020_ida.csv' ,
            #                   './data/2020/ID1/2020_id1.csv',
            #                   './data/2020/PV/2020_pv.csv',
            #                   '2020-01-06 00:00:00'], 
            #  '2021': [75.5,'./data/2021/DA/2021_daa.csv',
            #                   './data/2021/IDA/2021_ida.csv' ,
            #                   './data/2021/ID1/2021_id1.csv',
            #                   './data/2021/PV/2021_pv.csv',
            #                   '2021-01-04 00:00:00'], 
            #  '2022': [223.1,'./data/2022/DA/2022_daa.csv',
            #                   './data/2022/IDA/2022_ida.csv' ,
            #                   './data/2022/ID1/2022_id1.csv',
            #                   './data/2022/PV/2022_pv.csv',
            #                   '2022-01-03 00:00:00'], 
            #  '2023': [72.0,'./data/2023/DA/2023_daa.csv',
            #                   './data/2023/IDA/2023_ida.csv' ,
            #                   './data/2023/ID1/2023_id1.csv',
            #                   './data/2023/PV/2023_pv.csv',
            #                   '2023-01-02 00:00:00'],
             '2024': [46.24,'./data/2024/DA/2024_daa.csv',
                              './data/2024/IDA/2024_ida.csv' ,
                              './data/2024/ID1/2024_id1.csv',
                              './data/2024/PV/2024_pv.csv',
                              '2024-01-01 00:00:00'], 
            }
# Extract the market value for the specified year
market_value = year_data[year][0]

# %% [markdown]
# ### Load DAA, IDA and IDC data from files

# %%
daa = pd.read_csv(year_data[year][1], index_col = 0)
daa.index = pd.to_datetime(daa.index)

ida = pd.read_csv(year_data[year][2], index_col = 0)
ida.index = pd.to_datetime(ida.index)

idc = pd.read_csv(year_data[year][3], index_col = 0)
idc.index = pd.to_datetime(idc.index)

# %% [markdown]
# ### Load PV load profile from .csv:

# %%
pv = pd.read_csv(year_data[year][4], index_col = 0)
pv.index = pd.to_datetime(pv.index)
pv.PV = [max(0, v) for v in pv.PV] # Set negative values to zero

# %% [markdown]
# ### Get the optimzized schedule
# This is done for weekly time slices. The results for the single weeks are then concatenated into a result dataframe.

# %%
start = pd.to_datetime(year_data[year][5])
end = start + pd.DateOffset(days=7) - pd.DateOffset(minutes=15)  # Set end to the next week minus 15 minutes
result_list = []

for i in range(1, number_of_weeks + 1):
    print('start/end', start, end)
    pv_vector = pv.PV[start:end].to_list()
    daa_price_vector = daa.DAA[start:end].to_list()
    ida_price_vector = ida.IDA[start:end].to_list()
    idc_price_vector = idc.ID1[start:end].to_list()

    # Ensure the vectors are not empty
    if not pv_vector or not daa_price_vector or not ida_price_vector or not idc_price_vector:
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors cannot be empty.")

    # Ensure the vectors are of the same length
    if len(pv_vector) != len(daa_price_vector) or len(pv_vector) != len(ida_price_vector) or len(pv_vector) != len(idc_price_vector):
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors must have the same length.")

    pv_output, daa_price, p_charge_daa, p_discharge_daa, soc_daa, p_curtailed_daa, injection_power_daa = get_daa_schedule(pv_vector,
                                                                                                  daa_price_vector, 
                                                                                                  p_limit, 
                                                                                                  storage_capacity, 
                                                                                                  p_charge_max, 
                                                                                                  p_discharge_max, 
                                                                                                  number_of_cycles, 
                                                                                                  efficiency, 
                                                                                                  start_soc, 
                                                                                                  end_soc)

    ida_price, p_charge_ida, p_discharge_ida, p_close_charge_daa, p_close_discharge_daa, p_curtailed_ida, \
        p_close_curtailed_daa, p_curtailed_daa_ida ,p_charge_daa_ida, p_discharge_daa_ida, soc_ida, injection_power_ida = get_ida_schedule(
                                                                                                                        ida_price_vector, 
                                                                                                                        pv_output,
                                                                                                                        p_limit, 
                                                                                                                        storage_capacity, 
                                                                                                                        p_charge_max, 
                                                                                                                        p_discharge_max,
                                                                                                                        p_charge_daa,
                                                                                                                        p_discharge_daa,
                                                                                                                        p_curtailed_daa,
                                                                                                                        number_of_cycles, 
                                                                                                                        efficiency, 
                                                                                                                        start_soc, 
                                                                                                                        end_soc)
    
    idc_price, p_charge_idc, p_discharge_idc, p_close_charge_daa_ida, p_close_discharge_daa_ida, p_curtailed_idc, \
        p_close_curtailed_daa_ida, p_curtailed_daa_ida_idc, p_charge_daa_ida_idc, p_discharge_daa_ida_idc, soc_idc, injection_power_idc = get_idc_schedule(
                                                                                                                                idc_price_vector,
                                                                                                                                pv_output, 
                                                                                                                                p_limit, 
                                                                                                                                storage_capacity, 
                                                                                                                                p_charge_max, 
                                                                                                                                p_discharge_max,
                                                                                                                                p_charge_daa_ida,
                                                                                                                                p_discharge_daa_ida,
                                                                                                                                p_curtailed_daa_ida,
                                                                                                                                number_of_cycles, 
                                                                                                                                efficiency, 
                                                                                                                                start_soc, 
                                                                                                                                end_soc
                                                                                                                            )

    # Create a DataFrame to store the results for the current week
    result = pd.DataFrame({# prices and PV output
                           'daa_price': daa_price,
                           'ida_price': ida_price,
                           'idc_price': idc_price,
                           'pv_output': pv_output,
                            # DAA results
                           'p_charge_daa': p_charge_daa,
                           'p_discharge_daa': p_discharge_daa,
                           'p_curtailed_daa': p_curtailed_daa,
                           'soc_daa': soc_daa,
                           'injection_power_daa': injection_power_daa,
                           # IDA results
                           'p_charge_ida': p_charge_ida,
                           'p_discharge_ida': p_discharge_ida,
                           'p_close_charge_daa': p_close_charge_daa,
                           'p_close_discharge_daa': p_close_discharge_daa,
                           'p_curtailed_ida': p_curtailed_ida,
                           'p_close_curtailed_daa': p_close_curtailed_daa,
                           'p_charge_daa_ida': p_charge_daa_ida,
                           'p_discharge_daa_ida': p_discharge_daa_ida,
                           'p_curtailed_daa_ida': p_curtailed_daa_ida,
                           'soc_ida': soc_ida,
                           'injection_power_ida': injection_power_ida,
                           # IDC results
                           'p_charge_idc': p_charge_idc,
                           'p_discharge_idc': p_discharge_idc,
                           'p_close_charge_daa_ida': p_close_charge_daa_ida,
                           'p_close_discharge_daa_ida': p_close_discharge_daa_ida,
                           'p_curtailed_idc': p_curtailed_idc,
                           'p_close_curtailed_daa_ida': p_close_curtailed_daa_ida,
                           'p_charge_daa_ida_idc': p_charge_daa_ida_idc,
                           'p_discharge_daa_ida_idc': p_discharge_daa_ida_idc,
                           'p_curtailed_daa_ida_idc': p_curtailed_daa_ida_idc,
                           'soc_idc': soc_idc,
                           'injection_power_idc': injection_power_idc
                          }
                         )
    
    result.index = pd.date_range(start=start, end=end, freq='15min')
    
    result_list.append(result)

    start = start + pd.DateOffset(days=7) # Set start and end to the next week
    end = end + pd.DateOffset(days=7)
    
results = pd.concat(result_list)
# Out:
# start/end 2024-01-01 00:00:00 2024-01-07 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 14989 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [3e-03, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4235 rows, 3091 cols, 10416 nonzeros  0s
# 2219 rows, 2217 cols, 6918 nonzeros  0s
# 1702 rows, 1290 cols, 4104 nonzeros  0s
# 1253 rows, 1288 cols, 3204 nonzeros  0s
#
# Solving MIP model with:
#    1253 rows
#    1288 cols (225 binary, 0 integer, 0 implied int., 1063 continuous, 0 domain fixed)
#    3204 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             481.1233084        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   728.6329703     544.1182475       33.91%        0      0      0      1025     0.1s
#  L       0       0         0   0.00%   728.6329703     728.6329703        0.00%      504    176      0      1172     0.3s
#          1       0         1 100.00%   728.6329703     728.6329703        0.00%      504    176      0      1235     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      728.632970339
#   Dual bound        728.632970339
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.749417448856
#   Solution status   feasible
#                     728.632970339 (objective)
#                     0 (bound viol.)
#                     4.62963001269e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.26 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1235 (total)
#                     0 (strong br.)
#                     147 (separation)
#                     63 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 2 |values| in [1.68754e-15, 1.68754e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31504 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [2e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-18, 6e+01]
# Presolving model
# 9326 rows, 3461 cols, 16507 nonzeros  0s
# 2789 rows, 2594 cols, 8610 nonzeros  0s
# 1836 rows, 1657 cols, 4913 nonzeros  0s
# 1810 rows, 1657 cols, 4861 nonzeros  0s
#
# Solving MIP model with:
#    1810 rows
#    1657 cols (404 binary, 0 integer, 0 implied int., 1253 continuous, 0 domain fixed)
#    4861 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -258.4368187       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   65.29694293     60.36089999        8.18%        0      0      0      1204     0.2s
#  H       0       0         0   0.00%   65.29694293     65.29694293        0.00%      219     60      0      1264     0.3s
#          1       0         1 100.00%   65.29694293     65.29694293        0.00%      219     60      0      1264     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      65.2969429339
#   Dual bound        65.2969429339
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.50398367267
#   Solution status   feasible
#                     65.2969429339 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.31 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1264 (total)
#                     0 (strong br.)
#                     60 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 7 |values| in [3.9443e-31, 4.44089e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31524 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [3e-02, 5e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-31, 6e+01]
# Presolving model
# 9346 rows, 3501 cols, 16687 nonzeros  0s
# 2880 rows, 2664 cols, 8868 nonzeros  0s
# 1912 rows, 1713 cols, 5112 nonzeros  0s
# 1892 rows, 1713 cols, 5072 nonzeros  0s
#
# Solving MIP model with:
#    1892 rows
#    1713 cols (432 binary, 0 integer, 0 implied int., 1281 continuous, 0 domain fixed)
#    5072 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -345.2501731       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   152.0874999     143.9054396        5.69%        0      0      0      1158     0.2s
#  H       0       0         0   0.00%   152.0874999     152.0874999        0.00%      144     37      0      1195     0.3s
#          1       0         1 100.00%   152.0874999     152.0874999        0.00%      144     37      0      1195     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      152.087499864
#   Dual bound        152.087499864
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.8659784372
#   Solution status   feasible
#                     152.087499864 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.29 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1195 (total)
#                     0 (strong br.)
#                     37 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-08 00:00:00 2024-01-14 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 14996 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [2e+01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4242 rows, 3105 cols, 10451 nonzeros  0s
# 2253 rows, 2242 cols, 6997 nonzeros  0s
# 1719 rows, 1281 cols, 4081 nonzeros  0s
# 1236 rows, 1279 cols, 3104 nonzeros  0s
#
# Solving MIP model with:
#    1236 rows
#    1279 cols (217 binary, 0 integer, 0 implied int., 1062 continuous, 0 domain fixed)
#    3104 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             1639.156389        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1909.179928     1758.290272        8.58%        0      0      0      1013     0.1s
#  L       0       0         0   0.00%   1909.179928     1909.179928        0.00%      494    156      0      1157     0.3s
#          1       0         1 100.00%   1909.179928     1909.179928        0.00%      494    156      0      1234     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1909.17992787
#   Dual bound        1909.17992787
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.230653589637
#   Solution status   feasible
#                     1909.17992787 (objective)
#                     0 (bound viol.)
#                     5.51780843239e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.27 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1234 (total)
#                     0 (strong br.)
#                     144 (separation)
#                     77 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 3 |values| in [6.85563e-16, 1.68754e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31538 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [1e+01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [7e-18, 6e+01]
# Presolving model
# 9360 rows, 3515 cols, 16725 nonzeros  0s
# 2892 rows, 2657 cols, 8894 nonzeros  0s
# 1867 rows, 1680 cols, 4983 nonzeros  0s
# 1849 rows, 1680 cols, 4947 nonzeros  0s
#
# Solving MIP model with:
#    1849 rows
#    1680 cols (407 binary, 0 integer, 0 implied int., 1273 continuous, 0 domain fixed)
#    4947 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -319.915028        Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   206.61238       200.6388614        2.98%        0      0      0      1150     0.4s
#  C       0       0         0   0.00%   206.61238       201.0087457        2.79%      162     43      0      1193     0.5s
#  H       0       0         0   0.00%   206.61238       206.61238          0.00%      162     43      0      1193     0.5s
#          1       0         1 100.00%   206.61238       206.61238          0.00%      162     43      0      1193     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      206.612380029
#   Dual bound        206.612380029
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      8.05061147454
#   Solution status   feasible
#                     206.612380029 (objective)
#                     0 (bound viol.)
#                     5.77315972805e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.49 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1193 (total)
#                     0 (strong br.)
#                     43 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 16 |values| in [9.86076e-32, 1.5099e-14] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31542 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [6e+00, 1e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-32, 6e+01]
# Presolving model
# 9364 rows, 3523 cols, 16760 nonzeros  0s
# 2908 rows, 2668 cols, 8946 nonzeros  0s
# 1876 rows, 1687 cols, 5010 nonzeros  0s
# 1853 rows, 1687 cols, 4964 nonzeros  0s
#
# Solving MIP model with:
#    1853 rows
#    1687 cols (410 binary, 0 integer, 0 implied int., 1277 continuous, 0 domain fixed)
#    4964 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -574.6756998       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   646.0584127     630.7637693        2.42%        0      0      0      1145     0.3s
#  C       0       0         0   0.00%   646.0584127     632.0680258        2.21%      134     33      0      1178     0.5s
#  H       0       0         0   0.00%   646.0584127     646.0584127        0.00%      134     33      0      1178     0.5s
#          1       0         1 100.00%   646.0584127     646.0584127        0.00%      134     33      0      1178     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      646.058412693
#   Dual bound        646.058412693
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.06318909975
#   Solution status   feasible
#                     646.058412693 (objective)
#                     0 (bound viol.)
#                     3.5527136788e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.48 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1178 (total)
#                     0 (strong br.)
#                     33 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-15 00:00:00 2024-01-21 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15004 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [9e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4250 rows, 3121 cols, 10491 nonzeros  0s
# 2345 rows, 2306 cols, 7229 nonzeros  0s
# 1819 rows, 1361 cols, 4361 nonzeros  0s
# 1323 rows, 1359 cols, 3330 nonzeros  0s
#
# Solving MIP model with:
#    1323 rows
#    1359 cols (253 binary, 0 integer, 0 implied int., 1106 continuous, 0 domain fixed)
#    3330 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             2263.275272        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2483.298756     2349.460092        5.70%        0      0      0      1004     0.1s
#  L       0       0         0   0.00%   2483.298756     2483.298756        0.00%      568    170      0      1170     0.5s
#          1       0         1 100.00%   2483.298756     2483.298756        0.00%      568    170      0      1221     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      2483.29875624
#   Dual bound        2483.29875624
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.171716294215
#   Solution status   feasible
#                     2483.29875624 (objective)
#                     0 (bound viol.)
#                     1.13242748512e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.46 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1221 (total)
#                     0 (strong br.)
#                     166 (separation)
#                     51 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [6.5814e-14, 6.5814e-14] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31546 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [6e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 5e+01]
# Presolving model
# 9368 rows, 3515 cols, 16706 nonzeros  0s
# 2962 rows, 2704 cols, 9066 nonzeros  0s
# 1926 rows, 1748 cols, 5135 nonzeros  0s
# 1905 rows, 1748 cols, 5093 nonzeros  0s
#
# Solving MIP model with:
#    1905 rows
#    1748 cols (435 binary, 0 integer, 0 implied int., 1313 continuous, 0 domain fixed)
#    5093 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -247.2523777       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   127.0979736     122.9571444        3.37%        0      0      0      1177     0.3s
#  H       0       0         0   0.00%   127.0979736     127.0979736        0.00%      234     58      0      1237     0.5s
#          1       0         1 100.00%   127.0979736     127.0979736        0.00%      234     58      0      1237     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      127.09797356
#   Dual bound        127.09797356
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      7.32142034197
#   Solution status   feasible
#                     127.09797356 (objective)
#                     0 (bound viol.)
#                     1.41183780877e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            0.52 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1237 (total)
#                     0 (strong br.)
#                     60 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 13 |values| in [1.26218e-29, 4.44089e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31558 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [3e+00, 5e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-30, 5e+01]
# Presolving model
# 9380 rows, 3539 cols, 16810 nonzeros  0s
# 3005 rows, 2734 cols, 9201 nonzeros  0s
# 1960 rows, 1772 cols, 5232 nonzeros  0s
# 1932 rows, 1772 cols, 5176 nonzeros  0s
#
# Solving MIP model with:
#    1932 rows
#    1772 cols (447 binary, 0 integer, 0 implied int., 1325 continuous, 0 domain fixed)
#    5176 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -135.2074401       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   251.600517      229.9902095        9.40%        0      0      0      1142     0.2s
#  C       0       0         0   0.00%   251.600517      245.5208574        2.48%      151     36      0      1181     0.3s
#  L       0       0         0   0.00%   251.600517      251.600517         0.00%      177     47      0      1196     0.6s
#          1       0         1 100.00%   251.600517      251.600517         0.00%      177     47      0      1275     0.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      251.600517038
#   Dual bound        251.600517038
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      5.97327634195
#   Solution status   feasible
#                     251.600517038 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.59 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1275 (total)
#                     0 (strong br.)
#                     54 (separation)
#                     79 (heuristics)
# Optimal solution found.
# start/end 2024-01-22 00:00:00 2024-01-28 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15011 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [7e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4257 rows, 3135 cols, 10526 nonzeros  0s
# 2406 rows, 2349 cols, 7380 nonzeros  0s
# 1909 rows, 1459 cols, 4678 nonzeros  0s
# 1429 rows, 1457 cols, 3661 nonzeros  0s
#
# Solving MIP model with:
#    1429 rows
#    1457 cols (298 binary, 0 integer, 0 implied int., 1159 continuous, 0 domain fixed)
#    3661 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             1737.323811        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2306.116821     2071.184994       11.34%        0      0      0       955     0.3s
#  L       0       0         0   0.00%   2306.116821     2306.116821        0.00%      491    163      0      1100     0.5s
#          1       0         1 100.00%   2306.116821     2306.116821        0.00%      491    163      0      1116     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      2306.11682109
#   Dual bound        2306.11682109
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.300117764367
#   Solution status   feasible
#                     2306.11682109 (objective)
#                     0 (bound viol.)
#                     1.74305014866e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.52 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1116 (total)
#                     0 (strong br.)
#                     145 (separation)
#                     16 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 2 |values| in [8.43769e-16, 8.43769e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31564 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [2e-03, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e-18, 5e+01]
# Presolving model
# 9386 rows, 3537 cols, 16783 nonzeros  0s
# 3048 rows, 2759 cols, 9309 nonzeros  0s
# 2008 rows, 1834 cols, 5401 nonzeros  0s
# 1985 rows, 1834 cols, 5355 nonzeros  0s
#
# Solving MIP model with:
#    1985 rows
#    1834 cols (471 binary, 0 integer, 0 implied int., 1363 continuous, 0 domain fixed)
#    5355 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -712.7677545       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   236.9849373     197.7674829       19.83%        0      0      0      1206     0.2s
#  H       0       0         0   0.00%   236.9849373     236.9849373        0.00%      272     77      0      1286     0.4s
#          1       0         1 100.00%   236.9849373     236.9849373        0.00%      272     77      0      1286     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      236.984937318
#   Dual bound        236.984937318
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.02895316514
#   Solution status   feasible
#                     236.984937318 (objective)
#                     0 (bound viol.)
#                     1.36557432029e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.44 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1286 (total)
#                     0 (strong br.)
#                     80 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 12 |values| in [1.97215e-31, 1.68754e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31601 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [4e-03, 2e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [5e-32, 5e+01]
# Presolving model
# 9423 rows, 3611 cols, 17108 nonzeros  0s
# 3164 rows, 2835 cols, 9658 nonzeros  0s
# 2143 rows, 1935 cols, 5835 nonzeros  0s
# 2115 rows, 1935 cols, 5779 nonzeros  0s
#
# Solving MIP model with:
#    2115 rows
#    1935 cols (520 binary, 0 integer, 0 implied int., 1415 continuous, 0 domain fixed)
#    5779 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -898.0018367       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   212.3988409     193.9579167        9.51%        0      0      0      1241     0.2s
#  H       0       0         0   0.00%   212.3988409     212.3988409        0.00%      224     60      0      1302     0.4s
#          1       0         1 100.00%   212.3988409     212.3988409        0.00%      224     60      0      1302     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      212.398840948
#   Dual bound        212.398840948
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.670144260172
#   Solution status   feasible
#                     212.398840948 (objective)
#                     0 (bound viol.)
#                     2.44249065418e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.36 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1302 (total)
#                     0 (strong br.)
#                     61 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-29 00:00:00 2024-02-04 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15023 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [7e-03, 2e+00]
#   Cost   [1e-01, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [7e-03, 7e+01]
# Presolving model
# 4269 rows, 3159 cols, 10586 nonzeros  0s
# 2403 rows, 2351 cols, 7352 nonzeros  0s
# 1896 rows, 1444 cols, 4598 nonzeros  0s
# 1416 rows, 1442 cols, 3586 nonzeros  0s
#
# Solving MIP model with:
#    1416 rows
#    1442 cols (285 binary, 0 integer, 0 implied int., 1157 continuous, 0 domain fixed)
#    3586 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             2111.923165        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2700.088503     2442.729439       10.54%        0      0      0      1014     0.1s
#  L       0       0         0   0.00%   2700.088503     2700.088503        0.00%      361    150      0      1164     0.2s
#  T       0       0         0   0.00%   2700.088503     2700.088503        0.00%      361    150      0      1189     0.2s
#          1       0         1 100.00%   2700.088503     2700.088503        0.00%      361    150      0      1189     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      2700.08850293
#   Dual bound        2700.08850293
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.126566441191
#   Solution status   feasible
#                     2700.08850293 (objective)
#                     0 (bound viol.)
#                     5.99520433298e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.25 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1189 (total)
#                     0 (strong br.)
#                     150 (separation)
#                     25 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [1.68754e-15, 1.68754e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31598 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [7e-03, 3e+00]
#   Cost   [1e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-16, 5e+01]
# Presolving model
# 9420 rows, 3581 cols, 16953 nonzeros  0s
# 3083 rows, 2786 cols, 9392 nonzeros  0s
# 2510 rows, 1848 cols, 6570 nonzeros  0s
# 1997 rows, 1846 cols, 5385 nonzeros  0s
#
# Solving MIP model with:
#    1997 rows
#    1846 cols (469 binary, 0 integer, 0 implied int., 1377 continuous, 0 domain fixed)
#    5385 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -615.8862129       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   285.5714642     256.1311324       11.49%        0      0      0      1242     0.2s
#  C       0       0         0   0.00%   285.5714642     267.4580138        6.77%      205     60      0      1301     0.3s
#  H       0       0         0   0.00%   285.5714642     285.5714642        0.00%      230     66      0      1313     0.4s
#          1       0         1 100.00%   285.5714642     285.5714642        0.00%      230     66      0      1313     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      285.571464159
#   Dual bound        285.571464159
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.24147763681
#   Solution status   feasible
#                     285.571464159 (objective)
#                     0 (bound viol.)
#                     9.10382880193e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.43 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1313 (total)
#                     0 (strong br.)
#                     71 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 16 |values| in [3.9443e-31, 8.43769e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31636 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [7e-03, 3e+00]
#   Cost   [3e-02, 1e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-31, 4e+01]
# Presolving model
# 9458 rows, 3657 cols, 17287 nonzeros  0s
# 3259 rows, 2920 cols, 9902 nonzeros  0s
# 2241 rows, 2030 cols, 6121 nonzeros  0s
# 2216 rows, 2030 cols, 6071 nonzeros  0s
#
# Solving MIP model with:
#    2216 rows
#    2030 cols (560 binary, 0 integer, 0 implied int., 1470 continuous, 0 domain fixed)
#    6071 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1256.723772       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   445.4985459     436.730708         2.01%        0      0      0      1217     0.2s
#  H       0       0         0   0.00%   445.4985459     445.4985459        0.00%      164     40      0      1261     0.4s
#          1       0         1 100.00%   445.4985459     445.4985459        0.00%      164     40      0      1261     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      445.498545923
#   Dual bound        445.498545923
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.752322886831
#   Solution status   feasible
#                     445.498545923 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.39 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1261 (total)
#                     0 (strong br.)
#                     44 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-05 00:00:00 2024-02-11 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15034 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [2e-03, 2e+00]
#   Cost   [7e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e-03, 7e+01]
# Presolving model
# 4280 rows, 3181 cols, 10641 nonzeros  0s
# 2327 rows, 2304 cols, 7131 nonzeros  0s
# 1835 rows, 1421 cols, 4451 nonzeros  0s
# 1380 rows, 1419 cols, 3518 nonzeros  0s
#
# Solving MIP model with:
#    1380 rows
#    1419 cols (267 binary, 0 integer, 0 implied int., 1152 continuous, 0 domain fixed)
#    3518 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             1639.615753        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2002.395799     1767.173505       13.31%        0      0      0      1059     0.1s
#  L       0       0         0   0.00%   2002.395799     2002.395799        0.00%      598    234      0      1236     0.4s
#          1       0         1 100.00%   2002.395799     2002.395799        0.00%      598    234      0      1316     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      2002.39579892
#   Dual bound        2002.39579892
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.210538563417
#   Solution status   feasible
#                     2002.39579892 (objective)
#                     0 (bound viol.)
#                     5.41788836017e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.39 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1316 (total)
#                     0 (strong br.)
#                     177 (separation)
#                     80 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31619 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [2e-03, 3e+00]
#   Cost   [3e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [9e-19, 6e+01]
# Presolving model
# 9441 rows, 3601 cols, 17038 nonzeros  0s
# 2992 rows, 2743 cols, 9107 nonzeros  0s
# 2050 rows, 1856 cols, 5515 nonzeros  0s
# 2027 rows, 1856 cols, 5469 nonzeros  0s
#
# Solving MIP model with:
#    2027 rows
#    1856 cols (476 binary, 0 integer, 0 implied int., 1380 continuous, 0 domain fixed)
#    5469 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -381.1734763       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   142.498237      130.7715689        8.97%        0      0      0      1234     0.2s
#  C       0       0         0   0.00%   142.498237      138.75095          2.70%      229     61      0      1298     0.3s
#  H       0       0         0   0.00%   142.498237      142.498237         0.00%      229     61      0      1298     0.3s
#          1       0         1 100.00%   142.498237      142.498237         0.00%      229     61      0      1298     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      142.498236985
#   Dual bound        142.498236985
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.59486912945
#   Solution status   feasible
#                     142.498236985 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.33 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1298 (total)
#                     0 (strong br.)
#                     64 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 7 |values| in [4.44089e-16, 4.44089e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31639 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [2e-03, 3e+00]
#   Cost   [1e-01, 8e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [9e-19, 6e+01]
# Presolving model
# 9461 rows, 3641 cols, 17213 nonzeros  0s
# 3044 rows, 2772 cols, 9261 nonzeros  0s
# 2121 rows, 1907 cols, 5750 nonzeros  0s
# 2097 rows, 1907 cols, 5702 nonzeros  0s
#
# Solving MIP model with:
#    2097 rows
#    1907 cols (501 binary, 0 integer, 0 implied int., 1406 continuous, 0 domain fixed)
#    5702 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -591.6585211       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   384.79145       349.1334469       10.21%        0      0      0      1194     0.2s
#  H       0       0         0   0.00%   384.79145       384.79145          0.00%      196     61      0      1262     0.4s
#          1       0         1 100.00%   384.79145       384.79145          0.00%      196     61      0      1262     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      384.791449951
#   Dual bound        384.791449951
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.42066860597
#   Solution status   feasible
#                     384.791449951 (objective)
#                     0 (bound viol.)
#                     4.48530101949e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.41 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1262 (total)
#                     0 (strong br.)
#                     68 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-12 00:00:00 2024-02-18 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15047 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [1e+01, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4293 rows, 3207 cols, 10706 nonzeros  0s
# 2361 rows, 2331 cols, 7200 nonzeros  0s
# 1883 rows, 1475 cols, 4599 nonzeros  0s
# 1434 rows, 1473 cols, 3672 nonzeros  0s
#
# Solving MIP model with:
#    1434 rows
#    1473 cols (287 binary, 0 integer, 0 implied int., 1186 continuous, 0 domain fixed)
#    3672 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
# ...
#                     0 (strong br.)
#                     61 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-16 00:00:00 2024-12-22 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 14982 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [3e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4228 rows, 3077 cols, 10381 nonzeros  0s
# 2215 rows, 2212 cols, 6919 nonzeros  0s
# 1695 rows, 1279 cols, 4087 nonzeros  0s
# 1238 rows, 1277 cols, 3170 nonzeros  0s
#
# Solving MIP model with:
#    1238 rows
#    1277 cols (223 binary, 0 integer, 0 implied int., 1054 continuous, 0 domain fixed)
#    3170 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             730.0716387        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   962.8741495     800.8477491       20.23%        0      0      0      1000     0.1s
#  L       0       0         0   0.00%   962.8741495     962.8741495        0.00%      456    151      0      1148     0.3s
#  T       0       0         0   0.00%   962.8741495     962.8741495        0.00%      456    151      0      1227     0.3s
#          1       0         1 100.00%   962.8741495     962.8741495        0.00%      456    151      0      1227     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      962.874149534
#   Dual bound        962.874149534
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.345891528985
#   Solution status   feasible
#                     962.874149534 (objective)
#                     0 (bound viol.)
#                     1.44328993201e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1227 (total)
#                     0 (strong br.)
#                     148 (separation)
#                     79 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31498 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [2e-02, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e-16, 6e+01]
# Presolving model
# 9320 rows, 3463 cols, 16524 nonzeros  0s
# 2811 rows, 2602 cols, 8688 nonzeros  0s
# 1846 rows, 1666 cols, 4981 nonzeros  0s
# 1826 rows, 1666 cols, 4941 nonzeros  0s
#
# Solving MIP model with:
#    1826 rows
#    1666 cols (409 binary, 0 integer, 0 implied int., 1257 continuous, 0 domain fixed)
#    4941 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -216.4712856       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   86.39751686     85.05639652        1.58%        0      0      0      1165     0.2s
#  H       0       0         0   0.00%   86.39751686     86.39751686        0.00%      186     46      0      1212     0.4s
#          1       0         1 100.00%   86.39751686     86.39751686        0.00%      186     46      0      1212     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      86.3975168562
#   Dual bound        86.3975168562
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.80936008857
#   Solution status   feasible
#                     86.3975168562 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.40 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1212 (total)
#                     0 (strong br.)
#                     47 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 10 |values| in [4.44089e-16, 2.66454e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31504 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [5e-02, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [9e-17, 6e+01]
# Presolving model
# 9326 rows, 3475 cols, 16576 nonzeros  0s
# 2840 rows, 2623 cols, 8773 nonzeros  0s
# 1895 rows, 1710 cols, 5149 nonzeros  0s
# 1875 rows, 1710 cols, 5109 nonzeros  0s
#
# Solving MIP model with:
#    1875 rows
#    1710 cols (431 binary, 0 integer, 0 implied int., 1279 continuous, 0 domain fixed)
#    5109 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -239.4023881       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   110.0704718     109.0279647        0.96%        0      0      0      1124     0.2s
#  H       0       0         0   0.00%   110.0704718     110.0704718        0.00%      120     31      0      1156     0.3s
#          1       0         1 100.00%   110.0704718     110.0704718        0.00%      120     31      0      1156     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      110.070471766
#   Dual bound        110.070471766
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.1769908767
#   Solution status   feasible
#                     110.070471766 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.26 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1156 (total)
#                     0 (strong br.)
#                     32 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-23 00:00:00 2024-12-29 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 14989 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [4e-03, 2e+00]
#   Cost   [2e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [4e-03, 7e+01]
# Presolving model
# 4235 rows, 3091 cols, 10416 nonzeros  0s
# 2219 rows, 2217 cols, 6918 nonzeros  0s
# 1676 rows, 1241 cols, 3956 nonzeros  0s
# 1239 rows, 1239 cols, 3080 nonzeros  0s
# 1193 rows, 1239 cols, 2988 nonzeros  0s
#
# Solving MIP model with:
#    1193 rows
#    1239 cols (201 binary, 0 integer, 0 implied int., 1038 continuous, 0 domain fixed)
#    2988 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             658.5664244        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   857.6121065     716.2872154       19.73%        0      0      0      1031     0.1s
#  L       0       0         0   0.00%   857.6121065     857.6121065        0.00%      484    170      0      1182     0.2s
#  T       0       0         0   0.00%   857.6121065     857.6121065        0.00%      484    170      0      1269     0.2s
#          1       0         1 100.00%   857.6121065     857.6121065        0.00%      484    170      0      1269     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      857.612106522
#   Dual bound        857.612106522
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.552644180673
#   Solution status   feasible
#                     857.612106522 (objective)
#                     0 (bound viol.)
#                     4.58855176078e-12 (int. viol.)
#                     0 (row viol.)
#   Timing            0.24 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1269 (total)
#                     0 (strong br.)
#                     151 (separation)
#                     87 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [8.43769e-16, 8.43769e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31522 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [3e-01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [9e-19, 6e+01]
# Presolving model
# 9344 rows, 3497 cols, 16670 nonzeros  0s
# 2839 rows, 2625 cols, 8765 nonzeros  0s
# 1844 rows, 1647 cols, 4903 nonzeros  0s
# 1823 rows, 1647 cols, 4861 nonzeros  0s
#
# Solving MIP model with:
#    1823 rows
#    1647 cols (400 binary, 0 integer, 0 implied int., 1247 continuous, 0 domain fixed)
#    4861 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -231.6194649       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   50.84762736     49.85592189        1.99%        0      0      0      1182     0.2s
#  C       0       0         0   0.00%   50.84762736     49.85592189        1.99%      211     50      0      1232     0.3s
#  H       0       0         0   0.00%   50.84762736     50.84762736        0.00%      211     50      0      1232     0.3s
#          1       0         1 100.00%   50.84762736     50.84762736        0.00%      211     50      0      1232     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      50.8476273589
#   Dual bound        50.8476273589
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.35589627573
#   Solution status   feasible
#                     50.8476273589 (objective)
#                     0 (bound viol.)
#                     4.77395900589e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.29 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1232 (total)
#                     0 (strong br.)
#                     50 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 6 |values| in [4.44089e-16, 8.43769e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31523 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [4e-03, 3e+00]
#   Cost   [5e+00, 8e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [9e-19, 6e+01]
# Presolving model
# 9345 rows, 3499 cols, 16678 nonzeros  0s
# 2843 rows, 2628 cols, 8778 nonzeros  0s
# 1844 rows, 1647 cols, 4904 nonzeros  0s
# 1823 rows, 1647 cols, 4862 nonzeros  0s
#
# Solving MIP model with:
#    1823 rows
#    1647 cols (400 binary, 0 integer, 0 implied int., 1247 continuous, 0 domain fixed)
#    4862 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -368.966769        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   139.0127085     138.4415146        0.41%        0      0      0      1197     0.2s
#  C       0       0         0   0.00%   139.0127085     138.4415146        0.41%      158     40      0      1237     0.3s
#  H       0       0         0   0.00%   139.0127085     139.0127085        0.00%      158     40      0      1237     0.3s
#          1       0         1 100.00%   139.0127085     139.0127085        0.00%      158     40      0      1237     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      139.012708549
#   Dual bound        139.012708549
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.85013640955
#   Solution status   feasible
#                     139.012708549 (objective)
#                     0 (bound viol.)
#                     1.39888101103e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.30 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1237 (total)
#                     0 (strong br.)
#                     40 (separation)
#                     0 (heuristics)
# Optimal solution found.

# %%
pd.set_option("display.max_columns", None)
results.head()
# Out:
#                      daa_price  ida_price  idc_price  pv_output  p_charge_daa  \
# 2024-01-01 00:00:00       0.10  18.908018   0.950255        0.0           0.0
# 2024-01-01 00:15:00       0.10   7.136068  -0.149025        0.0           0.0
# 2024-01-01 00:30:00       0.10   3.224757  -2.394920        0.0           0.0
# 2024-01-01 00:45:00       0.10   1.080706   3.409062        0.0           0.0
# 2024-01-01 01:00:00       0.01   5.907751  -0.344401        0.0           0.0
#
#                      p_discharge_daa  p_curtailed_daa  soc_daa  \
# 2024-01-01 00:00:00              0.0              0.0      0.0
# 2024-01-01 00:15:00              0.0              0.0      0.0
# 2024-01-01 00:30:00              0.0              0.0      0.0
# 2024-01-01 00:45:00              0.0              0.0      0.0
# 2024-01-01 01:00:00              0.0              0.0      0.0
#
#                      injection_power_daa  p_charge_ida  p_discharge_ida  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa  p_close_discharge_daa  \
# 2024-01-01 00:00:00                 0.0                    0.0
# 2024-01-01 00:15:00                 0.0                    0.0
# 2024-01-01 00:30:00                 0.0                    0.0
# 2024-01-01 00:45:00                 0.0                    0.0
# 2024-01-01 01:00:00                 0.0                    0.0
#
#                      p_curtailed_ida  p_close_curtailed_daa  p_charge_daa_ida  \
# 2024-01-01 00:00:00              0.0                    0.0               0.0
# 2024-01-01 00:15:00              0.0                    0.0               0.0
# 2024-01-01 00:30:00              0.0                    0.0               0.0
# 2024-01-01 00:45:00              0.0                    0.0               0.0
# 2024-01-01 01:00:00              0.0                    0.0               0.0
#
#                      p_discharge_daa_ida  p_curtailed_daa_ida  soc_ida  \
# 2024-01-01 00:00:00                  0.0                  0.0      0.0
# 2024-01-01 00:15:00                  0.0                  0.0      0.0
# 2024-01-01 00:30:00                  0.0                  0.0      0.0
# 2024-01-01 00:45:00                  0.0                  0.0      0.0
# 2024-01-01 01:00:00                  0.0                  0.0      0.0
#
#                      injection_power_ida  p_charge_idc  p_discharge_idc  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa_ida  p_close_discharge_daa_ida  \
# 2024-01-01 00:00:00                     0.0                        0.0
# 2024-01-01 00:15:00                     0.0                        0.0
# 2024-01-01 00:30:00                     0.0                        0.0
# 2024-01-01 00:45:00                     0.0                        0.0
# 2024-01-01 01:00:00                     0.0                        0.0
#
#                      p_curtailed_idc  p_close_curtailed_daa_ida  \
# 2024-01-01 00:00:00              0.0                        0.0
# 2024-01-01 00:15:00              0.0                        0.0
# 2024-01-01 00:30:00              0.0                        0.0
# 2024-01-01 00:45:00              0.0                        0.0
# 2024-01-01 01:00:00              0.0                        0.0
#
#                      p_charge_daa_ida_idc  p_discharge_daa_ida_idc  \
# 2024-01-01 00:00:00                   0.0                      0.0
# 2024-01-01 00:15:00                   0.0                      0.0
# 2024-01-01 00:30:00                   0.0                      0.0
# 2024-01-01 00:45:00                   0.0                      0.0
# 2024-01-01 01:00:00                   0.0                      0.0
#
#                      p_curtailed_daa_ida_idc  soc_idc  injection_power_idc
# 2024-01-01 00:00:00                      0.0      0.0                  0.0
# 2024-01-01 00:15:00                      0.0      0.0                  0.0
# 2024-01-01 00:30:00                      0.0      0.0                  0.0
# 2024-01-01 00:45:00                      0.0      0.0                  0.0
# 2024-01-01 01:00:00                      0.0      0.0                  0.0

# %% [markdown]
# ### Plot the results

# %%
# Plotting the results
# Set timerange for plotting
plot_start = pd.to_datetime('2024-06-21 00:00:00')
plot_end = pd.to_datetime('2024-06-28 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(21, 1, figsize=(12,36))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.ida_price, label='IDA [€/MWh]', color='cyan')
ax[3].plot(results_slice.idc_price, label='IDC [€/MWh]', color='magenta')
ax[4].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[4].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[5].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[6].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[7].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')

ax[8].plot(results_slice.p_close_charge_daa, label='Closed Charge Power DAA [MW]', color='yellow')
ax[8].plot(-results_slice.p_close_discharge_daa, label='Closed Discharge Power DAA [MW]', color='goldenrod')
ax[9].plot(results_slice.p_charge_ida, label='Charge Power IDA [MW]', color='lightblue')
ax[9].plot(-results_slice.p_discharge_ida, label='Discharge Power IDA [MW]', color='blue')
ax[10].plot(results_slice.p_close_curtailed_daa, label='Closed Curtailed Power DAA [MW]', color='plum')
ax[11].plot(results_slice.p_curtailed_daa_ida, label='Curtailed Power DAA IDA [MW]', color='lightcoral')
ax[12].plot(results_slice.soc_ida, label='SoC [MWh] IDA', color='lime')
ax[13].plot(results_slice.injection_power_ida, label='Injection Power DAA IDA [MW]', color='plum')

ax[14].plot(results_slice.p_close_charge_daa_ida, label='Closed Charge Power DAA IDA [MW]', color='lightgreen')
ax[14].plot(-results_slice.p_close_discharge_daa_ida, label='Closed Discharge Power DAA IDA [MW]', color='green')
ax[15].plot(results_slice.p_charge_idc, label='Charge Power IDC [MW]', color='#bfcf7c')
ax[15].plot(-results_slice.p_discharge_idc, label='Discharge Power IDC [MW]', color='olive') #, ls='', marker='_')
ax[16].plot(results_slice.p_close_curtailed_daa_ida, label='Closed Curtailed Power DAA IDA [MW]', color='plum')
ax[17].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='lightcoral')
ax[18].plot(results_slice.soc_idc, label='SoC [MWh] IDC', color='lime')
ax[19].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='plum')
ax[20].plot(results_slice.pv_output, label='PV Power [MW]', color='orange')
ax[20].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='red')
ax[20].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='darkred')

ax[20].set_xlabel('Time')

for i in range(21):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results.png')

# %% [markdown]
# ### Calculate energies and profits

# %%
##### Calculate energies
pv_production = results.pv_output.sum() * 15 / 60  # Convert from MW to MWh
injected_energy_daa = results.injection_power_daa.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_daa = results.p_curtailed_daa.sum() * 15 / 60 # Convert from MW to MWh
discharge_energy_daa = results.p_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa = results.p_charge_daa.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_ida = results.injection_power_ida.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_ida = results.p_curtailed_daa_ida.sum() * 15 / 60 # Convert from MW to MWh
closed_curtailed_daa_energy = results.p_close_curtailed_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_ida = results.p_discharge_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_ida = results.p_charge_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_energy = results.p_close_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_energy = results.p_close_charge_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida = results.p_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida = results.p_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_idc = results.injection_power_idc.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_idc = results.p_curtailed_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_curtailed_daa_ida_energy = results.p_close_curtailed_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_idc = results.p_discharge_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_idc = results.p_charge_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_ida_energy = results.p_close_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_ida_energy = results.p_close_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida_idc = results.p_discharge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida_idc = results.p_charge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh

# Print calculated energies
print('Annual Energies:')
print('==========================================')
print('PV')
print('----------')
print('PV Production:', f'{pv_production:.2f} MWh')
print('------------------------------------------')
print('DAA Market')
print('----------')
print('Injected Energy DAA:', f'{injected_energy_daa:.2f} MWh')
print('Curtailed Energy DAA:', f'{curtailed_energy_daa:.2f} MWh')
print('Charge Energy DAA:', f'{charge_energy_daa:.2f} MWh')
print('Discharge Energy DAA:', f'{discharge_energy_daa:.2f} MWh')
print('------------------------------------------')
print('IDA Market')
print('----------')
print('Injected Energy IDA:', f'{injected_energy_ida:.2f} MWh')
print('Curtailed Energy IDA:', f'{curtailed_energy_ida:.2f} MWh')
print('Closed Curtailed Energy DAA:', f'{closed_curtailed_daa_energy:.2f} MWh')
print('Charge Energy IDA:', f'{charge_energy_ida:.2f} MWh')
print('Discharge Energy IDA:', f'{discharge_energy_ida:.2f} MWh')
print('Closed Charge Energy DAA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA:', f'{charge_energy_daa_ida:.2f} MWh')
print('Physical Discharge Energy DAA IDA:', f'{discharge_energy_daa_ida:.2f} MWh')
print('------------------------------------------')
print('IDC Market')
print('----------')
print('Injected Energy IDC:', f'{injected_energy_idc:.2f} MWh')
print('Curtailed Energy IDC:', f'{curtailed_energy_idc:.2f} MWh')
print('Closed Curtailed Energy DAA IDA:', f'{closed_curtailed_daa_ida_energy:.2f} MWh')
print('Charge Energy IDC:', f'{charge_energy_idc:.2f} MWh')
print('Discharge Energy IDC:', f'{discharge_energy_idc:.2f} MWh')
print('Closed Charge Energy DAA IDA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA IDA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA IDC:', f'{charge_energy_daa_ida_idc:.2f} MWh')
print('Physical Discharge Energy DAA IDA IDC:', f'{discharge_energy_daa_ida_idc:.2f} MWh')
print('------------------------------------------')

##### Calculate profits
# Calculate annual profit from PV Output multiplied with DAA prices as reference
results['pv_direct_market_profit_reference'] = results.daa_price * results.pv_output * 15 / 60
# Only sum up profit at positive market prices, because plant will be curtailed at other times
condition_daa_positive = results.daa_price >= 0
annual_pv_production_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'pv_output'].sum() * 15 / 60
annual_pv_direct_market_profit_reference = results.loc[condition_daa_positive, 'pv_direct_market_profit_reference'].sum()

# Calculate annual profit on DAA market
results['injected_power_direct_market_profit_daa'] = results.daa_price * results.injection_power_daa * 15 / 60
annual_injected_energy_direct_market_profit_daa = results.injected_power_direct_market_profit_daa.sum()

# Calculate annual profit on IDA market
results['ida_market_profit'] = (results['p_discharge_ida'] - results['p_charge_ida'] 
                                + results['p_close_charge_daa'] - results['p_close_discharge_daa'] 
                                + results['p_close_curtailed_daa'] - results['p_curtailed_ida']) * results['ida_price']  / 4
annual_ida_market_profit = results['ida_market_profit'].sum()

# Calculate annual profit on IDC market
results['idc_market_profit'] = (results['p_discharge_idc'] - results['p_charge_idc'] 
                                + results['p_close_charge_daa_ida'] - results['p_close_discharge_daa_ida'] 
                                + results['p_close_curtailed_daa_ida'] - results['p_curtailed_idc']) * results['idc_price']  / 4
annual_idc_market_profit = results['idc_market_profit'].sum()

# Print annual profit values
print('Annual Direct Market Profits:')
print('----------------------------------------------------------------------------------------')
print('Annual PV Direct Market Profit (Reference):', f'{annual_pv_direct_market_profit_reference:.2f} €', '(excl. negative DAA price hours)')
print('Annual Injected Energy Direct Market Profit (DAA):', f'{annual_injected_energy_direct_market_profit_daa:.2f} €')
print('Annual IDA Market Profit:', f'{annual_ida_market_profit:.2f} €')
print('Annual IDC Market Profit:', f'{annual_idc_market_profit:.2f} €')
print('----------------------------------------------------------------------------------------')

# Calculate annual market bonus
annual_injected_energy_idc_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'injection_power_idc'].sum() * 15 / 60
market_bonus_injected_energy_idc = annual_injected_energy_idc_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_injected_energy_idc < 0:
    market_bonus_injected_energy_idc = 0
market_bonus_pv_production = annual_pv_production_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_pv_production < 0:
    market_bonus_pv_production = 0

print('Annual Market Boni:')
print('------------------------------------------------------------------')
print('Annual Market Bonus PV + BESS (IDC):', f'{market_bonus_injected_energy_idc:.2f} €', '(excl. negative DAA price hours)')
print('Annual Market Bonus PV only:', f'{market_bonus_pv_production:.2f} €', '(excl. negative DAA price hours)')
print('------------------------------------------------------------------')

print('Final Results:')
print('------------------------------------------------------------')
print('Annual profit PV only (reference):', f'{market_bonus_pv_production + annual_pv_direct_market_profit_reference:.2f} €')
print('Annual profit PV + BESS (DAA IDA IDC):', f'{market_bonus_injected_energy_idc 
                                                   + annual_injected_energy_direct_market_profit_daa 
                                                   + annual_ida_market_profit + annual_idc_market_profit:.2f} €')
print('Annual BESS profit (DAA IDA IDC):', f'{annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production :.2f} €')
print('Specific Annual BESS profit (DAA IDA IDC):', f'{(annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production) / storage_capacity:.2f} €/MWh')
# Out:
# Annual Energies:
# ==========================================
# PV
# ----------
# PV Production: 5568.25 MWh
# ------------------------------------------
# DAA Market
# ----------
# Injected Energy DAA: 4859.39 MWh
# Curtailed Energy DAA: 557.57 MWh
# Charge Energy DAA: 1551.72 MWh
# Discharge Energy DAA: 1400.43 MWh
# ------------------------------------------
# IDA Market
# ----------
# Injected Energy IDA: 4958.85 MWh
# Curtailed Energy IDA: 400.47 MWh
# Closed Curtailed Energy DAA: 275.36 MWh
# Charge Energy IDA: 998.00 MWh
# Discharge Energy IDA: 1318.28 MWh
# Closed Charge Energy DAA: 549.33 MWh
# Closed Discharge Energy DAA: 874.69 MWh
# Physical Charge Energy DAA IDA: 2142.88 MWh
# Physical Discharge Energy DAA IDA: 1933.95 MWh
# ------------------------------------------
# IDC Market
# ----------
# Injected Energy IDC: 4919.18 MWh
# Curtailed Energy IDC: 442.66 MWh
# Closed Curtailed Energy DAA IDA: 149.84 MWh
# Charge Energy IDC: 523.50 MWh
# Discharge Energy IDC: 851.38 MWh
# Closed Charge Energy DAA IDA: 549.33 MWh
# Closed Discharge Energy DAA IDA: 874.69 MWh
# Physical Charge Energy DAA IDA IDC: 2117.06 MWh
# Physical Discharge Energy DAA IDA IDC: 1910.64 MWh
# ------------------------------------------
# Annual Direct Market Profits:
# ----------------------------------------------------------------------------------------
# Annual PV Direct Market Profit (Reference): 304483.39 € (excl. negative DAA price hours)
# Annual Injected Energy Direct Market Profit (DAA): 431049.81 €
# Annual IDA Market Profit: 68859.84 €
# Annual IDC Market Profit: 57608.27 €
# ----------------------------------------------------------------------------------------
# Annual Market Boni:
# ------------------------------------------------------------------
# Annual Market Bonus PV + BESS (IDC): 0.00 € (excl. negative DAA price hours)
# Annual Market Bonus PV only: 0.00 € (excl. negative DAA price hours)
# ------------------------------------------------------------------
# Final Results:
# ------------------------------------------------------------
# Annual profit PV only (reference): 304483.39 €
# Annual profit PV + BESS (DAA IDA IDC): 557517.92 €
# Annual BESS profit (DAA IDA IDC): 253034.53 €
# Specific Annual BESS profit (DAA IDA IDC): 50606.91 €/MWh

# %%
# Plotting the results for abstract
# Set timerange for plotting
plot_start = pd.to_datetime('2024-06-15 00:00:00')
plot_end = pd.to_datetime('2024-06-21 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(7, 1, figsize=(12,12))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[3].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[4].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[5].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[6].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')
ax[6].set_xlabel('Time')

for i in range(7):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results_abstract.jpg')

# %% [markdown]
# ### Export results to .csv

# %%
results.to_csv('results.csv')
