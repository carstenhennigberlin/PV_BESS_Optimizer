# %% [markdown]
# # Load Intraday Auction Data (IDA)

# %%
import pandas as pd

# %%
dfs = []
for i in range(1, 53):
    df = pd.read_csv(f'energy-charts_Stromproduktion_und_Börsenstrompreise_in_Deutschland_in_Woche_{i}_2024.csv', 
                     sep=';', 
                     decimal=',',
                     header=None,
                     index_col=0
                    )
    df.sort_index(inplace=True) 
    dfs.append(df)

# %%
ida = pd.concat(dfs)

# %%
ida.head()
# Out:
#              1
# 0
# 1.0  64.727150
# 2.0  75.193600
# 3.0  37.950565
# 4.0  26.390119
# 5.0  71.026882

# %%
ida.rename(columns={1: 'IDA'}, inplace=True)
ida.index = pd.date_range(start='2023-1-2 00:00', 
                         end='2023-12-31 23:45', 
                         freq='15min ')

# %%
ida.describe()
# Out:
#                 IDA
# count  34944.000000
# mean      94.282754
# std       55.649086
# min     -650.167165
# 25%       68.526276
# 50%       96.823952
# 75%      124.950438
# max     1601.393885

# %%
ida.plot()
# Out:
# <AxesSubplot:>

# %%
ida.to_csv('2023_ida.csv')
