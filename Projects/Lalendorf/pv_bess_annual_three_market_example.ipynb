# %% [markdown]
# # PV-BESS optimizer

# %% [markdown]
# ### Example Jupyter notebook for scheduling a PV-BESS system using the Pyomo optimization framework.
# This jupyter notebook generates schedules for the marketing of the energy provided by a combination of a PV plant and a battery storage system (BESS) and calculates the corresponding profits on the day-ahead and intraday markets (DAA, IDA and IDC).
#
# This notebook uses historic market price data and PV production profiles and therefore represents a backtest following the principle of a perfect foresight.
#
# The schedules are generated by functions of the scheduler_three_market.py module, which make use of the Pyomo modelling framework for mathematical opimization. Each function includes an objective and several constraints, which can be reviewed in the module.

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries
from scheduler_three_market import get_daa_schedule, get_ida_schedule, get_idc_schedule # Import the scheduler module which contains the Pyomo model and optimization logic
import matplotlib.pyplot as plt  # Import matplotlib for plotting results
import pandas as pd  # Import pandas for data handling

# %% [markdown]
# ### Set the input parameters

# %%
# BESS (Battery Energy Storage System) parameters
p_limit = 13.5  # Maximum injection power limit in MW
storage_capacity = 15.3 # Storage capacity in MWh
p_charge_max = 5.8  # Maximum charge power in MW
p_discharge_max = 5.8 # Maximum discharge power MW
efficiency = 0.95 # Charge/discharge efficiency of the BESS
start_soc = 0.0  # Initial state of charge
end_soc = 0.0  # End state of charge, can be adjusted as needed
number_of_cycles = 1 * 7  # Number of cycles for the period (week)

# General parameters
number_of_weeks = 52  # Number of weeks in the year
year = '2024'  # Year for which the data is being processed

# Commercial parameters
applicable_value = 58.9 # Applicable value for the plant from EEG or tender ("anzulegneder Wert") in €/MWh. This is the value that the plant operator receives for the energy fed into the grid..

# %% [markdown]
# ### Year data dictionary

# %%
year_data = {
            # '2020': [24.6,'./data/2020/DA/2020_daa.csv',
            #                   './data/2020/IDA/2020_ida.csv' ,
            #                   './data/2020/ID1/2020_id1.csv',
            #                   './data/2020/PV/2020_pv.csv',
            #                   '2020-01-06 00:00:00'], 
            #  '2021': [75.5,'./data/2021/DA/2021_daa.csv',
            #                   './data/2021/IDA/2021_ida.csv' ,
            #                   './data/2021/ID1/2021_id1.csv',
            #                   './data/2021/PV/2021_pv.csv',
            #                   '2021-01-04 00:00:00'], 
            #  '2022': [223.1,'./data/2022/DA/2022_daa.csv',
            #                   './data/2022/IDA/2022_ida.csv' ,
            #                   './data/2022/ID1/2022_id1.csv',
            #                   './data/2022/PV/2022_pv.csv',
            #                   '2022-01-03 00:00:00'], 
            #  '2023': [72.0,'./data/2023/DA/2023_daa.csv',
            #                   './data/2023/IDA/2023_ida.csv' ,
            #                   './data/2023/ID1/2023_id1.csv',
            #                   './data/2023/PV/2023_pv.csv',
            #                   '2023-01-02 00:00:00'],
             '2024': [46.24,'./data/2024/DA/2024_daa.csv',
                              './data/2024/IDA/2024_ida.csv' ,
                              './data/2024/ID1/2024_id1.csv',
                              './data/2024/PV/2024_pv.csv',
                              '2024-01-01 00:00:00'], 
            }
# Extract the market value for the specified year
market_value = year_data[year][0]

# %% [markdown]
# ### Load DAA, IDA and IDC data from files

# %%
daa = pd.read_csv(year_data[year][1], index_col = 0)
daa.index = pd.to_datetime(daa.index)

ida = pd.read_csv(year_data[year][2], index_col = 0)
ida.index = pd.to_datetime(ida.index)

idc = pd.read_csv(year_data[year][3], index_col = 0)
idc.index = pd.to_datetime(idc.index)

# %% [markdown]
# ### Load PV load profile from .csv:

# %%
pv = pd.read_csv(year_data[year][4], index_col = 0)
pv.index = pd.to_datetime(pv.index)
pv.PV = [max(0, v) for v in pv.PV] # Set negative values to zero

# %% [markdown]
# ### Get the optimized schedule
# This is done for weekly time slices. The results for the single weeks are then concatenated into a result dataframe.

# %%
start = pd.to_datetime(year_data[year][5])
end = start + pd.DateOffset(days=7) - pd.DateOffset(minutes=15)  # Set end to the next week minus 15 minutes
result_list = []

for i in range(1, number_of_weeks + 1):
    print('start/end', start, end)
    pv_vector = pv.PV[start:end].to_list()
    daa_price_vector = daa.DAA[start:end].to_list()
    ida_price_vector = ida.IDA[start:end].to_list()
    idc_price_vector = idc.ID1[start:end].to_list()

    # Ensure the vectors are not empty
    if not pv_vector or not daa_price_vector or not ida_price_vector or not idc_price_vector:
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors cannot be empty.")

    # Ensure the vectors are of the same length
    if len(pv_vector) != len(daa_price_vector) or len(pv_vector) != len(ida_price_vector) or len(pv_vector) != len(idc_price_vector):
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors must have the same length.")

    pv_output, daa_price, p_charge_daa, p_discharge_daa, soc_daa, p_curtailed_daa, injection_power_daa = get_daa_schedule(pv_vector,
                                                                                                  daa_price_vector, 
                                                                                                  p_limit, 
                                                                                                  storage_capacity, 
                                                                                                  p_charge_max, 
                                                                                                  p_discharge_max, 
                                                                                                  number_of_cycles, 
                                                                                                  efficiency, 
                                                                                                  start_soc, 
                                                                                                  end_soc)

    ida_price, p_charge_ida, p_discharge_ida, p_close_charge_daa, p_close_discharge_daa, p_curtailed_ida, \
        p_close_curtailed_daa, p_curtailed_daa_ida ,p_charge_daa_ida, p_discharge_daa_ida, soc_ida, injection_power_ida = get_ida_schedule(
                                                                                                                        ida_price_vector, 
                                                                                                                        pv_output,
                                                                                                                        p_limit, 
                                                                                                                        storage_capacity, 
                                                                                                                        p_charge_max, 
                                                                                                                        p_discharge_max,
                                                                                                                        p_charge_daa,
                                                                                                                        p_discharge_daa,
                                                                                                                        p_curtailed_daa,
                                                                                                                        number_of_cycles, 
                                                                                                                        efficiency, 
                                                                                                                        start_soc, 
                                                                                                                        end_soc)
    
    idc_price, p_charge_idc, p_discharge_idc, p_close_charge_daa_ida, p_close_discharge_daa_ida, p_curtailed_idc, \
        p_close_curtailed_daa_ida, p_curtailed_daa_ida_idc, p_charge_daa_ida_idc, p_discharge_daa_ida_idc, soc_idc, injection_power_idc = get_idc_schedule(
                                                                                                                                idc_price_vector,
                                                                                                                                pv_output, 
                                                                                                                                p_limit, 
                                                                                                                                storage_capacity, 
                                                                                                                                p_charge_max, 
                                                                                                                                p_discharge_max,
                                                                                                                                p_charge_daa_ida,
                                                                                                                                p_discharge_daa_ida,
                                                                                                                                p_curtailed_daa_ida,
                                                                                                                                number_of_cycles, 
                                                                                                                                efficiency, 
                                                                                                                                start_soc, 
                                                                                                                                end_soc
                                                                                                                            )

    # Create a DataFrame to store the results for the current week
    result = pd.DataFrame({# prices and PV output
                           'daa_price': daa_price,
                           'ida_price': ida_price,
                           'idc_price': idc_price,
                           'pv_output': pv_output,
                            # DAA results
                           'p_charge_daa': p_charge_daa,
                           'p_discharge_daa': p_discharge_daa,
                           'p_curtailed_daa': p_curtailed_daa,
                           'soc_daa': soc_daa,
                           'injection_power_daa': injection_power_daa,
                           # IDA results
                           'p_charge_ida': p_charge_ida,
                           'p_discharge_ida': p_discharge_ida,
                           'p_close_charge_daa': p_close_charge_daa,
                           'p_close_discharge_daa': p_close_discharge_daa,
                           'p_curtailed_ida': p_curtailed_ida,
                           'p_close_curtailed_daa': p_close_curtailed_daa,
                           'p_charge_daa_ida': p_charge_daa_ida,
                           'p_discharge_daa_ida': p_discharge_daa_ida,
                           'p_curtailed_daa_ida': p_curtailed_daa_ida,
                           'soc_ida': soc_ida,
                           'injection_power_ida': injection_power_ida,
                           # IDC results
                           'p_charge_idc': p_charge_idc,
                           'p_discharge_idc': p_discharge_idc,
                           'p_close_charge_daa_ida': p_close_charge_daa_ida,
                           'p_close_discharge_daa_ida': p_close_discharge_daa_ida,
                           'p_curtailed_idc': p_curtailed_idc,
                           'p_close_curtailed_daa_ida': p_close_curtailed_daa_ida,
                           'p_charge_daa_ida_idc': p_charge_daa_ida_idc,
                           'p_discharge_daa_ida_idc': p_discharge_daa_ida_idc,
                           'p_curtailed_daa_ida_idc': p_curtailed_daa_ida_idc,
                           'soc_idc': soc_idc,
                           'injection_power_idc': injection_power_idc
                          }
                         )
    
    result.index = pd.date_range(start=start, end=end, freq='15min')
    
    result_list.append(result)

    start = start + pd.DateOffset(days=7) # Set start and end to the next week
    end = end + pd.DateOffset(days=7)
    
results = pd.concat(result_list)
# Out:
# start/end 2024-01-01 00:00:00 2024-01-07 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15004 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-03, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4250 rows, 3121 cols, 10491 nonzeros  0s
# 2234 rows, 2232 cols, 6933 nonzeros  0s
# 1736 rows, 1337 cols, 4217 nonzeros  0s
# 1297 rows, 1335 cols, 3337 nonzeros  0s
#
# Solving MIP model with:
#    1297 rows
#    1335 cols (240 binary, 0 integer, 0 implied int., 1095 continuous, 0 domain fixed)
#    3337 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             1636.011695        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2460.014952     1859.727788       32.28%        0      0      0      1057     0.1s
#  L       0       0         0   0.00%   2460.014952     2460.014952        0.00%      386    155      0      1212     0.3s
#          1       0         1 100.00%   2460.014952     2460.014952        0.00%      386    155      0      1280     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      2460.01495175
#   Dual bound        2460.01495175
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.629057944015
#   Solution status   feasible
#                     2460.01495175 (objective)
#                     0 (bound viol.)
#                     6.2172489379e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1280 (total)
#                     0 (strong br.)
#                     155 (separation)
#                     68 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 3 |values| in [2.10942e-16, 3.37508e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31549 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [2e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 9e+01]
# Presolving model
# 9371 rows, 3521 cols, 16744 nonzeros  0s
# 2841 rows, 2639 cols, 8733 nonzeros  0s
# 1922 rows, 1731 cols, 5175 nonzeros  0s
# 1899 rows, 1731 cols, 5129 nonzeros  0s
#
# Solving MIP model with:
#    1899 rows
#    1731 cols (431 binary, 0 integer, 0 implied int., 1300 continuous, 0 domain fixed)
#    5129 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -844.8391575       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   242.1025532     227.0217629        6.64%        0      0      0      1202     0.2s
#  H       0       0         0   0.00%   242.1025532     242.1025532        0.00%      202     55      0      1257     0.3s
#          1       0         1 100.00%   242.1025532     242.1025532        0.00%      202     55      0      1257     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      242.102553195
#   Dual bound        242.102553195
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.47616307682
#   Solution status   feasible
#                     242.102553195 (objective)
#                     0 (bound viol.)
#                     9.54791801178e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1257 (total)
#                     0 (strong br.)
#                     55 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 12 |values| in [4.93038e-32, 1.68754e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31569 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-02, 5e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-32, 9e+01]
# Presolving model
# 9391 rows, 3561 cols, 16922 nonzeros  0s
# 2930 rows, 2708 cols, 8985 nonzeros  0s
# 1991 rows, 1782 cols, 5357 nonzeros  0s
# 1969 rows, 1782 cols, 5313 nonzeros  0s
#
# Solving MIP model with:
#    1969 rows
#    1782 cols (456 binary, 0 integer, 0 implied int., 1326 continuous, 0 domain fixed)
#    5313 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1050.891779       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   519.6801558     499.3875595        4.06%        0      0      0      1201     0.2s
#  H       0       0         0   0.00%   519.6801558     519.6801558        0.00%      196     51      0      1255     0.3s
#          1       0         1 100.00%   519.6801558     519.6801558        0.00%      196     51      0      1255     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      519.680155759
#   Dual bound        519.680155759
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.31121779674
#   Solution status   feasible
#                     519.680155759 (objective)
#                     0 (bound viol.)
#                     1.15463194561e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.35 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1255 (total)
#                     0 (strong br.)
#                     54 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-08 00:00:00 2024-01-14 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15012 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [2e+01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4258 rows, 3137 cols, 10531 nonzeros  0s
# 2242 rows, 2240 cols, 6941 nonzeros  0s
# 1728 rows, 1313 cols, 4129 nonzeros  0s
# 1265 rows, 1311 cols, 3201 nonzeros  0s
#
# Solving MIP model with:
#    1265 rows
#    1311 cols (224 binary, 0 integer, 0 implied int., 1087 continuous, 0 domain fixed)
#    3201 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             4901.583724        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   5698.784552     5231.699803        8.93%        0      0      0      1022     0.1s
#  L       0       0         0   0.00%   5698.784552     5698.784552        0.00%      402    153      0      1177     0.3s
#          1       0         1 100.00%   5698.784552     5698.784552        0.00%      402    153      0      1259     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      5698.78455229
#   Dual bound        5698.78455229
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.201195140833
#   Solution status   feasible
#                     5698.78455229 (objective)
#                     0 (bound viol.)
#                     7.68274333041e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.31 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1259 (total)
#                     0 (strong br.)
#                     155 (separation)
#                     82 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31580 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [1e+01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [6e-17, 7e+01]
# Presolving model
# 9402 rows, 3567 cols, 16921 nonzeros  0s
# 2885 rows, 2668 cols, 8847 nonzeros  0s
# 1906 rows, 1714 cols, 5119 nonzeros  0s
# 1880 rows, 1714 cols, 5067 nonzeros  0s
#
# Solving MIP model with:
#    1880 rows
#    1714 cols (414 binary, 0 integer, 0 implied int., 1300 continuous, 0 domain fixed)
#    5067 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1005.455936       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   587.2705745     560.9494175        4.69%        0      0      0      1196     0.2s
#  C       0       0         0   0.00%   587.2705745     575.8749183        1.98%      166     47      0      1243     0.3s
#  H       0       0         0   0.00%   587.2705745     587.2705745        0.00%      166     47      0      1243     0.3s
#          1       0         1 100.00%   587.2705745     587.2705745        0.00%      166     47      0      1243     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      587.270574501
#   Dual bound        587.270574501
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.30762427707
#   Solution status   feasible
#                     587.270574501 (objective)
#                     0 (bound viol.)
#                     1.15463194561e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1243 (total)
#                     0 (strong br.)
#                     47 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 16 |values| in [8.88178e-16, 3.55271e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31591 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [6e+00, 1e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [6e-17, 7e+01]
# Presolving model
# 9413 rows, 3589 cols, 17019 nonzeros  0s
# 2916 rows, 2688 cols, 8943 nonzeros  0s
# 1933 rows, 1730 cols, 5199 nonzeros  0s
# 1908 rows, 1730 cols, 5149 nonzeros  0s
#
# Solving MIP model with:
#    1908 rows
#    1730 cols (423 binary, 0 integer, 0 implied int., 1307 continuous, 0 domain fixed)
#    5149 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1706.165277       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1633.787383     1621.358289        0.77%        0      0      0      1181     0.2s
#  H       0       0         0   0.00%   1633.787383     1633.787383        0.00%      151     41      0      1222     0.3s
#          1       0         1 100.00%   1633.787383     1633.787383        0.00%      151     41      0      1222     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1633.78738294
#   Dual bound        1633.78738294
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.89514003204
#   Solution status   feasible
#                     1633.78738294 (objective)
#                     0 (bound viol.)
#                     2.22044604925e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.26 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1222 (total)
#                     0 (strong br.)
#                     41 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-15 00:00:00 2024-01-21 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15018 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [9e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4264 rows, 3149 cols, 10561 nonzeros  0s
# 2245 rows, 2246 cols, 6941 nonzeros  0s
# 1737 rows, 1331 cols, 4165 nonzeros  0s
# 1282 rows, 1329 cols, 3253 nonzeros  0s
#
# Solving MIP model with:
#    1282 rows
#    1329 cols (230 binary, 0 integer, 0 implied int., 1099 continuous, 0 domain fixed)
#    3253 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             6575.230156        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   7241.921502     6915.760552        4.72%        0      0      0       989     0.1s
#  L       0       0         0   0.00%   7241.921502     7241.921502        0.00%      334    130      0      1116     0.2s
#          1       0         1 100.00%   7241.921502     7241.921502        0.00%      334    130      0      1176     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      7241.92150193
#   Dual bound        7241.92150193
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.107647362405
#   Solution status   feasible
#                     7241.92150193 (objective)
#                     0 (bound viol.)
#                     9.54791801178e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.23 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1176 (total)
#                     0 (strong br.)
#                     127 (separation)
#                     60 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31574 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [6e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 6e+01]
# Presolving model
# 9396 rows, 3543 cols, 16797 nonzeros  0s
# 2839 rows, 2643 cols, 8686 nonzeros  0s
# 1880 rows, 1710 cols, 5043 nonzeros  0s
# 1851 rows, 1710 cols, 4985 nonzeros  0s
#
# Solving MIP model with:
#    1851 rows
#    1710 cols (406 binary, 0 integer, 0 implied int., 1304 continuous, 0 domain fixed)
#    4985 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -822.80528         Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   332.7524709     298.0616536       11.64%        0      0      0      1190     0.2s
#  C       0       0         0   0.00%   332.7524709     298.3287015       11.54%      161     57      0      1250     0.3s
#  H       0       0         0   0.00%   332.7524709     332.7524709        0.00%      161     57      0      1250     0.3s
#          1       0         1 100.00%   332.7524709     332.7524709        0.00%      161     57      0      1250     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      332.752470863
#   Dual bound        332.752470863
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.98653389251
#   Solution status   feasible
#                     332.752470863 (objective)
#                     0 (bound viol.)
#                     1.24344978758e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.29 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1250 (total)
#                     0 (strong br.)
#                     60 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 12 |values| in [8.88178e-16, 1.5099e-14] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31608 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e+00, 5e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 6e+01]
# Presolving model
# 9430 rows, 3611 cols, 17098 nonzeros  0s
# 2942 rows, 2711 cols, 8994 nonzeros  0s
# 1970 rows, 1770 cols, 5318 nonzeros  0s
# 1949 rows, 1770 cols, 5276 nonzeros  0s
#
# Solving MIP model with:
#    1949 rows
#    1770 cols (435 binary, 0 integer, 0 implied int., 1335 continuous, 0 domain fixed)
#    5276 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -509.3163018       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   701.9535082     678.7910885        3.41%        0      0      0      1152     0.2s
#  H       0       0         0   0.00%   701.9535082     701.9535082        0.00%      161     40      0      1194     0.3s
#          1       0         1 100.00%   701.9535082     701.9535082        0.00%      161     40      0      1194     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      701.953508241
#   Dual bound        701.953508241
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      4.61032373839
#   Solution status   feasible
#                     701.953508241 (objective)
#                     0 (bound viol.)
#                     6.66133814775e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1194 (total)
#                     0 (strong br.)
#                     42 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-22 00:00:00 2024-01-28 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15024 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [7e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4270 rows, 3161 cols, 10591 nonzeros  0s
# 2254 rows, 2252 cols, 6953 nonzeros  0s
# 1772 rows, 1389 cols, 4333 nonzeros  0s
# 1351 rows, 1387 cols, 3489 nonzeros  0s
#
# Solving MIP model with:
#    1351 rows
#    1387 cols (256 binary, 0 integer, 0 implied int., 1131 continuous, 0 domain fixed)
#    3489 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             5036.894685        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   6745.022126     6260.254354        7.74%        0      0      0       967     0.1s
#  C       0       0         0   0.00%   6745.022126     6332.123718        6.52%      438    169      0      1113     0.2s
#  L       0       0         0   0.00%   6745.022126     6745.022126        0.00%      448    172      0      1117     0.3s
#          1       0         1 100.00%   6745.022126     6745.022126        0.00%      448    172      0      1153     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      6745.02212591
#   Dual bound        6745.02212591
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.181011371271
#   Solution status   feasible
#                     6745.02212591 (objective)
#                     0 (bound viol.)
#                     6.2172489379e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.30 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1153 (total)
#                     0 (strong br.)
#                     150 (separation)
#                     36 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [3.37508e-15, 3.37508e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31606 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [2e-03, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-17, 4e+01]
# Presolving model
# 9428 rows, 3595 cols, 17005 nonzeros  0s
# 2905 rows, 2685 cols, 8867 nonzeros  0s
# 1943 rows, 1765 cols, 5286 nonzeros  0s
# 1923 rows, 1765 cols, 5246 nonzeros  0s
#
# Solving MIP model with:
#    1923 rows
#    1765 cols (426 binary, 0 integer, 0 implied int., 1339 continuous, 0 domain fixed)
#    5246 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2282.51458        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   508.5854591     442.7913952       14.86%        0      0      0      1182     0.2s
#  C       0       0         0   0.00%   508.5854591     462.2619521       10.02%      210     60      0      1247     0.3s
#  H       0       0         0   0.00%   508.5854591     508.5854591        0.00%      210     61      0      1248     0.3s
#          1       0         1 100.00%   508.5854591     508.5854591        0.00%      210     61      0      1248     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      508.585459112
#   Dual bound        508.585459112
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.798105183507
#   Solution status   feasible
#                     508.585459112 (objective)
#                     0 (bound viol.)
#                     7.32747196253e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.30 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1248 (total)
#                     0 (strong br.)
#                     66 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 10 |values| in [7.88861e-31, 2.66454e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31635 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [4e-03, 2e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [2e-31, 4e+01]
# Presolving model
# 9457 rows, 3653 cols, 17257 nonzeros  0s
# 3017 rows, 2766 cols, 9186 nonzeros  0s
# 2071 rows, 1868 cols, 5688 nonzeros  0s
# 2044 rows, 1868 cols, 5634 nonzeros  0s
#
# Solving MIP model with:
#    2044 rows
#    1868 cols (476 binary, 0 integer, 0 implied int., 1392 continuous, 0 domain fixed)
#    5634 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2632.762787       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   736.1243463     694.2960415        6.02%        0      0      0      1182     0.2s
#  H       0       0         0   0.00%   736.1243463     736.1243463        0.00%      176     50      0      1237     0.4s
#          1       0         1 100.00%   736.1243463     736.1243463        0.00%      176     50      0      1237     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      736.124346254
#   Dual bound        736.124346254
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.839435744861
#   Solution status   feasible
#                     736.124346254 (objective)
#                     0 (bound viol.)
#                     1.31006316906e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.35 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1237 (total)
#                     0 (strong br.)
#                     55 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-01-29 00:00:00 2024-02-04 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15037 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [1e-01, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4283 rows, 3187 cols, 10656 nonzeros  0s
# 2266 rows, 2265 cols, 6964 nonzeros  0s
# 1781 rows, 1390 cols, 4310 nonzeros  0s
# 1344 rows, 1386 cols, 3434 nonzeros  0s
#
# Solving MIP model with:
#    1344 rows
#    1386 cols (249 binary, 0 integer, 0 implied int., 1137 continuous, 0 domain fixed)
#    3434 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             6369.828003        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   8176.779811     7425.263915       10.12%        0      0      0      1013     0.1s
#  C       0       0         0   0.00%   8176.779811     7656.485384        6.80%      308    158      0      1171     0.2s
#  L       0       0         0   0.00%   8176.779811     8176.779811        0.00%      329    164      0      1182     0.3s
#  T       0       0         0   0.00%   8176.779811     8176.779811        0.00%      329    164      0      1231     0.3s
#          1       0         1 100.00%   8176.779811     8176.779811        0.00%      329    164      0      1231     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      8176.7798111
#   Dual bound        8176.7798111
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.106682813202
#   Solution status   feasible
#                     8176.7798111 (objective)
#                     0 (bound viol.)
#                     2.18415285858e-11 (int. viol.)
#                     0 (row viol.)
#   Timing            0.34 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1231 (total)
#                     0 (strong br.)
#                     169 (separation)
#                     49 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31652 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [1e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-16, 3e+01]
# Presolving model
# 9474 rows, 3661 cols, 17269 nonzeros  0s
# 2974 rows, 2735 cols, 9044 nonzeros  0s
# 2398 rows, 1809 cols, 6284 nonzeros  0s
# 1965 rows, 1803 cols, 5369 nonzeros  0s
#
# Solving MIP model with:
#    1965 rows
#    1803 cols (437 binary, 0 integer, 0 implied int., 1366 continuous, 0 domain fixed)
#    5369 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2065.795764       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   832.7708125     805.0472608        3.44%        0      0      0      1244     0.2s
#  H       0       0         0   0.00%   832.7708125     832.7708125        0.00%      199     63      0      1312     0.3s
#          1       0         1 100.00%   832.7708125     832.7708125        0.00%      199     63      0      1312     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      832.770812522
#   Dual bound        832.770812522
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.945079912486
#   Solution status   feasible
#                     832.770812522 (objective)
#                     0 (bound viol.)
#                     3.10862446895e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.30 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1312 (total)
#                     0 (strong br.)
#                     68 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 23 |values| in [8.43769e-16, 1.77636e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31678 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-02, 1e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-16, 2e+01]
# Presolving model
# 9500 rows, 3713 cols, 17499 nonzeros  0s
# 3112 rows, 2844 cols, 9439 nonzeros  0s
# 2173 rows, 1957 cols, 5986 nonzeros  0s
# 2145 rows, 1957 cols, 5930 nonzeros  0s
#
# Solving MIP model with:
#    2145 rows
#    1957 cols (514 binary, 0 integer, 0 implied int., 1443 continuous, 0 domain fixed)
#    5930 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -3378.564473       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1252.99077      1226.85868         2.13%        0      0      0      1154     0.2s
#  C       0       0         0   0.00%   1252.99077      1227.605904        2.07%      105     32      0      1188     0.3s
#  H       0       0         0   0.00%   1252.99077      1252.99077         0.00%      105     34      0      1190     0.3s
#          1       0         1 100.00%   1252.99077      1252.99077         0.00%      105     34      0      1190     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      1252.99077018
#   Dual bound        1252.99077018
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.75111554496
#   Solution status   feasible
#                     1252.99077018 (objective)
#                     0 (bound viol.)
#                     6.2172489379e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.33 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1190 (total)
#                     0 (strong br.)
#                     36 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-05 00:00:00 2024-02-11 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15045 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [7e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4291 rows, 3203 cols, 10696 nonzeros  0s
# 2275 rows, 2273 cols, 6974 nonzeros  0s
# 1796 rows, 1413 cols, 4364 nonzeros  0s
# 1367 rows, 1411 cols, 3504 nonzeros  0s
#
# Solving MIP model with:
#    1367 rows
#    1411 cols (257 binary, 0 integer, 0 implied int., 1154 continuous, 0 domain fixed)
#    3504 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             4801.606048        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   5920.844376     5257.468804       12.62%        0      0      0      1067     0.1s
#  L       0       0         0   0.00%   5920.844376     5920.844376        0.00%      439    182      0      1239     0.3s
#          1       0         1 100.00%   5920.844376     5920.844376        0.00%      439    182      0      1306     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      5920.84437607
#   Dual bound        5920.84437607
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.152962371213
#   Solution status   feasible
#                     5920.84437607 (objective)
#                     0 (bound viol.)
#                     3.45545814184e-12 (int. viol.)
#                     0 (row viol.)
#   Timing            0.29 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1306 (total)
#                     0 (strong br.)
#                     172 (separation)
#                     67 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31649 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-02, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-17, 7e+01]
# Presolving model
# 9471 rows, 3639 cols, 17181 nonzeros  0s
# 2942 rows, 2721 cols, 8948 nonzeros  0s
# 2045 rows, 1847 cols, 5530 nonzeros  0s
# 2020 rows, 1847 cols, 5480 nonzeros  0s
#
# Solving MIP model with:
#    2020 rows
#    1847 cols (465 binary, 0 integer, 0 implied int., 1382 continuous, 0 domain fixed)
#    5480 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1168.016971       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   446.8376749     433.3024213        3.12%        0      0      0      1190     0.2s
#  H       0       0         0   0.00%   446.8376749     446.8376749        0.00%      181     57      0      1249     0.4s
#          1       0         1 100.00%   446.8376749     446.8376749        0.00%      181     57      0      1249     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      446.837674855
#   Dual bound        446.837674855
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.69944126698
#   Solution status   feasible
#                     446.837674855 (objective)
#                     0 (bound viol.)
#                     2.30926389122e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.35 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1249 (total)
#                     0 (strong br.)
#                     59 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 10 |values| in [8.88178e-16, 8.88178e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31668 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [1e-01, 8e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [3e-17, 7e+01]
# Presolving model
# 9490 rows, 3677 cols, 17347 nonzeros  0s
# 2986 rows, 2746 cols, 9086 nonzeros  0s
# 2097 rows, 1883 cols, 5715 nonzeros  0s
# 2067 rows, 1883 cols, 5655 nonzeros  0s
#
# Solving MIP model with:
#    2067 rows
#    1883 cols (483 binary, 0 integer, 0 implied int., 1400 continuous, 0 domain fixed)
#    5655 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1710.037611       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   940.2017204     906.4020759        3.73%        0      0      0      1195     0.3s
#  H       0       0         0   0.00%   940.2017204     940.2017204        0.00%      196     63      0      1263     0.5s
#          1       0         1 100.00%   940.2017204     940.2017204        0.00%      196     63      0      1263     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      940.201720373
#   Dual bound        940.201720373
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.3657315948
#   Solution status   feasible
#                     940.201720373 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.52 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1263 (total)
#                     0 (strong br.)
#                     68 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-02-12 00:00:00 2024-02-18 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15063 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [1e+01, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4309 rows, 3239 cols, 10786 nonzeros  0s
# 2291 rows, 2291 cols, 6988 nonzeros  0s
# 1832 rows, 1468 cols, 4490 nonzeros  0s
# 1419 rows, 1465 cols, 3662 nonzeros  0s
#
# Solving MIP model with:
#    1419 rows
#    1465 cols (275 binary, 0 integer, 0 implied int., 1190 continuous, 0 domain fixed)
#    3662 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# ...
#                     18916.2380518 (objective)
#                     0 (bound viol.)
#                     1.15463194561e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.30 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1279 (total)
#                     0 (strong br.)
#                     72 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-16 00:00:00 2024-12-22 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 14998 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-03, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4244 rows, 3109 cols, 10461 nonzeros  0s
# 2228 rows, 2226 cols, 6927 nonzeros  0s
# 1726 rows, 1326 cols, 4195 nonzeros  0s
# 1284 rows, 1324 cols, 3309 nonzeros  0s
#
# Solving MIP model with:
#    1284 rows
#    1324 cols (238 binary, 0 integer, 0 implied int., 1086 continuous, 0 domain fixed)
#    3309 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             2293.350676        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3044.20038      2553.528225       19.22%        0      0      0      1006     0.1s
#  L       0       0         0   0.00%   3044.20038      3044.20038         0.00%      488    209      0      1158     0.2s
#          1       0         1 100.00%   3044.20038      3044.20038         0.00%      488    209      0      1218     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      3044.20038002
#   Dual bound        3044.20038002
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.334456398393
#   Solution status   feasible
#                     3044.20038002 (objective)
#                     0 (bound viol.)
#                     4.4408920985e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.24 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1218 (total)
#                     0 (strong br.)
#                     152 (separation)
#                     60 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [1.11378e-13, 1.11378e-13] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31543 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [2e-02, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 8e+01]
# Presolving model
# 9365 rows, 3521 cols, 16749 nonzeros  0s
# 2845 rows, 2637 cols, 8760 nonzeros  0s
# 1915 rows, 1725 cols, 5195 nonzeros  0s
# 1893 rows, 1725 cols, 5151 nonzeros  0s
#
# Solving MIP model with:
#    1893 rows
#    1725 cols (430 binary, 0 integer, 0 implied int., 1295 continuous, 0 domain fixed)
#    5151 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -703.8614504       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   222.5445701     209.4777658        6.24%        0      0      0      1170     0.2s
#  C       0       0         0   0.00%   222.5445701     210.2245277        5.86%      148     40      0      1211     0.3s
#  H       0       0         0   0.00%   222.5445701     222.5445701        0.00%      148     40      0      1211     0.3s
#          1       0         1 100.00%   222.5445701     222.5445701        0.00%      148     40      0      1211     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      222.544570145
#   Dual bound        222.544570145
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.87939981625
#   Solution status   feasible
#                     222.544570145 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.27 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1211 (total)
#                     0 (strong br.)
#                     41 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 10 |values| in [8.88178e-16, 8.88178e-16] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31552 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [5e-02, 3e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 8e+01]
# Presolving model
# 9374 rows, 3539 cols, 16827 nonzeros  0s
# 2878 rows, 2661 cols, 8850 nonzeros  0s
# 1976 rows, 1778 cols, 5402 nonzeros  0s
# 1954 rows, 1778 cols, 5358 nonzeros  0s
#
# Solving MIP model with:
#    1954 rows
#    1778 cols (455 binary, 0 integer, 0 implied int., 1323 continuous, 0 domain fixed)
#    5358 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -800.4836216       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   318.2995119     314.3921649        1.24%        0      0      0      1171     0.2s
#  H       0       0         0   0.00%   318.2995119     318.2995119        0.00%      151     37      0      1208     0.3s
#          1       0         1 100.00%   318.2995119     318.2995119        0.00%      151     37      0      1208     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      318.299511893
#   Dual bound        318.299511893
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.0698619321
#   Solution status   feasible
#                     318.299511893 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.27 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1208 (total)
#                     0 (strong br.)
#                     37 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2024-12-23 00:00:00 2024-12-29 23:45:00
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 7396 rows; 4033 cols; 15006 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [2e+00, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-02, 1e+02]
# Presolving model
# 4252 rows, 3125 cols, 10501 nonzeros  0s
# 2236 rows, 2234 cols, 6935 nonzeros  0s
# 1716 rows, 1295 cols, 4087 nonzeros  0s
# 1246 rows, 1292 cols, 3145 nonzeros  0s
#
# Solving MIP model with:
#    1246 rows
#    1292 cols (218 binary, 0 integer, 0 implied int., 1074 continuous, 0 domain fixed)
#    3145 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             2268.174258        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2939.813546     2482.705947       18.41%        0      0      0      1073     0.1s
#  L       0       0         0   0.00%   2939.813546     2939.813546        0.00%      646    294      0      1238     0.2s
#          1       0         1 100.00%   2939.813546     2939.813546        0.00%      646    294      0      1321     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      2939.81354575
#   Dual bound        2939.81354575
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.460870738489
#   Solution status   feasible
#                     2939.81354575 (objective)
#                     0 (bound viol.)
#                     6.2172489379e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.22 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1321 (total)
#                     0 (strong br.)
#                     165 (separation)
#                     83 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# MIP  has 12772 rows; 8065 cols; 31577 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [3e-01, 4e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 9e+01]
# Presolving model
# 9399 rows, 3573 cols, 16973 nonzeros  0s
# 2910 rows, 2684 cols, 8939 nonzeros  0s
# 1951 rows, 1738 cols, 5231 nonzeros  0s
# 1927 rows, 1738 cols, 5183 nonzeros  0s
#
# Solving MIP model with:
#    1927 rows
#    1738 cols (433 binary, 0 integer, 0 implied int., 1305 continuous, 0 domain fixed)
#    5183 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -792.3829933       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   148.822679      145.3120791        2.42%        0      0      0      1174     0.2s
#  H       0       0         0   0.00%   148.822679      148.822679         0.00%      141     34      0      1208     0.3s
#          1       0         1 100.00%   148.822679      148.822679         0.00%      141     34      0      1208     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      148.822679006
#   Dual bound        148.822679006
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      3.5268373632
#   Solution status   feasible
#                     148.822679006 (objective)
#                     0 (bound viol.)
#                     1.15463194561e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1208 (total)
#                     0 (strong br.)
#                     34 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.11.0 (git hash: 364c83a): Copyright (c) 2025 HiGHS under MIT licence terms
# WARNING: LP matrix packed vector contains 10 |values| in [8.88178e-16, 6.75016e-15] less than or equal to 1e-09: ignored
# MIP  has 12772 rows; 8065 cols; 31576 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix [1e-02, 6e+00]
#   Cost   [5e+00, 8e+01]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e-17, 9e+01]
# Presolving model
# 9398 rows, 3571 cols, 16964 nonzeros  0s
# 2905 rows, 2680 cols, 8928 nonzeros  0s
# 1942 rows, 1730 cols, 5204 nonzeros  0s
# 1917 rows, 1730 cols, 5154 nonzeros  0s
#
# Solving MIP model with:
#    1917 rows
#    1730 cols (430 binary, 0 integer, 0 implied int., 1300 continuous, 0 domain fixed)
#    5154 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; J => Feasibility jump;
#      H => Heuristic; L => Sub-MIP; P => Empty MIP; R => Randomized rounding; Z => ZI Round;
#      I => Shifting; S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1213.13884        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   342.5803891     341.0040145        0.46%        0      0      0      1205     0.2s
#  H       0       0         0   0.00%   342.5803891     342.5803891        0.00%      186     45      0      1250     0.3s
#          1       0         1 100.00%   342.5803891     342.5803891        0.00%      186     45      0      1250     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      342.5803891
#   Dual bound        342.5803891
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.44234412315
#   Solution status   feasible
#                     342.5803891 (objective)
#                     0 (bound viol.)
#                     2.44249065418e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.29 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1250 (total)
#                     0 (strong br.)
#                     45 (separation)
#                     0 (heuristics)
# Optimal solution found.

# %%
pd.set_option("display.max_columns", None)
results.head()
# Out:
#                      daa_price  ida_price  idc_price  pv_output  p_charge_daa  \
# 2024-01-01 00:00:00       0.10  18.908018   0.950255        0.0           0.0
# 2024-01-01 00:15:00       0.10   7.136068  -0.149025        0.0           0.0
# 2024-01-01 00:30:00       0.10   3.224757  -2.394920        0.0           0.0
# 2024-01-01 00:45:00       0.10   1.080706   3.409062        0.0           0.0
# 2024-01-01 01:00:00       0.01   5.907751  -0.344401        0.0           0.0
#
#                      p_discharge_daa  p_curtailed_daa  soc_daa  \
# 2024-01-01 00:00:00              0.0              0.0      0.0
# 2024-01-01 00:15:00              0.0              0.0      0.0
# 2024-01-01 00:30:00              0.0              0.0      0.0
# 2024-01-01 00:45:00              0.0              0.0      0.0
# 2024-01-01 01:00:00              0.0              0.0      0.0
#
#                      injection_power_daa  p_charge_ida  p_discharge_ida  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa  p_close_discharge_daa  \
# 2024-01-01 00:00:00                 0.0                    0.0
# 2024-01-01 00:15:00                 0.0                    0.0
# 2024-01-01 00:30:00                 0.0                    0.0
# 2024-01-01 00:45:00                 0.0                    0.0
# 2024-01-01 01:00:00                 0.0                    0.0
#
#                      p_curtailed_ida  p_close_curtailed_daa  p_charge_daa_ida  \
# 2024-01-01 00:00:00              0.0                    0.0               0.0
# 2024-01-01 00:15:00              0.0                    0.0               0.0
# 2024-01-01 00:30:00              0.0                    0.0               0.0
# 2024-01-01 00:45:00              0.0                    0.0               0.0
# 2024-01-01 01:00:00              0.0                    0.0               0.0
#
#                      p_discharge_daa_ida  p_curtailed_daa_ida  soc_ida  \
# 2024-01-01 00:00:00                  0.0                  0.0      0.0
# 2024-01-01 00:15:00                  0.0                  0.0      0.0
# 2024-01-01 00:30:00                  0.0                  0.0      0.0
# 2024-01-01 00:45:00                  0.0                  0.0      0.0
# 2024-01-01 01:00:00                  0.0                  0.0      0.0
#
#                      injection_power_ida  p_charge_idc  p_discharge_idc  \
# 2024-01-01 00:00:00                  0.0           0.0              0.0
# 2024-01-01 00:15:00                  0.0           0.0              0.0
# 2024-01-01 00:30:00                  0.0           0.0              0.0
# 2024-01-01 00:45:00                  0.0           0.0              0.0
# 2024-01-01 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa_ida  p_close_discharge_daa_ida  \
# 2024-01-01 00:00:00                     0.0                        0.0
# 2024-01-01 00:15:00                     0.0                        0.0
# 2024-01-01 00:30:00                     0.0                        0.0
# 2024-01-01 00:45:00                     0.0                        0.0
# 2024-01-01 01:00:00                     0.0                        0.0
#
#                      p_curtailed_idc  p_close_curtailed_daa_ida  \
# 2024-01-01 00:00:00              0.0                        0.0
# 2024-01-01 00:15:00              0.0                        0.0
# 2024-01-01 00:30:00              0.0                        0.0
# 2024-01-01 00:45:00              0.0                        0.0
# 2024-01-01 01:00:00              0.0                        0.0
#
#                      p_charge_daa_ida_idc  p_discharge_daa_ida_idc  \
# 2024-01-01 00:00:00                   0.0                      0.0
# 2024-01-01 00:15:00                   0.0                      0.0
# 2024-01-01 00:30:00                   0.0                      0.0
# 2024-01-01 00:45:00                   0.0                      0.0
# 2024-01-01 01:00:00                   0.0                      0.0
#
#                      p_curtailed_daa_ida_idc  soc_idc  injection_power_idc
# 2024-01-01 00:00:00                      0.0      0.0                  0.0
# 2024-01-01 00:15:00                      0.0      0.0                  0.0
# 2024-01-01 00:30:00                      0.0      0.0                  0.0
# 2024-01-01 00:45:00                      0.0      0.0                  0.0
# 2024-01-01 01:00:00                      0.0      0.0                  0.0

# %% [markdown]
# ### Plot the results

# %%
# Plotting the results
# Set timerange for plotting
plot_start = pd.to_datetime('2024-06-21 00:00:00')
plot_end = pd.to_datetime('2024-06-28 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(21, 1, figsize=(12,36))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.ida_price, label='IDA [€/MWh]', color='cyan')
ax[3].plot(results_slice.idc_price, label='IDC [€/MWh]', color='magenta')
ax[4].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[4].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[5].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[6].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[7].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')

ax[8].plot(results_slice.p_close_charge_daa, label='Closed Charge Power DAA [MW]', color='yellow')
ax[8].plot(-results_slice.p_close_discharge_daa, label='Closed Discharge Power DAA [MW]', color='goldenrod')
ax[9].plot(results_slice.p_charge_ida, label='Charge Power IDA [MW]', color='lightblue')
ax[9].plot(-results_slice.p_discharge_ida, label='Discharge Power IDA [MW]', color='blue')
ax[10].plot(results_slice.p_close_curtailed_daa, label='Closed Curtailed Power DAA [MW]', color='plum')
ax[11].plot(results_slice.p_curtailed_daa_ida, label='Curtailed Power DAA IDA [MW]', color='lightcoral')
ax[12].plot(results_slice.soc_ida, label='SoC [MWh] IDA', color='lime')
ax[13].plot(results_slice.injection_power_ida, label='Injection Power DAA IDA [MW]', color='plum')

ax[14].plot(results_slice.p_close_charge_daa_ida, label='Closed Charge Power DAA IDA [MW]', color='lightgreen')
ax[14].plot(-results_slice.p_close_discharge_daa_ida, label='Closed Discharge Power DAA IDA [MW]', color='green')
ax[15].plot(results_slice.p_charge_idc, label='Charge Power IDC [MW]', color='#bfcf7c')
ax[15].plot(-results_slice.p_discharge_idc, label='Discharge Power IDC [MW]', color='olive') #, ls='', marker='_')
ax[16].plot(results_slice.p_close_curtailed_daa_ida, label='Closed Curtailed Power DAA IDA [MW]', color='plum')
ax[17].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='lightcoral')
ax[18].plot(results_slice.soc_idc, label='SoC [MWh] IDC', color='lime')
ax[19].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='plum')
ax[20].plot(results_slice.pv_output, label='PV Power [MW]', color='orange')
ax[20].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='red')
ax[20].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='darkred')

ax[20].set_xlabel('Time')

for i in range(21):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results.png')

# %% [markdown]
# ### Calculate energies and profits

# %%
##### Calculate energies
pv_production = results.pv_output.sum() * 15 / 60  # Convert from MW to MWh
injected_energy_daa = results.injection_power_daa.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_daa = results.p_curtailed_daa.sum() * 15 / 60 # Convert from MW to MWh
discharge_energy_daa = results.p_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa = results.p_charge_daa.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_ida = results.injection_power_ida.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_ida = results.p_curtailed_daa_ida.sum() * 15 / 60 # Convert from MW to MWh
closed_curtailed_daa_energy = results.p_close_curtailed_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_ida = results.p_discharge_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_ida = results.p_charge_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_energy = results.p_close_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_energy = results.p_close_charge_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida = results.p_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida = results.p_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_idc = results.injection_power_idc.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_idc = results.p_curtailed_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_curtailed_daa_ida_energy = results.p_close_curtailed_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_idc = results.p_discharge_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_idc = results.p_charge_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_ida_energy = results.p_close_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_ida_energy = results.p_close_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida_idc = results.p_discharge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida_idc = results.p_charge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh

# Print calculated energies
print('Annual Energies:')
print('==========================================')
print('PV')
print('----------')
print('PV Production:', f'{pv_production:.2f} MWh')
print('------------------------------------------')
print('DAA Market')
print('----------')
print('Injected Energy DAA:', f'{injected_energy_daa:.2f} MWh')
print('Curtailed Energy DAA:', f'{curtailed_energy_daa:.2f} MWh')
print('Charge Energy DAA:', f'{charge_energy_daa:.2f} MWh')
print('Discharge Energy DAA:', f'{discharge_energy_daa:.2f} MWh')
print('------------------------------------------')
print('IDA Market')
print('----------')
print('Injected Energy IDA:', f'{injected_energy_ida:.2f} MWh')
print('Curtailed Energy IDA:', f'{curtailed_energy_ida:.2f} MWh')
print('Closed Curtailed Energy DAA:', f'{closed_curtailed_daa_energy:.2f} MWh')
print('Charge Energy IDA:', f'{charge_energy_ida:.2f} MWh')
print('Discharge Energy IDA:', f'{discharge_energy_ida:.2f} MWh')
print('Closed Charge Energy DAA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA:', f'{charge_energy_daa_ida:.2f} MWh')
print('Physical Discharge Energy DAA IDA:', f'{discharge_energy_daa_ida:.2f} MWh')
print('------------------------------------------')
print('IDC Market')
print('----------')
print('Injected Energy IDC:', f'{injected_energy_idc:.2f} MWh')
print('Curtailed Energy IDC:', f'{curtailed_energy_idc:.2f} MWh')
print('Closed Curtailed Energy DAA IDA:', f'{closed_curtailed_daa_ida_energy:.2f} MWh')
print('Charge Energy IDC:', f'{charge_energy_idc:.2f} MWh')
print('Discharge Energy IDC:', f'{discharge_energy_idc:.2f} MWh')
print('Closed Charge Energy DAA IDA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA IDA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA IDC:', f'{charge_energy_daa_ida_idc:.2f} MWh')
print('Physical Discharge Energy DAA IDA IDC:', f'{discharge_energy_daa_ida_idc:.2f} MWh')
print('------------------------------------------')

##### Calculate profits
# Calculate annual profit from PV Output multiplied with DAA prices as reference
results['pv_direct_market_profit_reference'] = results.daa_price * results.pv_output * 15 / 60
# Only sum up profit at positive market prices, because plant will be curtailed at other times
condition_daa_positive = results.daa_price >= 0
annual_pv_production_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'pv_output'].sum() * 15 / 60
annual_pv_direct_market_profit_reference = results.loc[condition_daa_positive, 'pv_direct_market_profit_reference'].sum()

# Calculate annual profit on DAA market
results['injected_power_direct_market_profit_daa'] = results.daa_price * results.injection_power_daa * 15 / 60
annual_injected_energy_direct_market_profit_daa = results.injected_power_direct_market_profit_daa.sum()

# Calculate annual profit on IDA market
results['ida_market_profit'] = (results['p_discharge_ida'] - results['p_charge_ida'] 
                                + results['p_close_charge_daa'] - results['p_close_discharge_daa'] 
                                + results['p_close_curtailed_daa'] - results['p_curtailed_ida']) * results['ida_price']  / 4
annual_ida_market_profit = results['ida_market_profit'].sum()

# Calculate annual profit on IDC market
results['idc_market_profit'] = (results['p_discharge_idc'] - results['p_charge_idc'] 
                                + results['p_close_charge_daa_ida'] - results['p_close_discharge_daa_ida'] 
                                + results['p_close_curtailed_daa_ida'] - results['p_curtailed_idc']) * results['idc_price']  / 4
annual_idc_market_profit = results['idc_market_profit'].sum()

# Print annual profit values
print('Annual Direct Market Profits:')
print('----------------------------------------------------------------------------------------')
print('Annual PV Direct Market Profit (Reference):', f'{annual_pv_direct_market_profit_reference:.2f} €', '(excl. negative DAA price hours)')
print('Annual Injected Energy Direct Market Profit (DAA):', f'{annual_injected_energy_direct_market_profit_daa:.2f} €')
print('Annual IDA Market Profit:', f'{annual_ida_market_profit:.2f} €')
print('Annual IDC Market Profit:', f'{annual_idc_market_profit:.2f} €')
print('----------------------------------------------------------------------------------------')

# Calculate annual market bonus
annual_injected_energy_idc_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'injection_power_idc'].sum() * 15 / 60
market_bonus_injected_energy_idc = annual_injected_energy_idc_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_injected_energy_idc < 0:
    market_bonus_injected_energy_idc = 0
market_bonus_pv_production = annual_pv_production_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_pv_production < 0:
    market_bonus_pv_production = 0

print('Annual Market Boni:')
print('------------------------------------------------------------------')
print('Annual Market Bonus PV + BESS (IDC):', f'{market_bonus_injected_energy_idc:.2f} €', '(excl. negative DAA price hours)')
print('Annual Market Bonus PV only:', f'{market_bonus_pv_production:.2f} €', '(excl. negative DAA price hours)')
print('------------------------------------------------------------------')

# Calculate number of hours with negative DAA prices
number_of_hours_negative_daa_price = len(results[results.daa_price < 0])
print('Negative price hours:')
print('------------------------------------------------------------')
print('Number of hours with negative DAA prices:', number_of_hours_negative_daa_price * 15 / 60, 'hours')
print('------------------------------------------------------------')

# Final results
print('Final Results:')
print('------------------------------------------------------------')
print('Annual profit PV only (reference):', f'{market_bonus_pv_production + annual_pv_direct_market_profit_reference:.2f} €')
print('Annual profit PV + BESS (DAA IDA IDC):', f'{market_bonus_injected_energy_idc 
                                                   + annual_injected_energy_direct_market_profit_daa 
                                                   + annual_ida_market_profit + annual_idc_market_profit:.2f} €')
print('Annual BESS profit (DAA IDA IDC):', f'{annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production :.2f} €')
print('Specific Annual BESS profit (DAA IDA IDC):', f'{(annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production) / storage_capacity:.2f} €/MWh')
# Out:
# Annual Energies:
# ==========================================
# PV
# ----------
# PV Production: 15899.99 MWh
# ------------------------------------------
# DAA Market
# ----------
# Injected Energy DAA: 13511.81 MWh
# Curtailed Energy DAA: 1946.61 MWh
# Charge Energy DAA: 4528.98 MWh
# Discharge Energy DAA: 4087.40 MWh
# ------------------------------------------
# IDA Market
# ----------
# Injected Energy IDA: 13803.14 MWh
# Curtailed Energy IDA: 1646.48 MWh
# Closed Curtailed Energy DAA: 768.24 MWh
# Charge Energy IDA: 1425.48 MWh
# Discharge Energy IDA: 2163.38 MWh
# Closed Charge Energy DAA: 1248.64 MWh
# Closed Discharge Energy DAA: 1949.21 MWh
# Physical Charge Energy DAA IDA: 4619.12 MWh
# Physical Discharge Energy DAA IDA: 4168.76 MWh
# ------------------------------------------
# IDC Market
# ----------
# Injected Energy IDC: 13786.92 MWh
# Curtailed Energy IDC: 1665.16 MWh
# Closed Curtailed Energy DAA IDA: 592.15 MWh
# Charge Energy IDC: 1223.39 MWh
# Discharge Energy IDC: 1926.43 MWh
# Closed Charge Energy DAA IDA: 1248.64 MWh
# Closed Discharge Energy DAA IDA: 1949.21 MWh
# Physical Charge Energy DAA IDA IDC: 4593.88 MWh
# Physical Discharge Energy DAA IDA IDC: 4145.98 MWh
# ------------------------------------------
# Annual Direct Market Profits:
# ----------------------------------------------------------------------------------------
# Annual PV Direct Market Profit (Reference): 784365.24 € (excl. negative DAA price hours)
# Annual Injected Energy Direct Market Profit (DAA): 1149528.87 €
# Annual IDA Market Profit: 159428.79 €
# Annual IDC Market Profit: 162092.84 €
# ----------------------------------------------------------------------------------------
# Annual Market Boni:
# ------------------------------------------------------------------
# Annual Market Bonus PV + BESS (IDC): 160963.92 € (excl. negative DAA price hours)
# Annual Market Bonus PV only: 163142.10 € (excl. negative DAA price hours)
# ------------------------------------------------------------------
# Negative price hours:
# ------------------------------------------------------------
# Number of hours with negative DAA prices: 457.0 hours
# ------------------------------------------------------------
# Final Results:
# ------------------------------------------------------------
# Annual profit PV only (reference): 947507.34 €
# Annual profit PV + BESS (DAA IDA IDC): 1632014.42 €
# Annual BESS profit (DAA IDA IDC): 684507.07 €
# Specific Annual BESS profit (DAA IDA IDC): 44739.02 €/MWh

# %%
# Plotting the results for abstract
# Set timerange for plotting
plot_start = pd.to_datetime('2024-06-15 00:00:00')
plot_end = pd.to_datetime('2024-06-21 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(7, 1, figsize=(12,12))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[3].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[4].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[5].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[6].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')
ax[6].set_xlabel('Time')

for i in range(7):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results_abstract.jpg')

# %% [markdown]
# ### Export results to .csv

# %%
# results.to_csv('results.csv')
