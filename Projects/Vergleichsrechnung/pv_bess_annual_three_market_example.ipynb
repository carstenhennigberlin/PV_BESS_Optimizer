# %% [markdown]
# # PV-BESS optimizer

# %% [markdown]
# ### Example Jupyter notebook for scheduling a PV-BESS system using the Pyomo optimization framework.
# This jupyter notebook generates schedules for the marketing of the energy provided by a combination of a PV plant and a battery storage system (BESS) and calculates the corresponding profits on the day-ahead and intraday markets (DAA, IDA and IDC).
#
# This notebook uses historic market price data and PV production profiles and therefore represents a backtest following the principle of a perfect foresight.
#
# The schedules are generated by functions of the scheduler_three_market.py module, which make use of the Pyomo modelling framework for mathematical opimization. Each function includes an objective and several constraints, which can be reviewed in the module.

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries
from scheduler_three_market import get_daa_schedule, get_ida_schedule, get_idc_schedule # Import the scheduler module which contains the Pyomo model and optimization logic
import matplotlib.pyplot as plt  # Import matplotlib for plotting results
import pandas as pd  # Import pandas for data handling

# %% [markdown]
# ### Set the input parameters

# %%
# BESS (Battery Energy Storage System) parameters
p_limit = 15.0  # Maximum injection power limit in MW
storage_capacity = 15.0 # Storage capacity in MWh
p_charge_max = 7.5   # Maximum charge power in MW
p_discharge_max = 7.5 # Maximum discharge power MW
efficiency = 0.934 # Charge/discharge efficiency of the BESS
start_soc = 0.0  # Initial state of charge
end_soc = 0.0  # End state of charge, can be adjusted as needed
number_of_cycles = 1 * 7  # Number of cycles for the period (week)

# General parameters
number_of_weeks = 52  # Number of weeks in the year
year = '2025'  # Year for which the data is being processed

# Commercial parameters
applicable_value = 50.0 # Applicable value for the plant from EEG or tender ("anzulegneder Wert") in €/MWh. This is the value that the plant operator receives for the energy fed into the grid..

# %% [markdown]
# ### Year data dictionary

# %%
year_data = {
             '2024': [46.24,'./data/2024/DA/2024_daa.csv',
                              './data/2024/IDA/2024_ida.csv' ,
                              './data/2024/ID1/2024_id1.csv',
                              './data/2024/PV/2024_pv.csv',
                              '2024-01-01 00:00:00'], 
             '2025': [45.08,'./data/2025/DA/2025_daa.csv',
                            './data/2025/IDA/2025_ida.csv' ,
                            './data/2025/ID1/2025_id1.csv',
                            './data/2025/PV/2025_pv.csv',
                            '2024-12-30 00:00:00']
            }
# Extract the market value (capture price) for the specified year
market_value = year_data[year][0]

# %% [markdown]
# ### Load DAA, IDA and IDC data from files

# %%
daa = pd.read_csv(year_data[year][1], index_col = 0)
daa.index = pd.to_datetime(daa.index)

ida = pd.read_csv(year_data[year][2], index_col = 0)
ida.index = pd.to_datetime(ida.index)

idc = pd.read_csv(year_data[year][3], index_col = 0)
idc.index = pd.to_datetime(idc.index)

# %% [markdown]
# ### Load PV load profile from .csv:

# %%
pv = pd.read_csv(year_data[year][4], index_col = 0)
pv.index = pd.to_datetime(pv.index)
pv.PV = [max(0, v) for v in pv.PV] # Set negative values to zero

# %%
pv.PV.plot()
# Out:
# <Axes: xlabel='datetime'>

# %% [markdown]
# ### Get the optimized schedule
# This is done for weekly time slices. The results for the single weeks are then concatenated into a result dataframe.

# %%
start = pd.to_datetime(year_data[year][5])
end = start + pd.DateOffset(days=7) - pd.DateOffset(minutes=15)  # Set end to the next week minus 15 minutes
result_list = []

for i in range(1, number_of_weeks + 1):
    print('start/end', start, end)
    pv_vector = pv.PV[start:end].to_list()
    daa_price_vector = daa.DAA[start:end].to_list()
    ida_price_vector = ida.IDA[start:end].to_list()
    idc_price_vector = idc.ID1[start:end].to_list()

    # Ensure the vectors are not empty
    if not pv_vector or not daa_price_vector or not ida_price_vector or not idc_price_vector:
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors cannot be empty.")

    # Ensure the vectors are of the same length
    if len(pv_vector) != len(daa_price_vector) or len(pv_vector) != len(ida_price_vector) or len(pv_vector) != len(idc_price_vector):
        raise ValueError("PV output, DAA price, IDA price, and IDC price vectors must have the same length.")

    pv_output, daa_price, p_charge_daa, p_discharge_daa, soc_daa, p_curtailed_daa, injection_power_daa = get_daa_schedule(pv_vector,
                                                                                                  daa_price_vector, 
                                                                                                  p_limit, 
                                                                                                  storage_capacity, 
                                                                                                  p_charge_max, 
                                                                                                  p_discharge_max, 
                                                                                                  number_of_cycles, 
                                                                                                  efficiency, 
                                                                                                  start_soc, 
                                                                                                  end_soc)

    ida_price, p_charge_ida, p_discharge_ida, p_close_charge_daa, p_close_discharge_daa, p_curtailed_ida, \
        p_close_curtailed_daa, p_curtailed_daa_ida ,p_charge_daa_ida, p_discharge_daa_ida, soc_ida, injection_power_ida = get_ida_schedule(
                                                                                                                        ida_price_vector, 
                                                                                                                        pv_output,
                                                                                                                        p_limit, 
                                                                                                                        storage_capacity, 
                                                                                                                        p_charge_max, 
                                                                                                                        p_discharge_max,
                                                                                                                        p_charge_daa,
                                                                                                                        p_discharge_daa,
                                                                                                                        p_curtailed_daa,
                                                                                                                        number_of_cycles, 
                                                                                                                        efficiency, 
                                                                                                                        start_soc, 
                                                                                                                        end_soc)
    
    idc_price, p_charge_idc, p_discharge_idc, p_close_charge_daa_ida, p_close_discharge_daa_ida, p_curtailed_idc, \
        p_close_curtailed_daa_ida, p_curtailed_daa_ida_idc, p_charge_daa_ida_idc, p_discharge_daa_ida_idc, soc_idc, injection_power_idc = get_idc_schedule(
                                                                                                                                idc_price_vector,
                                                                                                                                pv_output, 
                                                                                                                                p_limit, 
                                                                                                                                storage_capacity, 
                                                                                                                                p_charge_max, 
                                                                                                                                p_discharge_max,
                                                                                                                                p_charge_daa_ida,
                                                                                                                                p_discharge_daa_ida,
                                                                                                                                p_curtailed_daa_ida,
                                                                                                                                number_of_cycles, 
                                                                                                                                efficiency, 
                                                                                                                                start_soc, 
                                                                                                                                end_soc
                                                                                                                            )

    # Create a DataFrame to store the results for the current week
    result = pd.DataFrame({# prices and PV output
                           'daa_price': daa_price,
                           'ida_price': ida_price,
                           'idc_price': idc_price,
                           'pv_output': pv_output,
                            # DAA results
                           'p_charge_daa': p_charge_daa,
                           'p_discharge_daa': p_discharge_daa,
                           'p_curtailed_daa': p_curtailed_daa,
                           'soc_daa': soc_daa,
                           'injection_power_daa': injection_power_daa,
                           # IDA results
                           'p_charge_ida': p_charge_ida,
                           'p_discharge_ida': p_discharge_ida,
                           'p_close_charge_daa': p_close_charge_daa,
                           'p_close_discharge_daa': p_close_discharge_daa,
                           'p_curtailed_ida': p_curtailed_ida,
                           'p_close_curtailed_daa': p_close_curtailed_daa,
                           'p_charge_daa_ida': p_charge_daa_ida,
                           'p_discharge_daa_ida': p_discharge_daa_ida,
                           'p_curtailed_daa_ida': p_curtailed_daa_ida,
                           'soc_ida': soc_ida,
                           'injection_power_ida': injection_power_ida,
                           # IDC results
                           'p_charge_idc': p_charge_idc,
                           'p_discharge_idc': p_discharge_idc,
                           'p_close_charge_daa_ida': p_close_charge_daa_ida,
                           'p_close_discharge_daa_ida': p_close_discharge_daa_ida,
                           'p_curtailed_idc': p_curtailed_idc,
                           'p_close_curtailed_daa_ida': p_close_curtailed_daa_ida,
                           'p_charge_daa_ida_idc': p_charge_daa_ida_idc,
                           'p_discharge_daa_ida_idc': p_discharge_daa_ida_idc,
                           'p_curtailed_daa_ida_idc': p_curtailed_daa_ida_idc,
                           'soc_idc': soc_idc,
                           'injection_power_idc': injection_power_idc
                          }
                         )
    
    result.index = pd.date_range(start=start, end=end, freq='15min')
    
    result_list.append(result)

    start = start + pd.DateOffset(days=7) # Set start and end to the next week
    end = end + pd.DateOffset(days=7)
    
results = pd.concat(result_list)
# Out:
# start/end 2024-12-30 00:00:00 2025-01-05 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14999 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [3e-03, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4245 rows, 2745 cols, 9551 nonzeros  0s
# 2287 rows, 2285 cols, 7073 nonzeros  0s
# 1783 rows, 1384 cols, 4337 nonzeros  0s
# 1351 rows, 1382 cols, 3471 nonzeros  0s
# Presolve reductions: rows 1351(-6045); columns 1382(-2651); nonzeros 3471(-11528)
#
# Solving MIP model with:
#    1351 rows
#    1382 cols (267 binary, 0 integer, 0 implied int., 1115 continuous, 0 domain fixed)
#    3471 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             2677.483149        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   3562.514089     2825.760895       26.07%        0      0      0      1023     0.1s
#  L       0       0         0   0.00%   3562.514089     3562.514089        0.00%      782    157      0      1213     0.3s
#          1       0         1 100.00%   3562.514089     3562.514089        0.00%      782    157      0      1267     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      3562.51408935
#   Dual bound        3562.51408935
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.359718842199
#   Solution status   feasible
#                     3562.51408935 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.31
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1267
#                     0 (strong br.)
#                     190 (separation)
#                     54 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 1 |values| in [1.63064e-16, 1.63064e-16] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31527 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [3e-05, 6e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-17, 8e+01]
# WARNING: Problem has some excessively small costs
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9143 rows, 3075 cols, 15160 nonzeros  0s
# 2807 rows, 2617 cols, 8640 nonzeros  0s
# 1846 rows, 1667 cols, 4919 nonzeros  0s
# 1823 rows, 1667 cols, 4873 nonzeros  0s
# Presolve reductions: rows 1823(-10949); columns 1667(-6398); nonzeros 4873(-26654)
#
# Solving MIP model with:
#    1823 rows
#    1667 cols (403 binary, 0 integer, 0 implied int., 1264 continuous, 0 domain fixed)
#    4873 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -911.6810547       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   446.3709136     437.3550853        2.06%        0      0      0      1186     0.2s
#  H       0       0         0   0.00%   446.3709136     446.3709136        0.00%      245     66      0      1255     0.3s
#          1       0         1 100.00%   446.3709136     446.3709136        0.00%      245     66      0      1255     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      446.370913561
#   Dual bound        446.370913561
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.97883221389
#   Solution status   feasible
#                     446.370913561 (objective)
#                     0 (bound viol.)
#                     5.29947791997e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.34
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1255
#                     0 (strong br.)
#                     69 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 5 |values| in [1.63064e-16, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31538 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [8e-05, 2e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-17, 8e+01]
# WARNING: Problem has some excessively small costs
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9153 rows, 3095 cols, 15251 nonzeros  0s
# 2838 rows, 2637 cols, 8733 nonzeros  0s
# 1907 rows, 1717 cols, 5132 nonzeros  0s
# 1882 rows, 1717 cols, 5082 nonzeros  0s
# Presolve reductions: rows 1882(-10890); columns 1717(-6348); nonzeros 5082(-26456)
#
# Solving MIP model with:
#    1882 rows
#    1717 cols (428 binary, 0 integer, 0 implied int., 1289 continuous, 0 domain fixed)
#    5082 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -980.930794        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   2456.205966     2403.839417        2.18%        0      0      0      1166     0.1s
#  C       0       0         0   0.00%   2456.205966     2404.3955          2.15%      238     62      0      1229     0.2s
#  H       0       0         0   0.00%   2456.205966     2456.205966        0.00%      238     62      0      1229     0.2s
#          1       0         1 100.00%   2456.205966     2456.205966        0.00%      237     62      0      1229     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      2456.20596603
#   Dual bound        2456.20596603
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.24205937232
#   Solution status   feasible
#                     2456.20596603 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.23
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1229
#                     0 (strong br.)
#                     63 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-01-06 00:00:00 2025-01-12 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15002 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [1e+00, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4248 rows, 2687 cols, 9406 nonzeros  0s
# 2232 rows, 2230 cols, 6931 nonzeros  0s
# 1705 rows, 1282 cols, 4052 nonzeros  0s
# 1232 rows, 1278 cols, 3105 nonzeros  0s
# Presolve reductions: rows 1232(-6164); columns 1278(-2755); nonzeros 3105(-11897)
#
# Solving MIP model with:
#    1232 rows
#    1278 cols (214 binary, 0 integer, 0 implied int., 1064 continuous, 0 domain fixed)
#    3105 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             6082.04227         Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   8063.039953     7015.003404       14.94%        0      0      0       937     0.1s
#  L       0       0         0   0.00%   8063.039953     8063.039953        0.00%      416    162      0      1056     0.2s
#          1       0         1 100.00%   8063.039953     8063.039953        0.00%      416    162      0      1099     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      8063.03995321
#   Dual bound        8063.03995321
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.150227689804
#   Solution status   feasible
#                     8063.03995321 (objective)
#                     0 (bound viol.)
#                     2.10942374679e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.20
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1099
#                     0 (strong br.)
#                     119 (separation)
#                     43 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 5 |values| in [1.62023e-18, 2.32276e-14] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31517 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [7e-02, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [4e-19, 5e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9130 rows, 3043 cols, 15002 nonzeros  0s
# 2763 rows, 2583 cols, 8504 nonzeros  0s
# 1749 rows, 1603 cols, 4648 nonzeros  0s
# 1723 rows, 1603 cols, 4596 nonzeros  0s
# Presolve reductions: rows 1723(-11049); columns 1603(-6462); nonzeros 4596(-26921)
#
# Solving MIP model with:
#    1723 rows
#    1603 cols (363 binary, 0 integer, 0 implied int., 1240 continuous, 0 domain fixed)
#    4596 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2060.532056       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   343.8715235     335.9304815        2.36%        0      0      0      1056     0.1s
#  H       0       0         0   0.00%   343.8715235     343.8715235        0.00%       96     31      0      1088     0.2s
#          1       0         1 100.00%   343.8715235     343.8715235        0.00%       96     31      0      1088     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      343.871523477
#   Dual bound        343.871523477
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.07813100778
#   Solution status   feasible
#                     343.871523477 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.22
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1088
#                     0 (strong br.)
#                     32 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 12 |values| in [1.92593e-34, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31519 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [1e-03, 2e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [5e-35, 6e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9131 rows, 3045 cols, 15012 nonzeros  0s
# 2767 rows, 2586 cols, 8513 nonzeros  0s
# 1764 rows, 1614 cols, 4692 nonzeros  0s
# 1735 rows, 1614 cols, 4634 nonzeros  0s
# Presolve reductions: rows 1735(-11037); columns 1614(-6451); nonzeros 4634(-26885)
#
# Solving MIP model with:
#    1735 rows
#    1614 cols (369 binary, 0 integer, 0 implied int., 1245 continuous, 0 domain fixed)
#    4634 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4432.276908       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   972.4628335     606.3251659       60.39%        0      0      0      1100     0.1s
#  C       0       0         0   0.00%   972.4628335     840.4599556       15.71%      168     48      0      1152     0.2s
#  H       0       0         0   0.00%   972.4628335     972.4628335        0.00%      173     51      0      1155     0.2s
#          1       0         1 100.00%   972.4628335     972.4628335        0.00%      173     51      0      1155     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      972.46283349
#   Dual bound        972.46283349
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.555483415074
#   Solution status   feasible
#                     972.46283349 (objective)
#                     0 (bound viol.)
#                     2.45803377652e-13 (int. viol.)
#                     0 (row viol.)
#   Timing            0.25
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1155
#                     0 (strong br.)
#                     55 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-01-13 00:00:00 2025-01-19 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15010 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 9e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4256 rows, 2687 cols, 9406 nonzeros  0s
# 2240 rows, 2238 cols, 6939 nonzeros  0s
# 1716 rows, 1303 cols, 4099 nonzeros  0s
# 1255 rows, 1301 cols, 3175 nonzeros  0s
# Presolve reductions: rows 1255(-6141); columns 1301(-2732); nonzeros 3175(-11835)
#
# Solving MIP model with:
#    1255 rows
#    1301 cols (222 binary, 0 integer, 0 implied int., 1079 continuous, 0 domain fixed)
#    3175 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             9764.906699        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   13452.606985    11875.717459      13.28%        0      0      0       974     0.1s
#  L       0       0         0   0.00%   13452.606985    13452.606985       0.00%      319    135      0      1122     0.2s
#  T       0       0         0   0.00%   13452.606985    13452.606985       0.00%      319    135      0      1212     0.2s
#          1       0         1 100.00%   13452.606985    13452.606985       0.00%      319    135      0      1212     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      13452.606985
#   Dual bound        13452.606985
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.146306693684
#   Solution status   feasible
#                     13452.606985 (objective)
#                     0 (bound viol.)
#                     2.38697950294e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.24
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1212
#                     0 (strong br.)
#                     148 (separation)
#                     90 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 2 |values| in [6.63647e-15, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31543 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 1e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [6e-17, 6e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9145 rows, 3057 cols, 15073 nonzeros  0s
# 2795 rows, 2608 cols, 8580 nonzeros  0s
# 1813 rows, 1652 cols, 4836 nonzeros  0s
# 1783 rows, 1652 cols, 4776 nonzeros  0s
# Presolve reductions: rows 1783(-10989); columns 1652(-6413); nonzeros 4776(-26767)
#
# Solving MIP model with:
#    1783 rows
#    1652 cols (386 binary, 0 integer, 0 implied int., 1266 continuous, 0 domain fixed)
#    4776 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4272.955621       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   531.7768302     479.0147553       11.01%        0      0      0      1168     0.2s
#  H       0       0         0   0.00%   531.7768302     531.7768302        0.00%      204     51      0      1221     0.3s
#          1       0         1 100.00%   531.7768302     531.7768302        0.00%      204     51      0      1221     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      531.776830158
#   Dual bound        531.776830158
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.1100070474
#   Solution status   feasible
#                     531.776830158 (objective)
#                     0 (bound viol.)
#                     1.5537608651e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.35
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1221
#                     0 (strong br.)
#                     53 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 6 |values| in [8.88178e-16, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31551 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 8e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-16, 6e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9152 rows, 3071 cols, 15137 nonzeros  0s
# 2820 rows, 2626 cols, 8646 nonzeros  0s
# 2262 rows, 1680 cols, 5790 nonzeros  0s
# 1823 rows, 1678 cols, 4888 nonzeros  0s
# Presolve reductions: rows 1823(-10949); columns 1678(-6387); nonzeros 4888(-26663)
#
# Solving MIP model with:
#    1823 rows
#    1678 cols (399 binary, 0 integer, 0 implied int., 1279 continuous, 0 domain fixed)
#    4888 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2451.242014       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   1985.672881     1820.516996        9.07%        0      0      0      1205     0.2s
#  H       0       0         0   0.00%   1985.672881     1985.672881        0.00%      264     78      0      1284     0.5s
#          1       0         1 100.00%   1985.672881     1985.672881        0.00%      264     78      0      1284     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      1985.67288109
#   Dual bound        1985.67288109
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      2.17425597673
#   Solution status   feasible
#                     1985.67288109 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.48
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1284
#                     0 (strong br.)
#                     79 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-01-20 00:00:00 2025-01-26 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15020 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [6e+00, 1e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4266 rows, 2687 cols, 9406 nonzeros  0s
# 2250 rows, 2248 cols, 6949 nonzeros  0s
# 1741 rows, 1336 cols, 4179 nonzeros  0s
# 1288 rows, 1334 cols, 3271 nonzeros  0s
# Presolve reductions: rows 1288(-6108); columns 1334(-2699); nonzeros 3271(-11749)
#
# Solving MIP model with:
#    1288 rows
#    1334 cols (232 binary, 0 integer, 0 implied int., 1102 continuous, 0 domain fixed)
#    3271 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             8417.894337        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   14208.045229    11917.706121      19.22%        0      0      0      1013     0.1s
#  L       0       0         0   0.00%   14208.045229    14208.045229       0.00%      340    157      0      1171     0.5s
#          1       0         1 100.00%   14208.045229    14208.045229       0.00%      340    157      0      1267     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      14208.0452286
#   Dual bound        14208.0452286
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.343862099377
#   Solution status   feasible
#                     14208.0452286 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.49
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1267
#                     0 (strong br.)
#                     158 (separation)
#                     96 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 3 |values| in [6.63647e-15, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31592 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [5e+00, 2e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [3e-17, 5e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9181 rows, 3109 cols, 15311 nonzeros  0s
# 2887 rows, 2674 cols, 8826 nonzeros  0s
# 2340 rows, 1749 cols, 6039 nonzeros  0s
# 1902 rows, 1745 cols, 5140 nonzeros  0s
# Presolve reductions: rows 1902(-10870); columns 1745(-6320); nonzeros 5140(-26452)
#
# Solving MIP model with:
#    1902 rows
#    1745 cols (425 binary, 0 integer, 0 implied int., 1320 continuous, 0 domain fixed)
#    5140 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -6345.65243        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1008.306822     966.5870793        4.32%        0      0      0      1289     0.1s
#  H       0       0         0   0.00%   1008.306822     1008.306822        0.00%      308     77      0      1366     0.2s
#          1       0         1 100.00%   1008.306822     1008.306822        0.00%      308     77      0      1366     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1008.30682225
#   Dual bound        1008.30682225
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.481737677243
#   Solution status   feasible
#                     1008.30682225 (objective)
#                     0 (bound viol.)
#                     5.3290705182e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.22
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1366
#                     0 (strong br.)
#                     77 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 8 |values| in [7.88861e-31, 3.55271e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31606 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [5e-04, 2e+02]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-31, 5e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9202 rows, 3151 cols, 15484 nonzeros  0s
# 2943 rows, 2715 cols, 8988 nonzeros  0s
# 2393 rows, 1787 cols, 6191 nonzeros  0s
# 1960 rows, 1783 cols, 5300 nonzeros  0s
# Presolve reductions: rows 1960(-10812); columns 1783(-6282); nonzeros 5300(-26306)
#
# Solving MIP model with:
#    1960 rows
#    1783 cols (444 binary, 0 integer, 0 implied int., 1339 continuous, 0 domain fixed)
#    5300 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -6443.616229       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   4704.530199     4680.034302        0.52%        0      0      0      1303     0.3s
#  H       0       0         0   0.00%   4704.530199     4704.530199        0.00%      261     76      0      1380     0.5s
#          1       0         1 100.00%   4704.530199     4704.530199        0.00%      261     76      0      1380     0.5s
#
# Solving report
#   Status            Optimal
#   Primal bound      4704.5301994
#   Dual bound        4704.5301994
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.15846443617
#   Solution status   feasible
#                     4704.5301994 (objective)
#                     0 (bound viol.)
#                     4.99600361081e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.51
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1380
#                     0 (strong br.)
#                     77 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-01-27 00:00:00 2025-02-02 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15040 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [3e+00, 5e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4286 rows, 2687 cols, 9406 nonzeros  0s
# 2270 rows, 2268 cols, 6969 nonzeros  0s
# 1784 rows, 1397 cols, 4325 nonzeros  0s
# 1350 rows, 1395 cols, 3455 nonzeros  0s
# Presolve reductions: rows 1350(-6046); columns 1395(-2638); nonzeros 3455(-11585)
#
# Solving MIP model with:
#    1350 rows
#    1395 cols (252 binary, 0 integer, 0 implied int., 1143 continuous, 0 domain fixed)
#    3455 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             7426.184976        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   10179.433753    9024.026232       12.80%        0      0      0      1060     0.1s
#  L       0       0         0   0.00%   10179.433753    10179.433753       0.00%      409    163      0      1220     0.3s
#  T       0       0         0   0.00%   10179.433753    10179.433753       0.00%      409    163      0      1252     0.3s
#          1       0         1 100.00%   10179.433753    10179.433753       0.00%      409    163      0      1252     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      10179.4337525
#   Dual bound        10179.4337525
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.328397948769
#   Solution status   feasible
#                     10179.4337525 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.28
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1252
#                     0 (strong br.)
#                     160 (separation)
#                     32 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 4 |values| in [6.63647e-15, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31648 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [5e-01, 5e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-16, 4e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9221 rows, 3149 cols, 15476 nonzeros  0s
# 2965 rows, 2732 cols, 9017 nonzeros  0s
# 2034 rows, 1836 cols, 5508 nonzeros  0s
# 2007 rows, 1836 cols, 5454 nonzeros  0s
# Presolve reductions: rows 2007(-10765); columns 1836(-6229); nonzeros 5454(-26194)
#
# Solving MIP model with:
#    2007 rows
#    1836 cols (456 binary, 0 integer, 0 implied int., 1380 continuous, 0 domain fixed)
#    5454 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -3201.256189       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   738.9860278     711.8319855        3.81%        0      0      0      1231     0.2s
#  C       0       0         0   0.00%   738.9860278     723.1383336        2.19%      187     52      0      1287     0.3s
#  H       0       0         0   0.00%   738.9860278     738.9860278        0.00%      187     52      0      1287     0.3s
#          1       0         1 100.00%   738.9860278     738.9860278        0.00%      187     52      0      1287     0.3s
#
# Solving report
#   Status            Optimal
#   Primal bound      738.986027825
#   Dual bound        738.986027825
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.28111321476
#   Solution status   feasible
#                     738.986027825 (objective)
#                     0 (bound viol.)
#                     2.55351295664e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.32
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1287
#                     0 (strong br.)
#                     56 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 9 |values| in [7.88861e-31, 8.88178e-16] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31654 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [9e-03, 7e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-31, 4e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9229 rows, 3165 cols, 15545 nonzeros  0s
# 2983 rows, 2742 cols, 9084 nonzeros  0s
# 2030 rows, 1830 cols, 5505 nonzeros  0s
# 2007 rows, 1830 cols, 5459 nonzeros  0s
# Presolve reductions: rows 2007(-10765); columns 1830(-6235); nonzeros 5459(-26195)
#
# Solving MIP model with:
#    2007 rows
#    1830 cols (454 binary, 0 integer, 0 implied int., 1376 continuous, 0 domain fixed)
#    5459 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -2694.302625       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1272.480417     1247.783314        1.98%        0      0      0      1307     0.2s
#  H       0       0         0   0.00%   1272.480417     1272.480417        0.00%      471    120      0      1435     0.4s
#          1       0         1 100.00%   1272.480417     1272.480417        0.00%      471    120      0      1435     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      1272.4804166
#   Dual bound        1272.4804166
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.45945603056
#   Solution status   feasible
#                     1272.4804166 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.39
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1435
#                     0 (strong br.)
#                     128 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-02-03 00:00:00 2025-02-09 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15050 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 6e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4296 rows, 2687 cols, 9406 nonzeros  0s
# 2280 rows, 2278 cols, 6979 nonzeros  0s
# 1807 rows, 1429 cols, 4400 nonzeros  0s
# 1382 rows, 1425 cols, 3549 nonzeros  0s
# Presolve reductions: rows 1382(-6014); columns 1425(-2608); nonzeros 3549(-11501)
#
# Solving MIP model with:
#    1382 rows
#    1425 cols (262 binary, 0 integer, 0 implied int., 1163 continuous, 0 domain fixed)
#    3549 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             15350.967412       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   19502.672742    18133.480454       7.55%        0      0      0       939     0.1s
#  C       0       0         0   0.00%   19502.672742    18400.107897       5.99%      266    123      0      1063     0.2s
#  L       0       0         0   0.00%   19502.672742    19502.672742       0.00%      398    147      0      1102     0.6s
#          1       0         1 100.00%   19502.672742    19502.672742       0.00%      398    147      0      1153     0.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      19502.6727422
#   Dual bound        19502.6727422
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.164481303092
#   Solution status   feasible
#                     19502.6727422 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.57
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1153
#                     0 (strong br.)
#                     163 (separation)
#                     51 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 4 |values| in [6.63647e-15, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31626 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 7e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-18, 2e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9196 rows, 3079 cols, 15133 nonzeros  0s
# 2863 rows, 2665 cols, 8691 nonzeros  0s
# 1895 rows, 1758 cols, 5118 nonzeros  0s
# 1863 rows, 1758 cols, 5054 nonzeros  0s
# Presolve reductions: rows 1863(-10909); columns 1758(-6307); nonzeros 5054(-26572)
#
# Solving MIP model with:
#    1863 rows
#    1758 cols (405 binary, 0 integer, 0 implied int., 1353 continuous, 0 domain fixed)
#    5054 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4571.591868       Large        0      0      0         0     0.2s
#  R       0       0         0   0.00%   1222.827086     1093.736248       11.80%        0      0      0      1103     0.2s
#  H       0       0         0   0.00%   1222.827086     1222.827086        0.00%      131     53      0      1161     0.4s
#          1       0         1 100.00%   1222.827086     1222.827086        0.00%      131     53      0      1161     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      1222.82708589
#   Dual bound        1222.82708589
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.04911739204
#   Solution status   feasible
#                     1222.82708589 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.38
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1161
#                     0 (strong br.)
#                     58 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 12 |values| in [7.88861e-31, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31664 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [6e+00, 8e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-31, 2e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9238 rows, 3163 cols, 15491 nonzeros  0s
# 2985 rows, 2745 cols, 9053 nonzeros  0s
# 1997 rows, 1826 cols, 5417 nonzeros  0s
# 1967 rows, 1826 cols, 5357 nonzeros  0s
# Presolve reductions: rows 1967(-10805); columns 1826(-6239); nonzeros 5357(-26307)
#
# Solving MIP model with:
#    1967 rows
#    1826 cols (439 binary, 0 integer, 0 implied int., 1387 continuous, 0 domain fixed)
#    5357 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -4206.81997        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   1397.399493     1314.870304        6.28%        0      0      0      1133     0.2s
#  C       0       0         0   0.00%   1397.399493     1330.181672        5.05%      163     43      0      1177     0.3s
#  H       0       0         0   0.00%   1397.399493     1397.399493        0.00%      196     58      0      1193     0.4s
#          1       0         1 100.00%   1397.399493     1397.399493        0.00%      196     58      0      1193     0.4s
#
# Solving report
#   Status            Optimal
#   Primal bound      1397.39949327
#   Dual bound        1397.39949327
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.30527805615
#   Solution status   feasible
#                     1397.39949327 (objective)
#                     0 (bound viol.)
#                     3.10862446895e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.44
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1193
#                     0 (strong br.)
#                     60 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-02-10 00:00:00 2025-02-16 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 15059 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [2e+01, 7e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4305 rows, 2689 cols, 9411 nonzeros  0s
# 2292 rows, 2289 cols, 6996 nonzeros  0s
# 1829 rows, 1458 cols, 4474 nonzeros  0s
# 1417 rows, 1456 cols, 3647 nonzeros  0s
# Presolve reductions: rows 1417(-5979); columns 1456(-2577); nonzeros 3647(-11412)
#
# Solving MIP model with:
#    1417 rows
#    1456 cols (272 binary, 0 integer, 0 implied int., 1184 continuous, 0 domain fixed)
#    3647 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
# ...
#                     615.491124545 (objective)
#                     0 (bound viol.)
#                     1.55431223448e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1110
#                     0 (strong br.)
#                     41 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-12-15 00:00:00 2025-12-21 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14997 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [8e-01, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4243 rows, 2687 cols, 9406 nonzeros  0s
# 2227 rows, 2225 cols, 6926 nonzeros  0s
# 1698 rows, 1268 cols, 4024 nonzeros  0s
# 1220 rows, 1266 cols, 3066 nonzeros  0s
# Presolve reductions: rows 1220(-6176); columns 1266(-2767); nonzeros 3066(-11931)
#
# Solving MIP model with:
#    1220 rows
#    1266 cols (209 binary, 0 integer, 0 implied int., 1057 continuous, 0 domain fixed)
#    3066 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             5458.868776        Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   6805.134347     6268.3883          8.56%        0      0      0       949     0.1s
#  L       0       0         0   0.00%   6805.134347     6805.134347        0.00%      175     80      0      1029     0.2s
#  T       0       0         0   0.00%   6805.134347     6805.134347        0.00%      175     80      0      1039     0.2s
#          1       0         1 100.00%   6805.134347     6805.134347        0.00%      175     80      0      1039     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      6805.13434663
#   Dual bound        6805.13434663
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.164396131844
#   Solution status   feasible
#                     6805.13434663 (objective)
#                     0 (bound viol.)
#                     3.99680288865e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1039
#                     0 (strong br.)
#                     80 (separation)
#                     10 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 12772 rows; 8065 cols; 31459 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [6e-01, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [9e-16, 7e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9073 rows, 2939 cols, 14543 nonzeros  0s
# 2606 rows, 2478 cols, 8036 nonzeros  0s
# 2042 rows, 1505 cols, 5100 nonzeros  0s
# 1576 rows, 1503 cols, 4146 nonzeros  0s
# Presolve reductions: rows 1576(-11196); columns 1503(-6562); nonzeros 4146(-27313)
#
# Solving MIP model with:
#    1576 rows
#    1503 cols (318 binary, 0 integer, 0 implied int., 1185 continuous, 0 domain fixed)
#    4146 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1146.301003       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   38.60252838     29.65045699       30.19%        0      0      0      1005     0.1s
#  H       0       0         0   0.00%   38.60252838     38.60252838        0.00%       74     24      0      1029     0.1s
#          1       0         1 100.00%   38.60252838     38.60252838        0.00%       74     24      0      1029     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      38.6025283787
#   Dual bound        38.6025283787
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.04977843451
#   Solution status   feasible
#                     38.6025283787 (objective)
#                     0 (bound viol.)
#                     6.66133814775e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.14
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1029
#                     0 (strong br.)
#                     24 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 2 |values| in [8.88178e-16, 3.31823e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31463 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [7e-05, 4e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [2e-16, 7e+01]
# WARNING: Problem has some excessively small costs
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9077 rows, 2947 cols, 14584 nonzeros  0s
# 2620 rows, 2488 cols, 8079 nonzeros  0s
# 2061 rows, 1522 cols, 5163 nonzeros  0s
# 1600 rows, 1520 cols, 4220 nonzeros  0s
# Presolve reductions: rows 1600(-11172); columns 1520(-6545); nonzeros 4220(-27243)
#
# Solving MIP model with:
#    1600 rows
#    1520 cols (326 binary, 0 integer, 0 implied int., 1194 continuous, 0 domain fixed)
#    4220 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -843.5499456       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   413.4850249     384.0192267        7.67%        0      0      0      1032     0.1s
#  H       0       0         0   0.00%   413.4850249     413.4850249        0.00%      256     83      0      1114     0.2s
#          1       0         1 100.00%   413.4850249     413.4850249        0.00%      256     83      0      1114     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      413.485024881
#   Dual bound        413.485024881
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.40619492934
#   Solution status   feasible
#                     413.485024881 (objective)
#                     0 (bound viol.)
#                     1.11022302463e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.16
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1114
#                     0 (strong br.)
#                     82 (separation)
#                     0 (heuristics)
# Optimal solution found.
# start/end 2025-12-22 00:00:00 2025-12-28 23:45:00
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# MIP has 7396 rows; 4033 cols; 14997 nonzeros; 1344 integer variables (1344 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [1e+01, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-02, 1e+02]
# Presolving model
# 4243 rows, 2687 cols, 9406 nonzeros  0s
# 2227 rows, 2225 cols, 6926 nonzeros  0s
# 1698 rows, 1268 cols, 4024 nonzeros  0s
# 1216 rows, 1263 cols, 3057 nonzeros  0s
# Presolve reductions: rows 1216(-6180); columns 1263(-2770); nonzeros 3057(-11940)
#
# Solving MIP model with:
#    1216 rows
#    1263 cols (208 binary, 0 integer, 0 implied int., 1055 continuous, 0 domain fixed)
#    3057 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             4161.119422        Large        0      0      0         0     0.0s
#  R       0       0         0   0.00%   5361.044456     4805.509511       11.56%        0      0      0       997     0.1s
#  L       0       0         0   0.00%   5361.044456     5361.044456        0.00%      246    111      0      1108     0.1s
#  T       0       0         0   0.00%   5361.044456     5361.044456        0.00%      246    111      0      1153     0.1s
#          1       0         1 100.00%   5361.044456     5361.044456        0.00%      246    111      0      1153     0.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      5361.04445551
#   Dual bound        5361.04445551
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.153108986858
#   Solution status   feasible
#                     5361.04445551 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.14
#   Max sub-MIP depth 1
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1153
#                     0 (strong br.)
#                     111 (separation)
#                     45 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 5 |values| in [3.24046e-18, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31505 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [1e+01, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [9e-19, 6e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9118 rows, 3029 cols, 14952 nonzeros  0s
# 2744 rows, 2571 cols, 8446 nonzeros  0s
# 1758 rows, 1605 cols, 4660 nonzeros  0s
# 1727 rows, 1605 cols, 4598 nonzeros  0s
# Presolve reductions: rows 1727(-11045); columns 1605(-6460); nonzeros 4598(-26907)
#
# Solving MIP model with:
#    1727 rows
#    1605 cols (367 binary, 0 integer, 0 implied int., 1238 continuous, 0 domain fixed)
#    4598 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -1161.940036       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   65.60299212     65.35991208        0.37%        0      0      0      1018     0.1s
#  H       0       0         0   0.00%   65.60299212     65.60299212        0.00%       69     18      0      1036     0.2s
#          1       0         1 100.00%   65.60299212     65.60299212        0.00%       69     18      0      1036     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      65.6029921199
#   Dual bound        65.6029921199
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      0.984292958355
#   Solution status   feasible
#                     65.6029921199 (objective)
#                     0 (bound viol.)
#                     2.36477504245e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.18
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1036
#                     0 (strong br.)
#                     18 (separation)
#                     0 (heuristics)
# Optimal solution found.
# Running HiGHS 1.13.0 (git hash: 1bce6d5): Copyright (c) 2026 under MIT licence terms
# WARNING: LP matrix packed vector contains 6 |values| in [3.85186e-34, 6.63647e-15] less than or equal to 1e-09: ignored
# MIP has 12772 rows; 8065 cols; 31480 nonzeros; 3360 integer variables (3360 binary)
# Coefficient ranges:
#   Matrix  [1e-02, 8e+00]
#   Cost    [5e+00, 3e+01]
#   Bound   [1e+00, 1e+00]
#   RHS     [1e-34, 7e+01]
# WARNING: Problem has some excessively small row bounds
# Presolving model
# 9092 rows, 2977 cols, 14720 nonzeros  0s
# 2666 rows, 2519 cols, 8212 nonzeros  0s
# 2111 rows, 1555 cols, 5304 nonzeros  0s
# 1652 rows, 1552 cols, 4369 nonzeros  0s
# Presolve reductions: rows 1652(-11120); columns 1552(-6513); nonzeros 4369(-27111)
#
# Solving MIP model with:
#    1652 rows
#    1552 cols (343 binary, 0 integer, 0 implied int., 1209 continuous, 0 domain fixed)
#    4369 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   inf             -855.4963332       Large        0      0      0         0     0.1s
#  R       0       0         0   0.00%   415.1063052     337.8074697       22.88%        0      0      0      1068     0.1s
#  H       0       0         0   0.00%   415.1063052     415.1063052        0.00%      200     73      0      1142     0.2s
#          1       0         1 100.00%   415.1063052     415.1063052        0.00%      200     73      0      1142     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      415.106305159
#   Dual bound        415.106305159
#   Gap               0% (tolerance: 0.01%)
#   P-D integral      1.14936539175
#   Solution status   feasible
#                     415.106305159 (objective)
#                     0 (bound viol.)
#                     5.65655784649e-14 (int. viol.)
#                     0 (row viol.)
#   Timing            0.17
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     1142
#                     0 (strong br.)
#                     74 (separation)
#                     0 (heuristics)
# Optimal solution found.

# %%
pd.set_option("display.max_columns", None)
results.head()
# Out:
#                      daa_price  ida_price   idc_price  pv_output  \
# 2024-12-30 00:00:00      71.73  86.585943  102.808704        0.0
# 2024-12-30 00:15:00      71.73  83.518208   87.572893        0.0
# 2024-12-30 00:30:00      71.73  75.519725   79.394564        0.0
# 2024-12-30 00:45:00      71.73  68.232719   73.844625        0.0
# 2024-12-30 01:00:00      68.60  86.079054   77.738717        0.0
#
#                      p_charge_daa  p_discharge_daa  p_curtailed_daa  soc_daa  \
# 2024-12-30 00:00:00           0.0              0.0              0.0      0.0
# 2024-12-30 00:15:00           0.0              0.0              0.0      0.0
# 2024-12-30 00:30:00           0.0              0.0              0.0      0.0
# 2024-12-30 00:45:00           0.0              0.0              0.0      0.0
# 2024-12-30 01:00:00           0.0              0.0              0.0      0.0
#
#                      injection_power_daa  p_charge_ida  p_discharge_ida  \
# 2024-12-30 00:00:00                  0.0           0.0              0.0
# 2024-12-30 00:15:00                  0.0           0.0              0.0
# 2024-12-30 00:30:00                  0.0           0.0              0.0
# 2024-12-30 00:45:00                  0.0           0.0              0.0
# 2024-12-30 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa  p_close_discharge_daa  \
# 2024-12-30 00:00:00                 0.0                    0.0
# 2024-12-30 00:15:00                 0.0                    0.0
# 2024-12-30 00:30:00                 0.0                    0.0
# 2024-12-30 00:45:00                 0.0                    0.0
# 2024-12-30 01:00:00                 0.0                    0.0
#
#                      p_curtailed_ida  p_close_curtailed_daa  p_charge_daa_ida  \
# 2024-12-30 00:00:00              0.0                    0.0               0.0
# 2024-12-30 00:15:00              0.0                    0.0               0.0
# 2024-12-30 00:30:00              0.0                    0.0               0.0
# 2024-12-30 00:45:00              0.0                    0.0               0.0
# 2024-12-30 01:00:00              0.0                    0.0               0.0
#
#                      p_discharge_daa_ida  p_curtailed_daa_ida  soc_ida  \
# 2024-12-30 00:00:00                  0.0                  0.0      0.0
# 2024-12-30 00:15:00                  0.0                  0.0      0.0
# 2024-12-30 00:30:00                  0.0                  0.0      0.0
# 2024-12-30 00:45:00                  0.0                  0.0      0.0
# 2024-12-30 01:00:00                  0.0                  0.0      0.0
#
#                      injection_power_ida  p_charge_idc  p_discharge_idc  \
# 2024-12-30 00:00:00                  0.0           0.0              0.0
# 2024-12-30 00:15:00                  0.0           0.0              0.0
# 2024-12-30 00:30:00                  0.0           0.0              0.0
# 2024-12-30 00:45:00                  0.0           0.0              0.0
# 2024-12-30 01:00:00                  0.0           0.0              0.0
#
#                      p_close_charge_daa_ida  p_close_discharge_daa_ida  \
# 2024-12-30 00:00:00                     0.0                        0.0
# 2024-12-30 00:15:00                     0.0                        0.0
# 2024-12-30 00:30:00                     0.0                        0.0
# 2024-12-30 00:45:00                     0.0                        0.0
# 2024-12-30 01:00:00                     0.0                        0.0
#
#                      p_curtailed_idc  p_close_curtailed_daa_ida  \
# 2024-12-30 00:00:00              0.0                        0.0
# 2024-12-30 00:15:00              0.0                        0.0
# 2024-12-30 00:30:00              0.0                        0.0
# 2024-12-30 00:45:00              0.0                        0.0
# 2024-12-30 01:00:00              0.0                        0.0
#
#                      p_charge_daa_ida_idc  p_discharge_daa_ida_idc  \
# 2024-12-30 00:00:00                   0.0                      0.0
# 2024-12-30 00:15:00                   0.0                      0.0
# 2024-12-30 00:30:00                   0.0                      0.0
# 2024-12-30 00:45:00                   0.0                      0.0
# 2024-12-30 01:00:00                   0.0                      0.0
#
#                      p_curtailed_daa_ida_idc  soc_idc  injection_power_idc
# 2024-12-30 00:00:00                      0.0      0.0                  0.0
# 2024-12-30 00:15:00                      0.0      0.0                  0.0
# 2024-12-30 00:30:00                      0.0      0.0                  0.0
# 2024-12-30 00:45:00                      0.0      0.0                  0.0
# 2024-12-30 01:00:00                      0.0      0.0                  0.0

# %% [markdown]
# ### Plot the results

# %%
# Plotting the results
# Set timerange for plotting
plot_start = pd.to_datetime('2025-06-21 00:00:00')
plot_end = pd.to_datetime('2025-06-28 23:45:00')

results_slice = results[plot_start:plot_end]

fig, ax = plt.subplots(21, 1, figsize=(12,36))
ax[0].plot(results_slice.pv_output, label='PV Power [MW]', color='yellow')
ax[1].plot(results_slice.daa_price, label='DAA [€/MWh]', color='blue')
ax[2].plot(results_slice.ida_price, label='IDA [€/MWh]', color='cyan')
ax[3].plot(results_slice.idc_price, label='IDC [€/MWh]', color='magenta')
ax[4].plot(results_slice.p_charge_daa, label='Charge Power DAA [MW]', color='red')
ax[4].plot(-results_slice.p_discharge_daa, label='Discharge Power DAA [MW]', color='orange')
ax[5].plot(results_slice.p_curtailed_daa, label='Curtailed Power DAA [MW]', color='violet')
ax[6].plot(results_slice.soc_daa, label='SoC [MWh] DAA', color='green')
ax[7].plot(results_slice.injection_power_daa, label='Injection Power DAA [MW]', color='black')

ax[8].plot(results_slice.p_close_charge_daa, label='Closed Charge Power DAA [MW]', color='yellow')
ax[8].plot(-results_slice.p_close_discharge_daa, label='Closed Discharge Power DAA [MW]', color='goldenrod')
ax[9].plot(results_slice.p_charge_ida, label='Charge Power IDA [MW]', color='lightblue')
ax[9].plot(-results_slice.p_discharge_ida, label='Discharge Power IDA [MW]', color='blue')
ax[10].plot(results_slice.p_close_curtailed_daa, label='Closed Curtailed Power DAA [MW]', color='plum')
ax[11].plot(results_slice.p_curtailed_daa_ida, label='Curtailed Power DAA IDA [MW]', color='lightcoral')
ax[12].plot(results_slice.soc_ida, label='SoC [MWh] IDA', color='lime')
ax[13].plot(results_slice.injection_power_ida, label='Injection Power DAA IDA [MW]', color='plum')

ax[14].plot(results_slice.p_close_charge_daa_ida, label='Closed Charge Power DAA IDA [MW]', color='lightgreen')
ax[14].plot(-results_slice.p_close_discharge_daa_ida, label='Closed Discharge Power DAA IDA [MW]', color='green')
ax[15].plot(results_slice.p_charge_idc, label='Charge Power IDC [MW]', color='#bfcf7c')
ax[15].plot(-results_slice.p_discharge_idc, label='Discharge Power IDC [MW]', color='olive') #, ls='', marker='_')
ax[16].plot(results_slice.p_close_curtailed_daa_ida, label='Closed Curtailed Power DAA IDA [MW]', color='plum')
ax[17].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='lightcoral')
ax[18].plot(results_slice.soc_idc, label='SoC [MWh] IDC', color='lime')
ax[19].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='plum')
ax[20].plot(results_slice.pv_output, label='PV Power [MW]', color='orange')
ax[20].plot(results_slice.injection_power_idc, label='Injection Power DAA IDA IDC [MW]', color='red')
ax[20].plot(results_slice.p_curtailed_daa_ida_idc, label='Curtailed Power DAA IDA IDC [MW]', color='darkred')

ax[20].set_xlabel('Time')

for i in range(21):
    ax[i].legend()
    ax[i].grid()


plt.tight_layout()
# plt.show()
plt.savefig('results.png')

# %% [markdown]
# ### Calculate energies and profits

# %%
##### Calculate energies
pv_production = results.pv_output.sum() * 15 / 60  # Convert from MW to MWh
injected_energy_daa = results.injection_power_daa.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_daa = results.p_curtailed_daa.sum() * 15 / 60 # Convert from MW to MWh
discharge_energy_daa = results.p_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa = results.p_charge_daa.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_ida = results.injection_power_ida.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_ida = results.p_curtailed_daa_ida.sum() * 15 / 60 # Convert from MW to MWh
closed_curtailed_daa_energy = results.p_close_curtailed_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_ida = results.p_discharge_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_ida = results.p_charge_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_energy = results.p_close_discharge_daa.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_energy = results.p_close_charge_daa.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida = results.p_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida = results.p_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh

injected_energy_idc = results.injection_power_idc.sum() * 15 / 60  # Convert from MW to MWh
curtailed_energy_idc = results.p_curtailed_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_curtailed_daa_ida_energy = results.p_close_curtailed_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_idc = results.p_discharge_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_idc = results.p_charge_idc.sum() * 15 / 60  # Convert from MW to MWh
closed_discharge_daa_ida_energy = results.p_close_discharge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
closed_charge_daa_ida_energy = results.p_close_charge_daa_ida.sum() * 15 / 60  # Convert from MW to MWh
discharge_energy_daa_ida_idc = results.p_discharge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh
charge_energy_daa_ida_idc = results.p_charge_daa_ida_idc.sum() * 15 / 60  # Convert from MW to MWh

# Print calculated energies
print('Annual Energies:')
print('==========================================')
print('PV')
print('----------')
print('PV Production:', f'{pv_production:.2f} MWh')
print('------------------------------------------')
print('DAA Market')
print('----------')
print('Injected Energy DAA:', f'{injected_energy_daa:.2f} MWh')
print('Curtailed Energy DAA:', f'{curtailed_energy_daa:.2f} MWh')
print('Charge Energy DAA:', f'{charge_energy_daa:.2f} MWh')
print('Discharge Energy DAA:', f'{discharge_energy_daa:.2f} MWh')
print('------------------------------------------')
print('IDA Market')
print('----------')
print('Injected Energy IDA:', f'{injected_energy_ida:.2f} MWh')
print('Curtailed Energy IDA:', f'{curtailed_energy_ida:.2f} MWh')
print('Closed Curtailed Energy DAA:', f'{closed_curtailed_daa_energy:.2f} MWh')
print('Charge Energy IDA:', f'{charge_energy_ida:.2f} MWh')
print('Discharge Energy IDA:', f'{discharge_energy_ida:.2f} MWh')
print('Closed Charge Energy DAA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA:', f'{charge_energy_daa_ida:.2f} MWh')
print('Physical Discharge Energy DAA IDA:', f'{discharge_energy_daa_ida:.2f} MWh')
print('------------------------------------------')
print('IDC Market')
print('----------')
print('Injected Energy IDC:', f'{injected_energy_idc:.2f} MWh')
print('Curtailed Energy IDC:', f'{curtailed_energy_idc:.2f} MWh')
print('Closed Curtailed Energy DAA IDA:', f'{closed_curtailed_daa_ida_energy:.2f} MWh')
print('Charge Energy IDC:', f'{charge_energy_idc:.2f} MWh')
print('Discharge Energy IDC:', f'{discharge_energy_idc:.2f} MWh')
print('Closed Charge Energy DAA IDA:', f'{closed_charge_daa_ida_energy:.2f} MWh')
print('Closed Discharge Energy DAA IDA:', f'{closed_discharge_daa_ida_energy:.2f} MWh')
print('Physical Charge Energy DAA IDA IDC:', f'{charge_energy_daa_ida_idc:.2f} MWh')
print('Physical Discharge Energy DAA IDA IDC:', f'{discharge_energy_daa_ida_idc:.2f} MWh')
print('------------------------------------------')

##### Calculate profits
# Calculate annual profit from PV Output multiplied with DAA prices as reference
results['pv_direct_market_profit_reference'] = results.daa_price * results.pv_output * 15 / 60
# Only sum up profit at positive market prices, because plant will be curtailed at other times
condition_daa_positive = results.daa_price >= 0
annual_pv_production_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'pv_output'].sum() * 15 / 60
annual_pv_direct_market_profit_reference = results.loc[condition_daa_positive, 'pv_direct_market_profit_reference'].sum()

# Calculate annual profit on DAA market
results['injected_power_direct_market_profit_daa'] = results.daa_price * results.injection_power_daa * 15 / 60
annual_injected_energy_direct_market_profit_daa = results.injected_power_direct_market_profit_daa.sum()

# Calculate annual profit on IDA market
results['ida_market_profit'] = (results['p_discharge_ida'] - results['p_charge_ida'] 
                                + results['p_close_charge_daa'] - results['p_close_discharge_daa'] 
                                + results['p_close_curtailed_daa'] - results['p_curtailed_ida']) * results['ida_price']  / 4
annual_ida_market_profit = results['ida_market_profit'].sum()

# Calculate annual profit on IDC market
results['idc_market_profit'] = (results['p_discharge_idc'] - results['p_charge_idc'] 
                                + results['p_close_charge_daa_ida'] - results['p_close_discharge_daa_ida'] 
                                + results['p_close_curtailed_daa_ida'] - results['p_curtailed_idc']) * results['idc_price']  / 4
annual_idc_market_profit = results['idc_market_profit'].sum()

# Print annual profit values
print('Annual Direct Market Profits:')
print('----------------------------------------------------------------------------------------')
print('Annual PV Direct Market Profit (Reference):', f'{annual_pv_direct_market_profit_reference:.2f} €', '(excl. negative DAA price hours)')
print('Annual Injected Energy Direct Market Profit (DAA):', f'{annual_injected_energy_direct_market_profit_daa:.2f} €')
print('Annual IDA Market Profit:', f'{annual_ida_market_profit:.2f} €')
print('Annual IDC Market Profit:', f'{annual_idc_market_profit:.2f} €')
print('----------------------------------------------------------------------------------------')

# Calculate annual market bonus
annual_injected_energy_idc_excl_negative_market_price_hours = results.loc[condition_daa_positive, 'injection_power_idc'].sum() * 15 / 60
market_bonus_injected_energy_idc = annual_injected_energy_idc_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_injected_energy_idc < 0:
    market_bonus_injected_energy_idc = 0
market_bonus_pv_production = annual_pv_production_excl_negative_market_price_hours * (applicable_value - market_value)
if market_bonus_pv_production < 0:
    market_bonus_pv_production = 0

print('Annual Market Boni:')
print('------------------------------------------------------------------')
print('Annual Market Bonus PV + BESS (IDC):', f'{market_bonus_injected_energy_idc:.2f} €', '(excl. negative DAA price hours)')
print('Annual Market Bonus PV only:', f'{market_bonus_pv_production:.2f} €', '(excl. negative DAA price hours)')
print('------------------------------------------------------------------')

# Calculate number of hours with negative DAA prices
number_of_hours_negative_daa_price = len(results[results.daa_price < 0])
print('Negative price hours:')
print('------------------------------------------------------------')
print('Number of hours with negative DAA prices:', number_of_hours_negative_daa_price * 15 / 60, 'hours')
print('------------------------------------------------------------')

# Final results
print('Final Results:')
print('------------------------------------------------------------')
print('Annual profit PV only (reference):', f'{market_bonus_pv_production + annual_pv_direct_market_profit_reference:.2f} €')
print('Annual profit PV + BESS (DAA IDA IDC):', f'{market_bonus_injected_energy_idc 
                                                   + annual_injected_energy_direct_market_profit_daa 
                                                   + annual_ida_market_profit + annual_idc_market_profit:.2f} €')
print('Annual BESS profit (DAA IDA IDC):', f'{annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production :.2f} €')
print('Specific Annual BESS profit (DAA IDA IDC):', f'{(annual_injected_energy_direct_market_profit_daa + market_bonus_injected_energy_idc + annual_ida_market_profit + annual_idc_market_profit
                                                   - annual_pv_direct_market_profit_reference - market_bonus_pv_production) / storage_capacity:.2f} €/MWh')
# Out:
# Annual Energies:
# ==========================================
# PV
# ----------
# PV Production: 15696.87 MWh
# ------------------------------------------
# DAA Market
# ----------
# Injected Energy DAA: 12491.65 MWh
# Curtailed Energy DAA: 2637.77 MWh
# Charge Energy DAA: 4445.52 MWh
# Discharge Energy DAA: 3878.08 MWh
# ------------------------------------------
# IDA Market
# ----------
# Injected Energy IDA: 13003.16 MWh
# Curtailed Energy IDA: 2123.90 MWh
# Closed Curtailed Energy DAA: 1017.18 MWh
# Charge Energy IDA: 1217.68 MWh
# Discharge Energy IDA: 2148.21 MWh
# Closed Charge Energy DAA: 1202.99 MWh
# Closed Discharge Energy DAA: 1793.50 MWh
# Physical Charge Energy DAA IDA: 4464.06 MWh
# Physical Discharge Energy DAA IDA: 3894.25 MWh
# ------------------------------------------
# IDC Market
# ----------
# Injected Energy IDC: 12698.25 MWh
# Curtailed Energy IDC: 2429.22 MWh
# Closed Curtailed Energy DAA IDA: 635.85 MWh
# Charge Energy IDC: 1199.72 MWh
# Discharge Energy IDC: 1790.64 MWh
# Closed Charge Energy DAA IDA: 1202.99 MWh
# Closed Discharge Energy DAA IDA: 1793.50 MWh
# Physical Charge Energy DAA IDA IDC: 4460.79 MWh
# Physical Discharge Energy DAA IDA IDC: 3891.39 MWh
# ------------------------------------------
# Annual Direct Market Profits:
# ----------------------------------------------------------------------------------------
# Annual PV Direct Market Profit (Reference): 765072.79 € (excl. negative DAA price hours)
# Annual Injected Energy Direct Market Profit (DAA): 1189625.31 €
# Annual IDA Market Profit: 126082.29 €
# Annual IDC Market Profit: 122296.75 €
# ----------------------------------------------------------------------------------------
# Annual Market Boni:
# ------------------------------------------------------------------
# Annual Market Bonus PV + BESS (IDC): 56593.09 € (excl. negative DAA price hours)
# Annual Market Bonus PV only: 57672.39 € (excl. negative DAA price hours)
# ------------------------------------------------------------------
# Negative price hours:
# ------------------------------------------------------------
# Number of hours with negative DAA prices: 574.75 hours
# ------------------------------------------------------------
# Final Results:
# ------------------------------------------------------------
# Annual profit PV only (reference): 822745.18 €
# Annual profit PV + BESS (DAA IDA IDC): 1494597.45 €
# Annual BESS profit (DAA IDA IDC): 671852.26 €
# Specific Annual BESS profit (DAA IDA IDC): 44790.15 €/MWh

# %% [markdown]
# ### Export results to .csv

# %%
# results.to_csv('results.csv')
